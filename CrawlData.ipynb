# %% [markdown]
# ### IMPORT THƯ VIỆN

# %%
import requests
import re
import csv
import time
import html 
from bs4 import BeautifulSoup
from typing import Optional, List, Tuple, Dict
from urllib.parse import urljoin

# %% [markdown]
# ### Thu thập dữ liệu từ thanglong.chinhphu.vn

# %%
import requests
import re
import csv
import time
import html
from bs4 import BeautifulSoup
from typing import Optional, Tuple, List, Dict
from urllib.parse import urljoin

# --- CẤU HÌNH ---
session = requests.Session()
session.headers.update({
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/120.0.0.0 Safari/537.36',
})

DOMAIN = 'https://thanglong.chinhphu.vn'
# Regex bắt link bài viết: thường kết thúc bằng -số_id.htm (VD: ...-10223.htm)
ARTICLE_URL_RE = re.compile(r'-(\d+)\.htm[l]?(?:$|\?)')

# --- CÁC HÀM XỬ LÝ TEXT ---
def clean_text(s: str) -> str:
    if not s: return ''
    s = html.unescape(s)
    s = html.unescape(s)
    return re.sub(r'\s+', ' ', s).strip()

def remove_prefix(text: str) -> str:
    pattern = r'^\s*\(Chinhphu\.vn\)\s*-\s*'
    return re.sub(pattern, '', text, flags=re.IGNORECASE).strip()

def normalize_href(href: str, base_url: str) -> Optional[str]:
    if not href or href.startswith(('javascript:', '#', 'mailto:')): return None
    if href.startswith('//'): return 'https:' + href
    if href.startswith('/'): return urljoin(DOMAIN, href)
    if href.startswith('http'): return href
    return urljoin(base_url, href)

# --- [SỬA ĐỔI QUAN TRỌNG] HÀM TẠO URL PHÂN TRANG ---
def make_page_url(base: str, page: int) -> str:
    """
    Chuyển đổi URL danh mục sang URL trang 2, 3...
    VD: .../thoi-su.htm -> .../thoi-su/trang-2.htm
    """
    if page <= 1: return base
    
    # 1. Bỏ đuôi .htm hoặc .html
    base_no_ext = re.sub(r'\.htm[l]?$', '', base, flags=re.IGNORECASE)
    
    # 2. Thêm đuôi /trang-{page}.htm
    return f"{base_no_ext}/trang-{page}.htm"

# --- HÀM CRAWL CHI TIẾT ---
def parse_article(url: str) -> Tuple[str, str, str, str, str, str]:
    try:
        resp = session.get(url, timeout=15)
        if resp.status_code != 200: return '', '', '', '', '', ''
        
        resp.encoding = 'utf-8'
        soup = BeautifulSoup(resp.text, 'html.parser')

        # 1. URL
        canonical = soup.find('link', attrs={'rel': 'canonical'})
        article_url = canonical.get('href') if canonical else url

        # 2. TITLE
        meta_title = soup.find('meta', property='og:title')
        title = clean_text(meta_title.get('content')) if meta_title else ''
        if not title:
            t_tag = soup.find('title')
            title = clean_text(t_tag.get_text()) if t_tag else ''

        # 3. PUBLISH TIME
        time_tag = soup.find(attrs={"data-role": "publishdate"})
        publish_time = clean_text(time_tag.get_text()) if time_tag else ''
        if not publish_time:
             meta_time = soup.find('meta', property='article:published_time')
             if meta_time: publish_time = clean_text(meta_time['content'])

        # 4. KEYWORDS
        meta_kw = soup.find('meta', attrs={'name': 'news_keywords'})
        if not meta_kw: meta_kw = soup.find('meta', attrs={'name': 'keywords'})
        keywords = clean_text(meta_kw.get('content')) if meta_kw else ''

        # 5. SUMMARY
        meta_desc = soup.find('meta', property='og:description')
        summary = clean_text(meta_desc.get('content')) if meta_desc else ''
        summary = remove_prefix(summary)

        # 6. CONTENT
        content = ''
        body = soup.select_one('div.detail-content, div.afcbc-body')
        
        if body:
            for garbage in body.select('table, figure, script, style, .box-responsive, .relate-news, .box-ads'):
                garbage.decompose()

            paras = body.select('p')
            
            # Xóa chữ ký tác giả ở cuối nếu ngắn
            if paras:
                last_txt = clean_text(paras[-1].get_text())
                if len(last_txt) < 50 and len(last_txt) > 0:
                     paras.pop()

            cleaned_paras = []
            for i, p in enumerate(paras):
                txt = clean_text(p.get_text())
                if not txt: continue
                # Bỏ tiền tố (Chinhphu.vn) ở đoạn đầu
                if i == 0: txt = remove_prefix(txt)
                cleaned_paras.append(txt)
            
            content = ' '.join(cleaned_paras)

        return title, summary, content, keywords, publish_time, article_url

    except Exception as e:
        print(f"Lỗi đọc bài ({url}): {e}")
        return '', '', '', '', '', ''

def get_links(url):
    try:
        resp = session.get(url, timeout=15)
        soup = BeautifulSoup(resp.text, 'html.parser')
        links = set()
        
        # Tìm trong các container chứa tin bài
        # Thêm các class thường gặp: article-list, timeline, zone-content
        main = soup.select_one('div.main, div#admwrapper, body') 
        
        if not main: return []
        
        for a in main.select('a[href]'):
            full = normalize_href(a.get('href'), url)
            
            # ĐIỀU KIỆN LỌC LINK:
            if full and DOMAIN in full:
                # 1. Phải khớp regex (có số ID ở cuối)
                if ARTICLE_URL_RE.search(full):
                    # 2. Không phải chính link đang quét
                    if full != url:
                        # 3. Không chứa 'trang-X.htm' (để tránh nhầm link phân trang là bài viết)
                        if '/trang-' not in full:
                            links.add(full)
                            
        return list(links)
    except: return []

# --- HÀM MAIN ---
def main(topics_dict):
    # [CẤU HÌNH] Tăng số trang muốn quét để lấy nhiều tin hơn
    MAX_PAGES_PER_LINK = 40  
    OUTPUT_FILE = 'thanglong_full_data.csv'

    seen_global = set() # Tránh trùng lặp giữa các trang

    with open(OUTPUT_FILE, 'w', newline='', encoding='utf-8-sig') as f:
        writer = csv.DictWriter(f, fieldnames=['topic', 'title', 'summary', 'content', 'keywords', 'publish_time', 'url'])
        writer.writeheader()
        
        for topic_name, url_data in topics_dict.items():
            print(f"\n========== CHỦ ĐỀ: {topic_name} ==========")
            
            list_urls = [url_data] if isinstance(url_data, str) else url_data

            for sub_url in list_urls:
                print(f"   >>> Đang quét nhánh: {sub_url}")
                
                # Vòng lặp quét các trang 1, 2, 3... (tương ứng ấn 'Xem thêm')
                for p in range(1, MAX_PAGES_PER_LINK + 1):
                    p_url = make_page_url(sub_url, p)
                    print(f"      -> Trang {p}: {p_url}")
                    
                    try:
                        links = get_links(p_url)
                    except:
                        links = []
                    
                    if not links:
                        print("         (Hết bài hoặc không tìm thấy)")
                        break # Dừng vòng lặp trang nếu trang hiện tại ko có bài

                    count_ok = 0
                    for link in links:
                        if link in seen_global: continue
                        seen_global.add(link)
                        
                        # Crawl bài viết
                        title, summary, content, kw, p_time, final_url = parse_article(link)
                        
                        if title and content:
                            writer.writerow({
                                'topic': topic_name,
                                'title': title,
                                'summary': summary,
                                'content': content,
                                'keywords': kw,
                                'publish_time': p_time,
                                'url': final_url
                            })
                            count_ok += 1
                            # In tiến độ 
                            print(f"         ✅ {title[:40]}...")
                        
                        time.sleep(0.1) 
                    
                    print(f"      -> Đã lưu {count_ok} bài mới.")
                    time.sleep(1.0) # Nghỉ giữa các trang phân trang

if __name__ == "__main__":
    # Danh sách chủ đề (đã bao gồm cả dạng chuỗi đơn và dạng danh sách)
    topics = {
        'Thời sự': 'https://thanglong.chinhphu.vn/thoi-su.htm',
        'Kinh tế': [
            'https://thanglong.chinhphu.vn/kinh-te.htm',
            'https://thanglong.chinhphu.vn/kinh-te/ngan-hang.htm',
            'https://thanglong.chinhphu.vn/kinh-te/chung-khoan.htm',
            'https://thanglong.chinhphu.vn/kinh-te/thi-truong.htm',
            'https://thanglong.chinhphu.vn/kinh-te/doanh-nghiep.htm',
            'https://thanglong.chinhphu.vn/kinh-te/khoi-nghiep.htm'
        ],
        'Xã hội': [
            'https://thanglong.chinhphu.vn/xa-hoi/khoa-hoc.htm',
            'https://thanglong.chinhphu.vn/xa-hoi/giao-duc.htm',
            'https://thanglong.chinhphu.vn/xa-hoi/phap-luat.htm',
            'https://thanglong.chinhphu.vn/xa-hoi/y-te.htm',
            'https://thanglong.chinhphu.vn/xa-hoi/doi-song.htm'
        ],
        'Văn hóa': 'https://thanglong.chinhphu.vn/van-hoa-giai-tri/ha-noi-van-hien.htm',
        'Chính phủ': 'https://thanglong.chinhphu.vn/chinh-phu-voi-ha-noi.htm',
        'Du lịch': [
            'https://thanglong.chinhphu.vn/du-lich/am-thuc.htm',
            'https://thanglong.chinhphu.vn/du-lich/diem-den.htm'
        ],
        'Nhà đầu tư': [
            'https://thanglong.chinhphu.vn/nha-dau-tu/chinh-sach-uu-dai.htm',
            'https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh.htm'
        ]
    }

    main(topics)
# Out:
# ========== CHỦ ĐỀ: Thời sự ==========
#    >>> Đang quét nhánh: https://thanglong.chinhphu.vn/thoi-su.htm
#       -> Trang 1: https://thanglong.chinhphu.vn/thoi-su.htm
#          ✅ Hà Nội tổ chức lễ hội Xuân Bính Ngọ 2026...
#          ✅ Du lịch, Hà Nội, 2026, khách quốc tế...
#          ✅ Đại tá Nguyễn Tiến Đạt giữ chức Thủ trưở...
#          ✅ Liên minh HTX TP Hà Nội: Đòn bẩy mở thị ...
#          ✅ Hà Nội: Kiện toàn 2 Trưởng ban HĐND, Giá...
#          ✅ Người dân Thủ đô được khám bác sĩ bệnh v...
#          ✅ Nâng vị thế trung tâm công nghiệp, đổi m...
#          ✅ Hà Nội chi quà Tết cho người hưởng lương...
#          ✅ Hà Nội yêu cầu đưa ngay các dữ liệu đất ...
#          ✅ Phát huy vai trò y tế cơ sở – 'lá chắn đ...
#          ✅ CPI bình quân của Hà Nội năm 2025 tăng 3...
#          ✅ Xóa bỏ ‘chợ cóc’: Cần có lộ trình và bảo...
#          ✅ Hà Nội thu hút 76,9 triệu USD vốn FDI tr...
#          ✅ Mặt trận - ‘cầu nối’ vững chắc giữa Đảng...
#          ✅ Bảo đảm TTATGT phục vụ sơ duyệt, diễn tậ...
#          ✅ ‘Bánh Chưng xanh - Tết vì người nghèo’ n...
#          ✅ Phát huy vai trò đại biểu dân cử, đưa cơ...
#          ✅ Hà Nội: Thu ngân sách trên 704 nghìn tỷ ...
#          ✅ Hà Nội triển khai đồng bộ giải pháp ứng ...
#          ✅ Sắp diễn ra chương trình “ĐẠO HỌC” kỷ ni...
#          ✅ Hà Nội triển khai 3 dự án theo lệnh khẩn...
#          ✅ Hà Nội quy định phạm vi, khung giờ hạn c...
#          ✅ HĐND TP. Hà Nội kiện toàn công tác nhân ...
#          ✅ Hà Nội tham gia Hội chợ Mùa xuân 2026 và...
#          ✅ Hà Nội tập trung các giải pháp bảo đảm a...
#          ✅ Phấn đấu để xứng đáng là cơ quan tham mư...
#          ✅ Hà Nội tăng tốc từ năm đầu nhiệm kỳ mới,...
#       -> Đã lưu 27 bài mới.
#       -> Trang 2: https://thanglong.chinhphu.vn/thoi-su/trang-2.htm
#          ✅ Bảo đảm an toàn thực phẩm phục vụ Tết và...
#          ✅ Khai mạc Đại hội Công đoàn thành phố Hà ...
#          ✅ Hà Nội tập trung hoàn thiện thể chế, quy...
#          ✅ Dấu ấn nổi bật từ những công trình trọng...
#          ✅ Khởi tố giám đốc công ty tổ chức show ‘V...
#          ✅ Hà Nội siết kỷ cương, giữ an ninh trật t...
#          ✅ Hà Nội tập trung xây dựng khu vực phòng ...
#          ✅ Hà Nội yêu cầu không tổ chức thăm, chúc ...
#          ✅ Hà Nội: Gần 80 tỷ đồng chăm lo Tết cho h...
#          ✅ Hạ tầng cần đi trước một bước, phát triể...
#          ✅ Khẳng định vị thế làng nghề, hướng tới t...
#          ✅ Hà Nội: Thu hồi gần 5.900 tỷ đồng từ các...
#          ✅ Hà Nội điều chỉnh giao thông cửa ngõ phí...
#          ✅ Hà Nội hướng dẫn phân luồng giao thông, ...
#          ✅ Hà Nội 'đánh thức' tiềm năng du lịch xã ...
#          ✅ Hà Nội: Kiểm tra doanh nghiệp vận tải có...
#          ✅ Bảo đảm cung-cầu, ổn định thị trường hàn...
#          ✅ Văn hóa, di sản là trụ cột để Hà Nội chi...
#          ✅ Hà Nội sẽ trồng hơn 400.000 cây xanh tro...
#          ✅ Đổi mới thể chế - động lực then chốt cho...
#          ✅ Hà Nội với các đột phá chiến lược, cùng ...
#          ✅ Cầu Long Biên mở lại cho xe máy, người đ...
#          ✅ Phường Thanh Xuân phấn đấu hoàn thành vư...
#          ✅ 10 dấu ấn nổi bật của Thủ đô Hà Nội năm ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 3: https://thanglong.chinhphu.vn/thoi-su/trang-3.htm
#          ✅ Bí thư Thành ủy Hà Nội yêu cầu bảo đảm t...
#          ✅ Đổi mới công tác cán bộ, xây dựng đội ng...
#          ✅ Hà Nội quyết tâm hoàn thành thắng lợi mụ...
#          ✅ Năm 2025, du lịch Hà Nội đạt doanh thu h...
#          ✅ Phó Giám đốc Công an Hà Nội Nguyễn Thành...
#          ✅ Hà Nội tăng tốc từ đầu năm, quyết tâm đạ...
#          ✅ Phân luồng giao thông phục vụ Đại hội Th...
#          ✅ Nhu cầu về sản phẩm thiết kế sáng tạo ng...
#          ✅ Hà Nội mong muốn thúc đẩy hợp tác với Hà...
#          ✅ Hà Nội: Quyết liệt chống hàng giả, bảo đ...
#          ✅ Hà Nội gỡ vướng cho doanh nghiệp tại khu...
#          ✅ Vùng phát thải thấp: Chủ trương, hạ tầng...
#          ✅ Cơ hội cho sản phẩm thiết kế sáng tạo kh...
#          ✅ Hà Nội sẵn sàng tiên phong để thực hiện ...
#          ✅ Giải tỏa dứt điểm ‘chợ cóc’, điểm kinh d...
#          ✅ Xúc tiến thương mại hàng tiêu dùng, sản ...
#          ✅ Y tế Thủ đô: Dấu ấn chuyển đổi số và nân...
#          ✅ Để khởi nghiệp sáng tạo của Hà Nội cất c...
#          ✅ Hà Nội: Khai mạc ‘Lễ hội mua sắm năm 202...
#          ✅ Kiến tạo hệ sinh thái số thống nhất cho ...
#          ✅ CATP Hà Nội phát động đợt thi đua 100 ng...
#          ✅ Lãnh đạo Mặt trận TP. Hà Nội thăm hỏi, đ...
#          ✅ Hà Nội: Bảo đảm tốt nhất nhu cầu đi lại ...
#          ✅ Nâng cao hiệu quả hoạt động của hệ thống...
#       -> Đã lưu 24 bài mới.
#       -> Trang 4: https://thanglong.chinhphu.vn/thoi-su/trang-4.htm
#          ✅ Sáng tạo mở đường băng cho di sản ẩm thự...
#          ✅ Hà Nội thực hiện các giải pháp đột phá đ...
#          ✅ Không gian di sản sống động trong chuỗi ...
#          ✅ Những hiệu quả từ việc tổ chức lại giao ...
#          ✅ Hà Nội thành lập Hội đồng điều phối phát...
#          ✅ Tháo nút thắt, tạo lực đẩy mới cho khu c...
#          ✅ 'Điểm chạm' sáng tạo: Khi sản phẩm OCOP ...
#          ✅ Từ làng nghề đến không gian sáng tạo: Cá...
#          ✅ Nhiều giải pháp để Hà Nội cải tiến toàn ...
#          ✅ Hà Nội tăng tốc cải thiện môi trường đầu...
#          ✅ Mở hướng phát triển du lịch xã Đa Phúc t...
#          ✅ Hà Nội tích cực xây dựng Đảng về đạo đức...
#          ✅ Khoa học công nghệ và đổi mới sáng tạo: ...
#          ✅ Gia tăng giá trị du lịch từ khai thác ch...
#          ✅ Doanh nhân tiên phong và sứ mệnh dẫn dắt...
#          ✅ Trung tâm thiết kế sáng tạo: Động lực mớ...
#          ✅ Kịp thời khống chế, dập tắt vụ cháy tại ...
#          ✅ Hà Nội phát động Tết trồng cây Xuân Bính...
#          ✅ Chuyển đổi số và chuyển đổi xanh: Hai tr...
#          ✅ Hà Nội phát động thi đua bảo đảm an ninh...
#          ✅ Khẳng định vai trò trung tâm trong xây d...
#          ✅ Hà Nội trao quyết định bổ nhiệm, điều độ...
#          ✅ Nâng cao hiệu quả quản lý đô thị khi thự...
#          ✅ Thúc đẩy sản xuất, tiêu dùng bền vững...
#       -> Đã lưu 24 bài mới.
#       -> Trang 5: https://thanglong.chinhphu.vn/thoi-su/trang-5.htm
#          ✅ Tháo gỡ vướng mắc cho các hộ kinh doanh ...
#          ✅ 10 dấu ấn tiêu biểu năm 2025 của Công an...
#          ✅ Khởi công Dự án tuyến đường kết nối sân ...
#          ✅ Khởi công tuyến đường sắt đô thị số 5, V...
#          ✅ Siết nguồn phát thải, Hà Nội tìm lời giả...
#          ✅ Đẩy mạnh các hoạt động phòng chống bệnh ...
#          ✅ Ngày 19/12, Hà Nội khởi công Khu đô thị ...
#          ✅ Di sản văn hóa - nguồn lực mềm cho phát ...
#          ✅ Khởi công Dự án Đầu tư xây dựng Trục đại...
#          ✅ Du lịch đêm Hà Nội tạo sức hút mới từ 'H...
#          ✅ Chuyên gia nói về Du lịch Hà Nội trước c...
#          ✅ Quyết liệt xử lý 5 điểm nghẽn, tạo động ...
#          ✅ Nâng cao chất lượng công tác nắm bắt, đị...
#          ✅ Kết nối sản phẩm OCOP và làng nghề gắn v...
#          ✅ Khởi công Dự án Cải tạo, chỉnh trang, tá...
#          ✅ Công an Thành phố Hà Nội: Quyết tâm hoàn...
#          ✅ Khai mạc Festival OCOP Hà Nội 2025 'Việt...
#          ✅ Tăng cường tiêm vét cho trẻ em trong chư...
#          ✅ Hà Nội trên hành trình trở thành 'đô thị...
#          ✅ Hà Nội khởi công 7 dự án lớn chào mừng Đ...
#          ✅ Tăng cường kiểm tra, xử lý thực phẩm khô...
#          ✅ Cột cờ Hà Nội trở thành không gian trải ...
#          ✅ Hà Nội đẩy mạnh quảng bá các sản phẩm th...
#          ✅ Khởi công dự án khu nhà ở xã hội Tiên Dư...
#       -> Đã lưu 24 bài mới.
#       -> Trang 6: https://thanglong.chinhphu.vn/thoi-su/trang-6.htm
#          ✅ Đánh giá, phân hạng sản phẩm OCOP năm 20...
#          ✅ Chuyển biến rõ nét trong kiểm soát và đơ...
#          ✅ Festival OCOP Việt Nam 2025: Việt Nam- H...
#          ✅ Hà Nội gỡ điểm nghẽn về trật tự đô thị: ...
#          ✅ Lễ hội Văn hóa Ẩm thực Hà Nội 2025 sẽ di...
#          ✅ Thường trực Thành ủy Hà Nội gặp mặt đại ...
#          ✅ Hà Nội công bố đường dây nóng vận tải dị...
#          ✅ Hà Nội siết chặt an toàn thực phẩm mùa l...
#          ✅ Hà Nội tiếp tục số hóa, xây dựng cơ sở d...
#          ✅ Đẩy mạnh công tác hỗ trợ, tư vấn cho ngư...
#          ✅ Hà Nội triển khai sớm các hoạt động Tết ...
#          ✅ Hệ thống 1.837 camera AI của Hà Nội hoạt...
#          ✅ Chuyển đổi số - bước chuyển trong đổi mớ...
#          ✅ Nông nghiệp an toàn: Hướng đi chiến lược...
#          ✅ Hà Nội chú trọng kiểm soát thực phẩm an ...
#          ✅ Thu gọn rào chắn dự án đường sắt đô thị ...
#          ✅ Bước tiến mới trong giải quyết TTHC khôn...
#          ✅ Hà Nội: Sôi động thị trường tuyển dụng v...
#          ✅ Hiện thực hóa giải pháp hút khách quốc t...
#          ✅ Khởi tố 3 bị can về sai phạm khi chi trả...
#          ✅ Hà Nội yêu cầu rà soát, cập nhật đầy đủ ...
#          ✅ Tháo gỡ cơ chế, vốn và hạ tầng để Hà Nội...
#          ✅ Thanh niên Thủ đô cần là lực lượng đi đầ...
#          ✅ Phát triển làng nghề Hà Nội: Khi du lịch...
#       -> Đã lưu 24 bài mới.
#       -> Trang 7: https://thanglong.chinhphu.vn/thoi-su/trang-7.htm
#          ✅ Hà Nội thông qua Quy hoạch phân khu đô t...
#          ✅ Hà Nội thông qua nghị quyết gỡ vướng tro...
#          ✅ Hai dự án trọng điểm của Hà Nội: Hướng t...
#          ✅ Thêm các trường hợp được mua, thuê nhà ở...
#          ✅ Hơn 560.000 giao dịch đảng phí trực tuyế...
#          ✅ Hà Nội tiên phong trong chuyển đổi số, t...
#          ✅ Quy hoạch tổng thể Thủ đô: Bước đi cần t...
#          ✅ Bước đi tất yếu trong xây dựng chính quy...
#          ✅ Thông qua các quy hoạch mang tầm nhìn tr...
#          ✅ Hà Nội đánh giá chỉ số cải cách hành chí...
#          ✅ Kết nối sản xuất tiêu thụ nông sản thực ...
#          ✅ Hà Nội được giữ lại 30% khoản thu cấp qu...
#          ✅ Học sinh Hà Nội được nghỉ Tết Dương lịch...
#          ✅ Hà Nội tiên phong kiến tạo thể chế đầu t...
#          ✅ Khởi nghiệp sáng tạo toàn dân - động lực...
#          ✅ Trục Đại lộ cảnh quan sông Hồng: Dự án đ...
#          ✅ Khai mạc kỳ họp thứ 29 HĐND thành phố Hà...
#          ✅ Công an Hà Nội mở đợt cao điểm tấn công,...
#          ✅ Trục Đại lộ cảnh quan sông Hồng mở ra kỳ...
#          ✅ Lập ‘lá chắn an toàn thực phẩm’ vững chắ...
#          ✅ Chế biến, bảo quản tại nguồn – Mắt xích ...
#          ✅ Khu đô thị thể thao Olympic: Tổ chức sự ...
#          ✅ Công an TP. Hà Nội kích hoạt 'bộ não gia...
#          ✅ Linh hoạt thời gian thẩm định thúc đẩy t...
#       -> Đã lưu 24 bài mới.
#       -> Trang 8: https://thanglong.chinhphu.vn/thoi-su/trang-8.htm
#          ✅ Kiểm soát chặt an toàn thực phẩm tại các...
#          ✅ Hà Nội lập lại trật tự hoạt động tư vấn ...
#          ✅ Tạo bước chuyển thực chất trong phục vụ ...
#          ✅ Từ tinh gọn tổ chức đến phân cấp mạnh mẽ...
#          ✅ Khai mạc Hội chợ ‘Made in Vietnam’ năm 2...
#          ✅ Hà Nội gặp mặt đội tuyển học sinh giỏi: ...
#          ✅ Hà Nội ban hành kế hoạch khắc phục điểm ...
#          ✅ Đẩy mạnh hoàn thiện thể chế, tạo bước độ...
#          ✅ Hà Nội mở đợt cao điểm an ninh bảo vệ Tế...
#          ✅ Hà Nội được 'chốt' cơ chế, chính sách đặ...
#          ✅ Hà Nội xây dựng lá chắn an ninh mạng cho...
#          ✅ Hà Nội chỉ đạo các giải pháp cấp bách ch...
#          ✅ Bộ Công an gửi Thư khen Công an thành ph...
#          ✅ Hà Nội siết chặt trận tuyến an toàn thực...
#          ✅ Kiểm soát an toàn thực phẩm đối với các ...
#          ✅ Hà Nội: OCOP khơi dậy dòng chảy sáng tạo...
#          ✅ Thúc đẩy doanh nghiệp tham gia trực tiếp...
#          ✅ Hà Nội nâng cấp tổng thể hệ thống đê điề...
#          ✅ Hà Nội giải quyết việc làm cho hơn 207.0...
#          ✅ Khai mạc Liên hoan Ẩm thực và Du lịch là...
#          ✅ Bí thư Thành ủy Hà Nội: Nhân rộng kinh n...
#          ✅ Cơ chế đặc thù thực hiện các dự án lớn: ...
#          ✅ Những sản phẩm OCOP 5 sao - tinh hoa của...
#          ✅ Tổ chức lại Trung tâm Phục vụ hành chính...
#       -> Đã lưu 24 bài mới.
#       -> Trang 9: https://thanglong.chinhphu.vn/thoi-su/trang-9.htm
#          ✅ Chuyển đổi phương tiện xanh ở Hà Nội: Kh...
#          ✅ Hưởng ứng Tháng hành động quốc gia về Dâ...
#          ✅ Chuyển đổi quản lý thuế hộ kinh doanh th...
#          ✅ Lưu ý các nguyên tắc bảo đảm an toàn thự...
#          ✅ Phó Bí thư Thành ủy Hà Nội Nguyễn Trọng ...
#          ✅ Hà Nội tăng cường giám sát, hoàn thiện m...
#          ✅ Hà Nội ban hành các cơ chế khuyến khích ...
#          ✅ Hà Nội điều chỉnh, phân luồng giao thông...
#          ✅ Huy động cả hệ thống chính trị vào cuộc ...
#          ✅ Hà Nội: Tạo sức bật mới cho du lịch Thủ ...
#          ✅ Không khoan nhượng với hàng giả, vi phạm...
#          ✅ Tòa án Hà Nội đặt mục tiêu giải quyết 10...
#          ✅ Đưa hàng Việt đến gần hơn với người dân ...
#          ✅ Phó Giám đốc Sở Xây dựng Hà Nội Đào Việt...
#          ✅ Đẩy mạnh giải ngân vốn đầu tư công, giải...
#          ✅ Phê chuẩn kết quả bầu, miễn nhiệm chức v...
#          ✅ Hà Nội vinh danh 87 cơ sở, công trình sử...
#          ✅ Hà Nội đẩy mạnh quảng bá hàng hóa, nông ...
#          ✅ Vận động sản xuất, kinh doanh nông sản a...
#          ✅ Di sản và liên kết tạo động lực mới cho ...
#          ✅ Hà Nội siết chặt kỷ cương, chuyển biến t...
#          ✅ Siết chặt truy xuất nguồn gốc, bảo đảm a...
#          ✅ Đảm bảo công tác khám tuyển nghĩa vụ Quâ...
#          ✅ Hà Nội ứng dụng khoa học - công nghệ để ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 10: https://thanglong.chinhphu.vn/thoi-su/trang-10.htm
#          ✅ Đề xuất Hà Nội được bồi thường tái định ...
#          ✅ Từ hành trình khởi nghiệp đến yêu cầu cấ...
#          ✅ Hà Nội: CPI tháng 11/2025 tăng 0,28%, gi...
#          ✅ Hà Nội yêu cầu 5 xã phía Bắc Thủ đô khai...
#          ✅ Hà Nội định hình mô hình đô thị thông mi...
#          ✅ Bệnh viện đa khoa Ba Vì tiếp nhận thiết ...
#          ✅ Giáo dục Hà Nội ghi nhận nhiều kết quả n...
#          ✅ Hà Nội thành lập Tổ giúp việc Ban Chỉ đạ...
#          ✅ Hà Nội quyết tâm chuẩn hóa cơ bản 'Công ...
#          ✅ Khám sức khoẻ nghĩa vụ quân sự và tham g...
#          ✅ Xã Phúc Thịnh, Vĩnh Thanh cần ưu tiên gi...
#          ✅ Ngọc Hà cần gương mẫu, đi đầu trong triể...
#          ✅ Hà Nội nỗ lực toàn diện hướng tới nền hà...
#          ✅ Hiện thực hóa giải pháp tăng cường thu h...
#          ✅ Quản lý thực phẩm, bảo vệ quyền lợi ngườ...
#          ✅ Hà Nội: Phường Phú Thượng bứt tốc kinh t...
#          ✅ Tăng cường giám sát an toàn thực phẩm gi...
#          ✅ Hà Nội thu hút 327.000 lượt khách di tíc...
#          ✅ Một xã của Hà Nội tăng tốc đầu tư hạ tần...
#          ✅ Siết chặt an toàn thực phẩm bếp ăn trườn...
#          ✅ Đầu tư 299 tỷ đồng xây dựng Trường THPT ...
#          ✅ Hà Nội: Hấp dẫn Liên hoan Ẩm thực và Du ...
#          ✅ Những thực phẩm không nên 'trú ngụ' lâu ...
#          ✅ Hà Nội tăng tốc khắc phục hạn chế trong ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 11: https://thanglong.chinhphu.vn/thoi-su/trang-11.htm
#          ✅ Hà Nội phân cấp vệ sinh môi trường, tăng...
#          ✅ Hà Nội - Seoul trao đổi kinh nghiệm phát...
#          ✅ Hà Nội: Di dời trụ sở, cơ sở sản xuất kh...
#          ✅ Bí thư Thành ủy Nguyễn Duy Ngọc giữ chức...
#          ✅ Chuyển đổi số trong vận hành và bảo trì ...
#          ✅ Đột phá chuỗi cung ứng vì sự phát triển ...
#          ✅ Hà Nội kiến tạo tương lai đô thị sáng tạ...
#          ✅ Hà Nội quyết tâm cao, vượt tiến độ 'xanh...
#          ✅ Hà Nội và Seoul tăng cường hợp tác, hướn...
#          ✅ Hà Nội kiến tạo mô hình vận hành thông m...
#          ✅ Hà Nội triển khai đồng bộ nhiều nhiệm vụ...
#          ✅ Phường Hai Bà Trưng cần giữ vững chất lư...
#          ✅ Xã Thư Lâm đẩy nhanh tiến độ giải phóng ...
#          ✅ Tạo điều kiện thuận lợi để hộ kinh doanh...
#          ✅ Hà Nội tìm lời giải cho bài toán biến di...
#          ✅ Chủ động nhận diện rủi ro và bảo vệ an t...
#          ✅ Chủ tịch UBND TP. Hà Nội Vũ Đại Thắng: P...
#          ✅ Phường Định Công cần tháo gỡ vướng mắc, ...
#          ✅ Hà Nội nỗ lực 'hút' khách quốc tế tới vù...
#          ✅ Hà Nội: Tích Giang khẳng định vị thế 'th...
#          ✅ Hà Nội triển khai vùng phát thải thấp: B...
#          ✅ Kinh nghiệm quốc tế cho hành trình số hó...
#          ✅ URENCO Hà Nội thúc đẩy thành lập liên do...
#          ✅ Hà Nội xây dựng quy trình xử phạt vi phạ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 12: https://thanglong.chinhphu.vn/thoi-su/trang-12.htm
#          ✅ Hà Nội bứt phá công nghiệp, nhóm ngành c...
#          ✅ Nâng cao năng lực bảo đảm an toàn thực p...
#          ✅ Đẩy mạnh kiểm tra, xử lý vi phạm về chất...
#          ✅ Tăng cường tuyên truyền nâng cao y đức t...
#          ✅ Hà Nội đẩy mạnh xây dựng nền nông nghiệp...
#          ✅ Hà Nội: Thương mại, dịch vụ bứt phá nhờ ...
#          ✅ Bảo đảm an toàn thực phẩm tại các hội ch...
#          ✅ Thúc đẩy môi trường thực phẩm an toàn- N...
#          ✅ Hà Nội yêu cầu trường học hạn chế hoạt đ...
#          ✅ Hướng dẫn, chia sẻ thực hiện thủ tục hàn...
#          ✅ Tuyên truyền khuyến cáo bảo vệ sức khỏe ...
#          ✅ Hà Nội thúc tiến độ xây dựng 7 cầu qua s...
#          ✅ Hà Nội tiên phong xanh hóa giao thông cô...
#          ✅ Hà Nội yêu cầu đẩy nhanh tiến độ khắc ph...
#          ✅ Chuyển đổi số tạo bước chuyển mình mạnh ...
#          ✅ Chính thức áp dụng hệ thống kiểm soát vé...
#          ✅ Yêu cầu kiểm soát chặt chẽ chi khám chữa...
#          ✅ Hà Nội: 'Ngôi sao sáng' trên bản đồ thu ...
#          ✅ Nâng cao hiểu biết sức khỏe sinh sản cho...
#          ✅ Hà Nội triển khai mạnh mẽ yêu cầu cắt gi...
#          ✅ Tiêm vaccine cúm để phòng bệnh hiệu quả ...
#          ✅ 'Chạy trước' hạ tầng trạm sạc để 'xanh h...
#          ✅ Hà Nội tăng tốc đầu tư công, loạt dự án ...
#          ✅ Hà Nội quyết tâm lập lại trật tự đô thị...
#       -> Đã lưu 24 bài mới.
#       -> Trang 13: https://thanglong.chinhphu.vn/thoi-su/trang-13.htm
#          ✅ Kiên quyết kiểm tra, xử lý vi phạm về hà...
#          ✅ Hà Nội tăng dự trữ hàng thiết yếu, giữ ổ...
#          ✅ Hồng Vân - Điểm sáng du lịch cộng đồng đ...
#          ✅ Hà Nội thúc đẩy giải pháp khai thác hiệu...
#          ✅ Truy xuất nguồn gốc nông sản: Cần cơ chế...
#          ✅ Xây dựng thương hiệu hợp chuẩn quốc tế v...
#          ✅ Hà Nội tăng cường 'lá chắn pháp lý' cho ...
#          ✅ Hà Nội và Viêng Chăn tiếp tục hợp tác ch...
#          ✅ Tăng cường năng lực kiểm định – nâng cao...
#          ✅ Tăng tốc chuyển đổi số trong nông nghiệp...
#          ✅ Hoàn thiện quy hoạch tổng thể Thủ đô với...
#          ✅ Độc đáo các hành trình du lịch di sản Hà...
#          ✅ Nhận biết và sơ cứu ngộ độc thực phẩm: N...
#          ✅ Hà Nội đẩy mạnh thực hiện Nghị quyết 68 ...
#          ✅ Hà Nội đẩy mạnh đầu tư các dự án điện mặ...
#          ✅ Hà Nội triển khai nhiệm vụ kinh tế, ngân...
#          ✅ Phụ nữ Thủ đô phát động hưởng ứng Tháng ...
#          ✅ Hà Nội: Khai mạc Hội chợ trái cây, nông ...
#          ✅ Tăng cường kiểm soát, nâng cao hiệu lực ...
#          ✅ Bàn giao công tác quản lý, bảo vệ và PCC...
#          ✅ Mở lối chuyển dịch năng lượng xanh trong...
#          ✅ Minh bạch nguồn gốc – nền tảng bảo đảm a...
#          ✅ Hà Nội ban hành phương pháp đo lường sự ...
#          ✅ Tăng cường phòng ngừa ngộ độc thực phẩm ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 14: https://thanglong.chinhphu.vn/thoi-su/trang-14.htm
#          ✅ Đình Thiết Úng - ngôi đình lưu giữ 7 đạo...
#          ✅ Hà Nội siết kỷ luật, yêu cầu chấm dứt tì...
#          ✅ Giảm 135 ca mắc sốt xuất huyết so với tu...
#          ✅ Động lực đa chiều thúc đẩy hợp tác chiến...
#          ✅ Đan Phượng tập huấn an toàn thực phẩm tạ...
#          ✅ Vì sao ngành du lịch Thủ đô đón lượng kh...
#          ✅ Hà Nội - Mátxcơva mở rộng hợp tác kinh t...
#          ✅ Triển khai chiến dịch bổ sung Vitamin A ...
#          ✅ Công tác kiểm tra an toàn thực phẩm sẽ t...
#          ✅ Hà Nội nghiên cứu mở rộng phạm vi cấm ôt...
#          ✅ Hà Nội phân công nhiệm vụ chống thất thu...
#          ✅ Việc phân cấp, phân quyền phải gắn liền ...
#          ✅ Đánh dấu bước phát triển mới của mô hình...
#          ✅ Hà Nội: Hoàn tất khoan hầm 4 ga ngầm đầu...
#          ✅ Ưu tiên giải quyết vấn đề ùn tắc giao th...
#          ✅ Sẵn sàng nguồn cung hàng hóa thiết yếu p...
#          ✅ Triển khai Hệ thống Quản lý Quốc gia về ...
#          ✅ Cửa Nam vận hành mạng WiFi công cộng phụ...
#          ✅ Hỗ trợ doanh nghiệp tận dụng các FTA, mở...
#          ✅ Siết chặt an toàn thực phẩm trước nhu cầ...
#          ✅ Siết chặt quản lý, kiểm soát thực phẩm ‘...
#          ✅ Hà Nội: Hộ kinh doanh ở vị trí trung tâm...
#          ✅ Đưa sản phẩm Việt có chất lượng đến tay ...
#          ✅ Giấc thiêng đền Sái: Nơi hội tụ huyền th...
#       -> Đã lưu 24 bài mới.
#       -> Trang 15: https://thanglong.chinhphu.vn/thoi-su/trang-15.htm
#          ✅ Cuối tuần này, Hà Nội ra mắt Dự án 'Âm n...
#          ✅ Hà Nội: Kịp thời khống chế đám cháy tại ...
#          ✅ Bảo đảm các nghị quyết được tổ chức thực...
#          ✅ Đẩy mạnh kết nối xuất khẩu nông sản sang...
#          ✅ Quảng bá nông, lâm, thủy sản an toàn tới...
#          ✅ Hà Nội: Tôn vinh 150 sản phẩm hàng Việt ...
#          ✅ Hấp dẫn du lịch đêm Hà Nội...
#          ✅ Đưa nghệ thuật rối trở thành sản phẩm vă...
#          ✅ Chủ tịch UBND TP. Hà Nội Vũ Đại Thắng: L...
#          ✅ Về Thiết Úng khám phá cái nôi nghề chạm ...
#          ✅ Hà Nội nâng cao an toàn và kiểm soát hoạ...
#          ✅ Tập huấn nâng an toàn thực phẩm bữa ăn b...
#          ✅ Vitamin A – Vi chất dinh dưỡng giúp trẻ ...
#          ✅ Nâng cao kỹ năng canh tác qua Diễn đàn '...
#          ✅ Đồng chí Vũ Đại Thắng được bầu giữ chức ...
#          ✅ Đẩy mạnh sản xuất rau an toàn ứng dụng c...
#          ✅ Hà Nội: Xã Thư Lâm tăng tốc phát triển s...
#          ✅ Tích cực triển khai chuyển đổi sang mô h...
#          ✅ Bàn giao 41 nhà Đại đoàn kết cho gia đìn...
#          ✅ Khai mạc sự kiện 'Hà Nội đêm không ngủ-H...
#          ✅ Hà Nội mở rộng dịch vụ công trực tuyến c...
#          ✅ Sắp ra mắt 4 hành trình du lịch di sản đ...
#          ✅ Đồng chí Vũ Minh Tuấn giữ chức Phó Trưởn...
#          ✅ Múa rối nước Đào Thục: Sản phẩm du lịch ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 16: https://thanglong.chinhphu.vn/thoi-su/trang-16.htm
#          ✅ Yêu cầu nhà hàng ký cam kết không tiêu t...
#          ✅ Hà Nội tăng mức chuẩn trợ cấp xã hội lên...
#          ✅ Hà Nội: Mức học phí trường công lập chất...
#          ✅ Hà Nội chuẩn hóa bữa ăn bán trú, bảo đảm...
#          ✅ Hà Nội tiếp nhận hơn 55 tỷ đồng ủng hộ đ...
#          ✅ Hà Nội thu hút 157 dự án tham gia cuộc t...
#          ✅ Khai mạc Hội chợ hàng công nghiệp nông t...
#          ✅ Bảo đảm phát triển hài hòa an sinh xã hộ...
#          ✅ Hà Nội quy định mức trông giữ học sinh n...
#          ✅ Hà Nội tăng cường quản lý hoạt động tập ...
#          ✅ Hà Nội quy định mức phụ cấp, trợ cấp đối...
#          ✅ Hà Nội tạo cú huých hỗ trợ toàn diện cho...
#          ✅ Hà Nội siết chặt quản lý phòng cháy, chữ...
#          ✅ Hà Nội hỗ trợ gần 5 triệu đồng/tháng cho...
#          ✅ Hà Nội: Tăng năng lực tiêu thoát nước tạ...
#          ✅ Đổi mới quản trị: Hà Nội tạo chuyển biến...
#          ✅ iHanoi là nền tảng số thống nhất phục vụ...
#          ✅ Hà Nội nâng cao hiệu quả công tác tiếp c...
#          ✅ Dịch bệnh sốt xuất huyết đã được kiểm so...
#          ✅ Hai nhóm cán bộ, công chức được tăng thu...
#          ✅ Cho phép sử dụng địa danh Chuyên Mỹ đăng...
#          ✅ Du lịch Hà Nội bùng nổ nhờ chuỗi lễ hội ...
#          ✅ Hà Nội thông qua mức chi hỗ trợ an sinh ...
#          ✅ Cho phép Hà Nội áp dụng cơ chế đặt hàng ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 17: https://thanglong.chinhphu.vn/thoi-su/trang-17.htm
#          ✅ Phối hợp giải quyết nhanh chóng, dứt điể...
#          ✅ Hoạt động giám sát của HĐND Thành phố ng...
#          ✅ Cấp cứu kịp thời bệnh nhân bị đột quỵ...
#          ✅ Phát huy hiệu quả các quỹ xã hội để tăng...
#          ✅ Cảnh báo nguy hiểm khi tự ý dùng thuốc p...
#          ✅ Hà Nội đặt mục tiêu tăng trưởng từ 11% t...
#       -> Đã lưu 24 bài mới.
#       -> Trang 19: https://thanglong.chinhphu.vn/thoi-su/trang-19.htm
#          ✅ Hà Nội đột phá hạ tầng giáo dục với hơn ...
#          ✅ Festival Thu Hà Nội 2025: Gắn kết văn hó...
#          ✅ Ủy ban MTTQ Hà Nội kêu gọi ủng hộ đồng b...
#          ✅ Mặt trận TP. Hà Nội ủng hộ đồng bào bị t...
#          ✅ Ủy ban bầu cử thành phố Hà Nội họp phiên...
#          ✅ Bảng giá đất Hà Nội năm 2026: Cần tránh ...
#          ✅ Hà Nội: Cử tri Trung Giã, Kim Anh, Sóc S...
#          ✅ Tập huấn cấp Giấy chứng nhận đủ điều kiệ...
#          ✅ Ngàn bánh chưng và hàng chục tỷ đồng sẻ ...
#          ✅ Khai mạc Hội chợ hàng Việt phục vụ công ...
#          ✅ Sở NN&MT sẽ giải quyết thủ tục hành chín...
#          ✅ Dấu ấn đồng diễn nghệ thuật 'Hà Nội - Mi...
#          ✅ Bảo đảm tiến độ, chất lượng xây dựng Dự ...
#          ✅ Chung tay ủng hộ đồng bào miền Trung tại...
#          ✅ Tăng cường xúc tiến thương mại, tiêu thụ...
#          ✅ Di sản thăng hoa trong không gian sáng t...
#          ✅ Tăng sức mạnh tổ chức, bảo vệ quyền lợi ...
#          ✅ Chỉ sử dụng thuốc kháng sinh khi được bá...
#          ✅ Dịch bệnh sốt xuất huyết tiếp tục giảm n...
#          ✅ Hà Nội trao 30 tỷ đồng cho tỉnh Đắk Lắk,...
#          ✅ Cơ quan Đoàn đại biểu Quốc hội và HĐND T...
#          ✅ Hà Nội hỗ trợ khẩn cấp tỉnh Gia Lai 50 t...
#          ✅ Kỳ họp thứ 28 HĐND TP. Hà Nội khóa XVI s...
#          ✅ Thuỷ điện Hoà Bình xả lũ, Hà Nội yêu cầu...
#       -> Đã lưu 24 bài mới.
#       -> Trang 20: https://thanglong.chinhphu.vn/thoi-su/trang-20.htm
#          ✅ Ưu tiên đầu tư phát triển đội ngũ giáo v...
#          ✅ Ấn tượng Lễ khai mạc Festival Thu Hà Nội...
#          ✅ Kiểm soát chất lượng bảo đảm an toàn thự...
#          ✅ Hà Nội điều chỉnh phân công công tác của...
#          ✅ Thành ủy Hà Nội ban hành quy định mới về...
#          ✅ Hà Nội xử phạt 243 trường hợp xe ba bánh...
#          ✅ Chăm sóc sức khỏe người cao tuổi trong b...
#          ✅ Khai mạc Đại hội điểm Đại hội Đại biểu P...
#          ✅ Bàn giải pháp phòng, chống ùn tắc giao t...
#          ✅ Triển khai nhiệm vụ về sắp xếp, bố trí, ...
#          ✅ Bứt phá kinh tế số Thủ đô từ chính quyền...
#          ✅ Giữ vững phẩm chất 'Bộ đội Cụ Hồ', tiên ...
#          ✅ Hà Nội ủng hộ 10 tỷ đồng hỗ trợ đồng bào...
#          ✅ Hà Nội xây dựng kế hoạch hỗ trợ các tỉnh...
#          ✅ Kỷ niệm 95 năm thành lập Hội Nông dân Vi...
#          ✅ Khai mạc Triển lãm sản phẩm OCOP, làng n...
#          ✅ Triển khai các hoạt động chăm lo Tết Ngu...
#          ✅ Hà Nội điều chỉnh giao thông đường Võ Ng...
#          ✅ Triển khai nhiệm vụ năm học 2025-2026 Cô...
#          ✅ Hà Nội chỉ đạo thực hiện Nghị quyết của ...
#          ✅ Thành lập Ủy ban bầu cử TP. Hà Nội...
#          ✅ Hà Nội triển khai xây dựng 3 phường kiểu...
#          ✅ Chương trình nghệ thuật 'Phụ nữ Thủ đô t...
#          ✅ Doanh nghiệp lữ hành Hà Nội 'hiến kế' ph...
#       -> Đã lưu 24 bài mới.
#       -> Trang 21: https://thanglong.chinhphu.vn/thoi-su/trang-21.htm
#          ✅ Độc đáo Tour "Một ngày cùng Di sản Phú T...
#          ✅ Hà Nội thành lập 2 ban chỉ đạo tháo gỡ v...
#          ✅ Giáo dục - nền tảng kiến tạo tương lai T...
#          ✅ Tri ân các y bác sĩ nhân Ngày Nhà giáo V...
#          ✅ Hội chợ hàng Việt phục vụ đoàn viên, côn...
#          ✅ Xóa 'chợ cóc', 'chợ tạm': Cần cải tổ hạ ...
#          ✅ Xử phạt tài xế làm rơi bùn xuống phố, gâ...
#          ✅ Quỹ Bảo vệ và Phát triển rừng: Tạo nguồn...
#          ✅ Hà Nội: Phát triển hệ thống vận tải hành...
#          ✅ Chuyển đổi phương tiện ‘xanh’: Giải pháp...
#          ✅ Hà Nội: Tổ chức giao thông đường Phan Tr...
#          ✅ Người Hiệu trưởng giữ ngọn lửa yêu nghề ...
#          ✅ Lãnh đạo thành phố chúc mừng Sở Giáo dục...
#          ✅ Hà Nội tập huấn quản lý xây dựng, hạ tần...
#          ✅ Tăng cường hỗ trợ hộ kinh doanh khi chuy...
#          ✅ Festival Thu Hà Nội 2025: Khi ký ức trở ...
#          ✅ Sắp diễn ra Lễ hội vinh danh làng nghề v...
#          ✅ Sóc Sơn sắp có thêm một trường học phổ t...
#          ✅ Hà Nội bước vào giai đoạn đột phá giáo d...
#          ✅ Hà Nội thí điểm xây dựng 3 phường kiểu m...
#          ✅ Xã Đại Thanh tăng cường bảo đảm an toàn ...
#          ✅ Triển khai quy định về xây dựng tại vùng...
#          ✅ Hà Nội tổ chức Triển lãm quảng bá sản ph...
#          ✅ Khẳng định vai trò khuyến công trong lan...
#       -> Đã lưu 24 bài mới.
#       -> Trang 22: https://thanglong.chinhphu.vn/thoi-su/trang-22.htm
#          ✅ Làng nghề mộc Vạn Điểm tăng sức hút cho ...
#          ✅ Khai mạc Triển lãm chuyên đề ngành thêu ...
#          ✅ Hỗ trợ doanh nghiệp công nghiệp chủ lực ...
#          ✅ Đại hội MTTQ Việt Nam TP. Hà Nội: ‘Đoàn ...
#          ✅ Hà Nội triển khai đánh giá, tự chấm điểm...
#          ✅ Hà Nội yêu cầu hoàn thành rà soát hiện t...
#          ✅ Công an Hà Nội học tập, quán triệt văn k...
#          ✅ Đại hội MTTQ Việt Nam TP. Hà Nội: Mở ra ...
#          ✅ Khánh thành trạm bơm giải quyết nhu cầu ...
#          ✅ Nâng cao trách nhiệm quản lý nhà nước về...
#          ✅ Hà Nội đẩy mạnh khai thác tiềm năng du l...
#          ✅ Tăng tốc chuyển đổi số trong lực lượng C...
#          ✅ Siết chặt quản lý bữa ăn bán trú, bảo đả...
#          ✅ Chống hàng giả dịp cuối năm: Tạo môi trư...
#          ✅ Khai mạc Festival Bảo tồn và Phát triển ...
#          ✅ Hà Nội thí điểm 15 ngày giải quyết thủ t...
#          ✅ Ra mắt ứng dụng 'Mặt trận số' trên iHano...
#          ✅ An an toàn thực phẩm trường học: Từ 'Ngà...
#          ✅ Số ca sốt xuất huyết giảm so với tuần tr...
#          ✅ Hà Nội tăng cường giám sát, cảnh báo sớm...
#          ✅ Bảo đảm an toàn thực phẩm trường học: Ki...
#          ✅ Hà Nội tôn vinh 35 sản phẩm công nghiệp ...
#          ✅ Trường THCS Lương Yên kỷ niệm 70 năm thà...
#          ✅ Hà Nội ban hành Chỉ số cải cách hành chí...
#       -> Đã lưu 24 bài mới.
#       -> Trang 23: https://thanglong.chinhphu.vn/thoi-su/trang-23.htm
#          ✅ HĐND Hà Nội phê duyệt dự án cải tạo chỉn...
#          ✅ Bàn biện pháp giải quyết hoạt động khiếu...
#          ✅ Nỗ lực kiểm soát mất cân bằng giới tính ...
#          ✅ Đồng chí Trần Thế Cương giữ chức vụ Phó ...
#          ✅ Đẩy mạnh các hoạt động chăm sóc sức khỏe...
#          ✅ Đồng chí Nguyễn Xuân Lưu được bầu giữ ch...
#          ✅ Người cao tuổi cần giữ ấm cơ thể khi thờ...
#          ✅ Hà Nội chuyển mạnh từ tư duy ‘quản lý’ s...
#          ✅ Giới thiệu nhân sự giữ các chức danh qua...
#          ✅ Hà Nội thông qua điều chỉnh chủ trương đ...
#          ✅ Thông qua chủ trương đầu tư xây dựng tuy...
#          ✅ Thành lập BCĐ Hội thi Kỹ thuật sáng tạo ...
#          ✅ Tôn vinh sáng tạo có giá trị thực tiễn...
#          ✅ Đồng chí Phùng Thị Hồng Hà được bầu giữ ...
#          ✅ Quyết tâm xây dựng xã Bát Tràng ‘sạch’ m...
#          ✅ HĐND TP. Hà Nội thông qua nhiều dự án tạ...
#          ✅ HĐND Hà Nội thành lập Ban Khoa học Công ...
#          ✅ Xử lý dứt điểm 'chợ cóc, chợ tạm' và cơ ...
#          ✅ Tư duy và hành động đột phá để đưa Nghị ...
#          ✅ Tân Chủ tịch UBND TP. Hà Nội: Tạo đột ph...
#          ✅ Tập trung hành động, tháo gỡ điểm nghẽn,...
#          ✅ Hà Nội kiến tạo sức bật du lịch xã Phù Đ...
#          ✅ Đồng chí Nguyễn Văn Thắng giữ chức Chủ t...
#          ✅ HĐND Hà Nội: Quyết nghị chủ trương một s...
#       -> Đã lưu 24 bài mới.
#       -> Trang 24: https://thanglong.chinhphu.vn/thoi-su/trang-24.htm
#          ✅ Hướng tới xây dựng một hệ sinh thái giao...
#          ✅ Đề xuất bổ sung nội dung giao thông vào ...
#          ✅ CATP Hà Nội và Công an tỉnh Đồng Nai tra...
#          ✅ Bí thư Thành ủy Hà Nội: Phân cấp, ủy quy...
#          ✅ Thúc đẩy phát triển đô thị xanh, thông m...
#          ✅ Nâng cao nhận thức để phòng chống bệnh đ...
#          ✅ Hà Nội triển khai hỗ trợ lưu động thủ tụ...
#          ✅ Hà Nội ủy quyền phê duyệt danh sách, kin...
#          ✅ Hà Nội ứng dụng iHanoi để chuẩn hóa dữ l...
#          ✅ Thành ủy Hà Nội tri ân các đồng chí được...
#          ✅ Tăng tốc thực hiện các nhiệm vụ trọng tâ...
#          ✅ Kỳ họp chuyên đề HĐND TP. Hà Nội sẽ xem ...
#          ✅ Hà Nội vận hành AI điều khiển giao thông...
#          ✅ Xây dựng đội ngũ đại biểu chuyên trách c...
#          ✅ Hà Nội ra mắt Kiosk thông minh, chứng th...
#          ✅ Giới thiệu đồng chí Nguyễn Đức Trung để ...
#          ✅ Hà Nội hút khách với tinh hoa di sản...
#          ✅ Đồng chí Nguyễn Đức Trung được điều động...
#          ✅ Khảo sát kết nối tour Hà Nội - Lai Châu:...
#          ✅ Đưa chỉ đạo chiến lược vào chương trình ...
#          ✅ Chuyển đổi mô hình từ thuế khoán sang kê...
#          ✅ Hơn 200 doanh nghiệp tham gia triển lãm ...
#          ✅ Ngành Giáo dục Thủ đô tuyên dương nhiều ...
#          ✅ Từ 14/11, cấm phương tiện rẽ trái từ Xuâ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 25: https://thanglong.chinhphu.vn/thoi-su/trang-25.htm
#          ✅ Ủy nhiệm đồng chí Dương Đức Tuấn điều hà...
#          ✅ Hà Nội đã chuyển đổi hơn 20% xe buýt san...
#          ✅ Lan tỏa tinh thần Nghị quyết Đại hội XVI...
#          ✅ Làng nghề tò he chuyển mình nhờ thương m...
#          ✅ Hà Nội và Vĩnh Long tăng cường hợp tác p...
#          ✅ Từ 18/11, tuyến metro Cát Linh-Hà Đông c...
#          ✅ Hà Nội: Kim ngạch xuất nhập khẩu đạt trê...
#          ✅ Học sinh Hà Nội giành 5 Huy chương tại O...
#          ✅ Hà Nội sẽ tuyên dương 95 thủ khoa tốt ng...
#          ✅ Gắn cải cách công vụ với chất lượng chăm...
#          ✅ Xử lý 'chợ cóc', 'chợ tạm' phải làm quyế...
#          ✅ Tuyên dương 'Sáng kiến, sáng tạo trong c...
#          ✅ Tăng cường đối thoại trực tiếp, lắng ngh...
#          ✅ Hà Nội khởi động Chương trình Khuyến mại...
#          ✅ Hà Nội: Chỉ số giá tiêu dùng tháng 10 tă...
#          ✅ Thị trường bán lẻ Hà Nội: 'Điểm sáng' tr...
#          ✅ Trường THPT Kim Anh được trao Bằng khen ...
#          ✅ Nâng cao chất lượng dân số qua sàng lọc ...
#          ✅ Hà Nội áp dụng quy định mới về bảo đảm t...
#          ✅ Thu ngân sách vượt gần 10% dự toán, tín ...
#          ✅ Khai mạc Triển lãm các sản phẩm thủ công...
#          ✅ Thi đua đổi mới, xây dựng Đảng bộ Thủ đô...
#          ✅ Áo dài - nhịp cầu kết nối văn hóa và du ...
#          ✅ Đổi mới sáng tạo - động lực then chốt ch...
#       -> Đã lưu 24 bài mới.
#       -> Trang 26: https://thanglong.chinhphu.vn/thoi-su/trang-26.htm
#          ✅ Hà Nội: Các phường đột phá tư duy, nâng ...
#          ✅ Số ca mắc sốt xuất huyết đang có xu hướn...
#          ✅ Hà Nội tiên phong hành động vì ‘Không kh...
#          ✅ Cảnh báo sức khỏe người cao tuổi và trẻ ...
#          ✅ Hà Nội đẩy mạnh tuyên truyền thành tựu c...
#          ✅ 'Ngày hội khuyến mại tháng 11': Thu hút ...
#          ✅ Chuyển biến mạnh mẽ trong sử dụng năng l...
#          ✅ Lan tỏa xu hướng sản xuất, tiêu dùng sản...
#          ✅ Hà Nội sẽ sử dụng cơ sở dữ liệu quốc gia...
#          ✅ Phát triển ngành thủ công mỹ nghệ: Cần x...
#          ✅ Khởi công xây dựng 1.200 căn hộ cho lực ...
#          ✅ Hà Nội tổ chức Triển lãm các sản phẩm th...
#          ✅ Tăng cường kiểm tra đột xuất, tập trung ...
#          ✅ Đồng chí Bùi Huyền Mai được chỉ định giữ...
#          ✅ Sản xuất công nghiệp Hà Nội tăng trưởng ...
#          ✅ Hà Nội thúc chuyển đổi số giáo dục nghề ...
#          ✅ Hà Nội chung tay vì người nghèo...
#          ✅ Hà Nội xây dựng kế hoạch phát triển 2026...
#          ✅ Lãnh đạo MTTQ TP. Hà Nội trao Huy hiệu Đ...
#          ✅ Hà Nội kiểm tra hoạt động kinh doanh vận...
#          ✅ Hiệu quả thiết thực từ các chương trình ...
#          ✅ Festival Thăng Long - Hà Nội 2025: Di sả...
#          ✅ Đồng chí Nguyễn Duy Ngọc được phân công ...
#          ✅ Thi đua cải cách hành chính - động lực đ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 27: https://thanglong.chinhphu.vn/thoi-su/trang-27.htm
#          ✅ Hà Nội xử lý nghiêm ca sĩ Jack về vi phạ...
#          ✅ Tăng cường niềm tin, xây dựng chính quyề...
#          ✅ Hà Nội tạo đột phá trong xây dựng Đảng v...
#          ✅ Kiều Phú khởi công xây dựng, sửa chữa 63...
#          ✅ Định hướng phát triển cho sản phẩm công ...
#          ✅ Cấm xe qua cầu Long Biên hướng vào trung...
#          ✅ Hà Nội trên hành trình đánh thức tiềm nă...
#          ✅ Xây dựng Trường Cao đẳng Công nghệ cao H...
#          ✅ Hà Nội tiên phong cắt giảm, đơn giản hóa...
#          ✅ Văn hóa xếp hàng thưởng thức ẩm thực ở H...
#          ✅ 'Gaia' đánh thức tình yêu Trái Đất giữa ...
#          ✅ Hà Nội quyết định không đấu giá 3 mỏ cát...
#          ✅ Đa Phúc hướng tới hoàn thành xã nông thô...
#          ✅ Lễ hội Áo dài Du lịch Hà Nội 2025: Tôn v...
#          ✅ Hà Nội tăng tốc các dự án đường sắt đô t...
#          ✅ Định vị thương hiệu 'Thành phố sáng tạo'...
#          ✅ Cần hình thành thói quen sử dụng phương ...
#          ✅ ‘Ngày hội khuyến mại tháng 11’: Tưng bừn...
#          ✅ Hà Nội tăng cường kiểm soát đầu tư hạ tầ...
#          ✅ Sẵn sàng cho Festival Bảo tồn, phát triể...
#          ✅ Hà Nội: Chung tay vì người nghèo, không ...
#          ✅ Festival bảo tồn và phát triển làng nghề...
#          ✅ Hà Nội và Viện VKIST tăng cường hợp tác ...
#          ✅ Sinh viên – ‘Hạt nhân’ tiên phong, lan t...
#       -> Đã lưu 24 bài mới.
#       -> Trang 28: https://thanglong.chinhphu.vn/thoi-su/trang-28.htm
#          ✅ Nâng mức phạt vi phạm phòng cháy chữa ch...
#          ✅ Hà Nội vươn tầm "Thành phố Ẩm thực châu ...
#          ✅ Ghi nhận gần 400 ca mắc sốt xuất huyết t...
#          ✅ Hà Nội đón 28,22 triệu lượt du khách tro...
#          ✅ Hà Nội mở rộng kết nối du lịch tại Hội n...
#          ✅ Hà Nội và Quảng Tây thúc đẩy hợp tác số,...
#          ✅ Kiểm tra đột xuất bữa ăn bán trú tại xã ...
#          ✅ Phát triển làng nghề Hà Nội gắn với xây ...
#          ✅ Hà Nội vận động cán bộ, công chức,...
#          ✅ Sinh viên Thủ đô với sứ mệnh xây dựng vă...
#          ✅ Trưởng Tiểu học Cự Khê thay nhà thầu mới...
#          ✅ Học sinh Hà Nội giành ngôi Vô địch Đường...
#          ✅ Ngành thủ công mỹ nghệ cần khai thác tối...
#          ✅ Chủ động phòng chống bệnh cho trẻ nhỏ th...
#          ✅ Ba đột phá chiến lược kiến tạo tầm vóc m...
#          ✅ Hà Nội sẽ xác thực điện tử, nhận diện si...
#          ✅ Hà Nội triển khai thực hiện chỉ đạo của ...
#          ✅ Du lịch Hà Nội tăng tốc cuối năm để bứt ...
#          ✅ Hướng tới Thủ đô phát triển toàn diện, n...
#          ✅ Kiểm tra đột xuất bữa ăn bán trú tại trư...
#          ✅ Hà Nội phát hiện hơn 16.000 sản phẩm giả...
#          ✅ Lan tỏa hình ảnh Thủ đô qua Hội chợ Mùa ...
#          ✅ Nhanh chóng khống chế vụ cháy nhà dân tạ...
#          ✅ Tạo động lực cho thương mại điện tử Hà N...
#       -> Đã lưu 24 bài mới.
#       -> Trang 29: https://thanglong.chinhphu.vn/thoi-su/trang-29.htm
#          ✅ Hà Nội triển khai Nghị định 271 của Chín...
#          ✅ Định hướng phát triển ngành công nghiệp ...
#          ✅ Kiểm tra đột xuất tại Trường Tiểu học Cự...
#          ✅ Chủ đầu tư dựng nhà bạt cho dân xếp hàng...
#          ✅ Hà Nội dừng yêu cầu nộp hồ sơ giấy với 2...
#          ✅ Khẩn trương hoàn thành công tác bàn giao...
#          ✅ Hà Nội quyết tâm hoàn thành giải ngân 10...
#          ✅ Tăng tốc phát triển chương trình OCOP và...
#          ✅ Công an Hà Nội tổ chức hội nghị chuyên đ...
#          ✅ Tăng cường hợp tác giữa Thủ đô Hà Nội và...
#          ✅ Chùa Non Nước: Điểm đến mang linh khí Th...
#          ✅ Phân luồng giao thông phục vụ Lễ mở ký C...
#          ✅ Hà Nội: Gần 1.900 camera AI sẽ tính lưu ...
#          ✅ Thông báo phân luồng giao thông phục vụ ...
#          ✅ Xử phạt trường hợp đăng tin sai sự thật,...
#          ✅ Hà Nội tăng cường xây dựng, chỉnh đốn Đả...
#          ✅ Xe dịch vụ công lưu động: Đưa chính quyề...
#          ✅ Tăng cường kiểm tra đột xuất thực phẩm l...
#          ✅ Tăng tốc trong chuyển đổi hạ tầng giao t...
#          ✅ Hà Nội tiên phong trong thực hiện chủ tr...
#          ✅ Đẩy mạnh vai trò quản lý nhà nước trong ...
#          ✅ Trao giải Hội thi sản phẩm làng nghề TP....
#          ✅ Khánh thành dự án cải tạo, nâng cấp Bảo ...
#          ✅ Hà Nội thành lập Tổ công tác thúc đẩy Dự...
#       -> Đã lưu 24 bài mới.
#       -> Trang 30: https://thanglong.chinhphu.vn/thoi-su/trang-30.htm
#          ✅ Hà Nội ra quân tiếp tục kiểm soát, xử lý...
#          ✅ Tìm giải pháp kiểm soát chất lượng an to...
#          ✅ Tăng cường quản lý giết mổ và tiêu thụ s...
#          ✅ Để hiện thực mục tiêu xây dựng Thủ đô Hà...
#          ✅ Hà Nội triển khai chương trình 'Chung ta...
#          ✅ Cấp cứu thành công bệnh nhân quốc tịch G...
#          ✅ "GOm Show" - Thêm sản phẩm du lịch đêm đ...
#          ✅ Dấu mốc đặc biệt mở ra thời kỳ phát triể...
#          ✅ Hà Nội phát động phong trào thi đua làm ...
#          ✅ Xử lý dứt điểm cơ sở giết mổ gia súc, gi...
#          ✅ Phát triển không gian đô thị đa cực: Nền...
#          ✅ Phát huy nguồn lực, trí tuệ của văn nghệ...
#          ✅ Tăng cường lãnh đạo của Đảng trong công ...
#          ✅ Hà Nội: Thành lập Ban Chỉ đạo về phát tr...
#          ✅ Giới thiệu, quảng bá sản phẩm an toàn đế...
#          ✅ "Sắc hoa Tường Phiêu" - Sản phẩm du lịch...
#          ✅ Cần hành động, có giải pháp dài hạn để g...
#          ✅ Hà Nội: Phấn đấu tăng thu ngân sách ít n...
#          ✅ Hà Nội tăng tốc thu hút du khách quốc tế...
#          ✅ Hà Nội đẩy mạnh du lịch golf, thu hút kh...
#          ✅ Thành lập Ban Chỉ đạo các dự án đường sắ...
#          ✅ Nhịp cầu nhà nông- Kết nối đưa nông sản ...
#          ✅ Đổi mới tư duy quy hoạch - nền tảng để H...
#          ✅ Hoàn thiện cơ chế phân cấp, phân quyền đ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 31: https://thanglong.chinhphu.vn/thoi-su/trang-31.htm
#          ✅ Danh sách Ủy ban Kiểm tra Thành ủy Hà Nộ...
#          ✅ Hà Nội dự kiến tăng trưởng khoảng 8,3% n...
#          ✅ Hà Nội dẫn đầu, thành phố Huế xếp thứ 2 ...
#          ✅ Hà Nội: Toàn bộ hồ sơ quản lý người lao ...
#          ✅ Hà Nội đồng loạt ra quân kiểm tra nồng đ...
#          ✅ Hà Nội: Ra mắt Ban Chấp hành Đảng bộ Thà...
#          ✅ Xóa bỏ tâm lý ngại thay đổi để xây dựng ...
#          ✅ Hà Nội yêu cầu không làm gián đoạn bữa ă...
#          ✅ Hà Nội tham dự Hội chợ quốc tế hàng thủ ...
#          ✅ Hà Nội ra mắt 3 sản phẩm du lịch mới...
#          ✅ Khuyến công-‘Trợ lực’ cho các làng nghề ...
#          ✅ Hà Nội sẽ giải quyết dứt điểm 4 vấn đề đ...
#          ✅ Đề xuất nhiều giải pháp để phân cấp mạnh...
#          ✅ Có tầm nhìn và tư duy đổi mới, dám nghĩ,...
#          ✅ Khai mạc Triển lãm sản phẩm OCOP, làng n...
#          ✅ Hà Nội tham gia Hội chợ quốc tế Lifestyl...
#          ✅ Đổi mới tư duy, tiên phong hành động tro...
#          ✅ Nữ bác sĩ trẻ Thủ đô ghi dấu ấn tại KSMO...
#          ✅ ‘Có vào, có ra, có lên, có xuống’ - bước...
#          ✅ ‘Sân chơi sáng tạo’ cho các sản phẩm thủ...
#          ✅ Hà Nội đề xuất tăng tuyến buýt phục vụ H...
#          ✅ Phát triển Hà Nội trở thành đại đô thị s...
#          ✅ Kiểm tra phòng, chống dịch phục vụ Kỳ họ...
#          ✅ Liên kết và đa dạng hóa sản phẩm để tạo ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 32: https://thanglong.chinhphu.vn/thoi-su/trang-32.htm
#          ✅ Phòng chống bệnh uốn ván mùa mưa lũ...
#          ✅ Danh sách 75 Ủy viên Ban chấp hành Đảng ...
#          ✅ Thử nghiệm tính năng vé tháng điện tử đị...
#          ✅ Khai mạc Đại hội Đảng bộ Hà Nội: Xây dựn...
#          ✅ Hà Nội xác định phải có đột phá trong đổ...
#          ✅ HÀ NỘI tự tin bước vào giai đoạn kiến tạ...
#          ✅ Hà Nội tiên phong trong kỷ nguyên mới: T...
#          ✅ Phát biểu của Tổng Bí thư Tô Lâm tại Đại...
#          ✅ Định hình mô hình tăng trưởng mới cho Th...
#          ✅ Đồng chí Bùi Thị Minh Hoài trúng cử Ban ...
#          ✅ Lần đầu tiên công nghệ số được ứng dụng ...
#          ✅ Đoàn kết, bản lĩnh và đổi mới: Nền tảng ...
#          ✅ Hà Nội chuyển mình mạnh mẽ trong hành tr...
#          ✅ Chiều nay, Đảng bộ TP. Hà Nội bầu Ban Ch...
#          ✅ HÀ NỘI tự tin bước vào giai đoạn kiến tạ...
#          ✅ Đồng chí Bùi Thị Minh Hoài tiếp tục giữ ...
#          ✅ Hà Nội phát hiện nhiều hành vi vi phạm k...
#          ✅ Tổng Bí thư gợi ý 7 nhiệm vụ đối với Đản...
#          ✅ Kỳ vọng những đột phá trong chuyển đổi s...
#          ✅ Xử lý kịp thời vi phạm an toàn thực phẩm...
#          ✅ Tổng Bí thư Tô Lâm đến dự Đại hội Đại bi...
#          ✅ Danh sách 17 đồng chí trong Ban Thường v...
#          ✅ Y tế Thủ đô, chuyển mình khẳng định vị t...
#          ✅ Khẩn trương rà soát thiệt hại của ngành ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 33: https://thanglong.chinhphu.vn/thoi-su/trang-33.htm
#          ✅ Cẩn trọng trước bánh Trung Thu 'siêu rẻ'...
#          ✅ Công an Hà Nội triệt phá đường dây sản x...
#          ✅ Đảng bộ Hà Nội: Gương mẫu, tiên phong để...
#          ✅ Giao thương kết nối các sản phẩm OCOP, l...
#          ✅ Tổng Bí thư Tô Lâm đến dự Đại hội Đại bi...
#          ✅ Chương trình 03-CTr/TU: Hà Nội khẳng địn...
#          ✅ Nhiều đề xuất thiết thực, thể hiện trách...
#          ✅ Hà Nội tạm cấm lưu thông một số tuyến đư...
#          ✅ Kinh tế Thủ đô 2021-2025: Giữ vững đà tă...
#          ✅ Khởi tố Shark Bình cùng đồng phạm liên q...
#          ✅ Tiên phong, đột phá trong kỷ nguyên mới,...
#          ✅ Nâng cao chất lượng xây dựng nông thôn m...
#          ✅ ‘Cơ hội vàng’ cho ngành thủ công mỹ nghệ...
#          ✅ Công an TP. Hà Nội triển khai phương án ...
#          ✅ Hà Nội: Ứng trực tại các điểm trọng yếu ...
#          ✅ Dấu mốc quan trọng, hướng tới Thủ đô hiệ...
#          ✅ Đại hội Đảng bộ TP. Hà Nội: 4 nhiệm vụ đ...
#          ✅ Hà Nội có 13 đội tuyển dự kỳ thi chọn họ...
#          ✅ Hà Nội phát động đợt thi đua cao điểm ch...
#          ✅ Hà Nội: Khởi tố 4 đối tượng sản xuất, bu...
#          ✅ Công an Hà Nội khởi tố 04 đối tượng tron...
#          ✅ Khai trương Trung tâm báo chí phục vụ Đạ...
#          ✅ Kỳ vọng những bước chuyển mạnh mẽ của Th...
#          ✅ Đại hội Đại biểu Đảng bộ TP. Hà Nội nhiệ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 34: https://thanglong.chinhphu.vn/thoi-su/trang-34.htm
#          ✅ Chủ tịch UBND TP. Hà Nội kiểm tra, chỉ đ...
#          ✅ Khẩn trương hỗ trợ y tế khắc phục hậu qu...
#          ✅ Phát động phong trào thi đua yêu nước, x...
#          ✅ Tai nạn lao động tại Công ty TNHH xuất n...
#          ✅ Lấy ý kiến về 3 dự thảo nghị quyết quy đ...
#          ✅ Nước sông Cầu rút dần, người dân chuẩn b...
#          ✅ Di dời người dân khỏi vùng nguy hiểm, gi...
#          ✅ Quốc lộ 3 ngập sâu, Hà Nội hướng dẫn lộ ...
#          ✅ Tìm giải pháp nâng cao năng lực, hoạt độ...
#          ✅ Thông tin ban đầu vụ cháy nhà làm 05 ngư...
#          ✅ Thi đua yêu nước - động lực xây dựng Thủ...
#          ✅ Lũ trên sông Cầu, sông Cà Lồ tiếp tục rú...
#          ✅ Hà Nội khánh thành Nhà máy điện rác Sóc ...
#          ✅ Nhiệm kỳ đổi mới sáng tạo, kiến tạo nền ...
#          ✅ Ra mắt các tính năng mới trên iHanoi: Nâ...
#          ✅ Chủ động xây dựng chuỗi cung ứng hàng Vi...
#          ✅ Chủ tịch TP. Hà Nội chỉ đạo khẩn trương ...
# ...
#          ✅ Hà Nội thành lập Trung tâm Quản trị hệ t...
#          ✅ Hà Nội kiểm tra, rà soát văn bản quy phạ...
#          ✅ Hà Nội: Nhiều đổi mới hiệu quả trong côn...
#          ✅ Hà Nội mở đợt thi đua cao điểm cài đặt t...
#       -> Đã lưu 16 bài mới.
#       -> Trang 7: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-7.htm
#          ✅ Hiệu quả từ camera giám sát giao thông...
#          ✅ Hà Nội tăng điểm về kết quả đánh giá Bộ ...
#          ✅ Hà Nội tìm giải pháp nâng cao các chỉ số...
#          ✅ Quận Hoàng Mai cần chấn chỉnh cán bộ xử ...
#          ✅ Hà Nội: Địa phương đầu tiên hoàn thành đ...
#          ✅ Hà Nội phê duyệt thí điểm thành lập Trun...
#          ✅ Hà Nội tổ chức lại bộ phận một cửa: Hướn...
#          ✅ Hà Nội khắc phục điểm nghẽn, xây dựng nề...
#          ✅ Chuyển đổi số từ mô hình ‘phường số’, ‘t...
#          ✅ Trung tâm Phục vụ hành chính công Hà Nội...
#          ✅ Thúc đẩy tiến độ dự án vốn ngoài ngân sá...
#       -> Đã lưu 11 bài mới.
#       -> Trang 8: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-8.htm
#          ✅ Hà Nội: Năm 2024 sẽ số hóa hoàn toàn 100...
#          ✅ Tập trung xử lý các "điểm nghẽn" trong g...
#          ✅ Hà Nội phân cấp quản lý để sử dụng hiệu ...
#          ✅ Nâng cao chất lượng phục vụ của các cơ q...
#          ✅ Hà Nội quyết tâm hoàn thành các chỉ tiêu...
#          ✅ Các cơ sở y tế công lập, tư nhân phải tr...
#          ✅ Xây dựng Thành phố thông minh: Hướng đến...
#          ✅ Hà Nội rút ngắn thời gian làm việc với h...
#          ✅ Hà Nội phát động triển khai thí điểm các...
#          ✅ Tháo gỡ "nút thắt" về TTHC cho người dân...
#          ✅ Công tác cán bộ là ‘then chốt của then c...
#          ✅ Để Hà Nội chuyển đổi số, xây dựng thành ...
#          ✅ Hà Nội đã hoàn thành giai đoạn “tăng tốc...
#          ✅ Hà Nội tiếp tục tháo gỡ vướng mắc cho 6 ...
#          ✅ Sở Nội vụ, quận Đống Đa đạt chỉ số Cải c...
#       -> Đã lưu 15 bài mới.
#       -> Trang 9: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-9.htm
#          ✅ Thí điểm mô hình quận, huyện chuyển đổi ...
#          ✅ Đề xuất sát thực tiễn để chuyển đổi số l...
#          ✅ Giải quyết nhanh các TTHC thuộc lĩnh vực...
#          ✅ Xây dựng, hoàn thiện cơ sở dữ liệu chuyê...
#          ✅ Phấn đấu 100% hồ sơ các sở, ngành xử lý ...
#          ✅ Chuyển đổi số để phục vụ tốt nhất cho ng...
#          ✅ Hà Nội sẽ có giải pháp rút ngắn thời gia...
#          ✅ Mô hình chính quyền đô thị: Vận hành thu...
#          ✅ Triển khai mô hình “Một cửa đô thị hiện ...
#          ✅ Nhiều mô hình, sáng kiến hay để phục vụ ...
#          ✅ Quyết tâm thực hiện chuyển đổi số trong ...
#          ✅ Hơn 10.000 chữ ký số đã được cấp miễn ph...
#          ✅ Đẩy mạnh ứng dụng CNTT trong các lĩnh vự...
#          ✅ Hà Nội sơ kết công tác CCHC, chuyển đổi ...
#          ✅ Quận đầu tiên ứng dụng trí tuệ nhân tạo ...
#          ✅ Phát triển công dân số...
#          ✅ Hà Nội sẽ giám sát việc thực hiện các cô...
#          ✅ Tích cực liên thông thủ tục hành chính đ...
#          ✅ Thi trực tuyến "Tìm hiểu pháp luật về đị...
#          ✅ Đẩy mạnh cải cách thủ tục hành chính tro...
#          ✅ Thành lập tổ ‘xung kích số’, mô hình cơ ...
#       -> Đã lưu 21 bài mới.
#       -> Trang 10: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-10.htm
#          ✅ Thực hiện mục tiêu xây dựng chính quyền ...
#          ✅ Giảm đầu mối, lược bỏ các bước xử lý nội...
#          ✅ Hà Nội triển khai xây dựng Đề án vị trí ...
#          ✅ Tập huấn sử dụng Hệ thống thông tin giải...
#          ✅ Hà Nội: "5 thủ tục hành chính không chờ"...
#          ✅ Đối thoại với cá nhân, tổ chức về thủ tụ...
#          ✅ Hà Nội đôn đốc thực hiện chỉ đạo của Chí...
#          ✅ Khai trương hoạt động các hệ thống thông...
#          ✅ Tăng cường tiếp nhận và xử lý phản ánh, ...
#          ✅ Nỗ lực trong triển khai chỉ đạo của Chín...
#          ✅ Đổi mới tư duy, phong cách lãnh đạo để đ...
#          ✅ Xây dựng đề án “TP. Hà Nội thông minh”; ...
#          ✅ Sở LĐ-TB&XH và quận Hoàn Kiếm đứng đầu v...
#          ✅ Hà Nội sẽ triển khai 2 phần mềm, rút ngắ...
#          ✅ Hà Nội tiếp tục cải thiện để nâng cao ch...
#          ✅ Chuyển đổi số để phát triển Thủ đô theo ...
#          ✅ Chuyển đổi số vì mục tiêu phục vụ người ...
#          ✅ Hà Nội: Văn phòng UBND Thành phố, huyện ...
#       -> Đã lưu 18 bài mới.
#       -> Trang 11: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-11.htm
#          ✅ Hà Nội xác định yếu tố con người là tiên...
#          ✅ Tập trung nguồn lực để nâng cao chất lượ...
#          ✅ Cải cách hành chính đi cùng tăng cường p...
#          ✅ Hà Nội chỉ đạo tập trung nâng cao các ch...
#          ✅ Hà Nội phấn đấu trong nhóm địa phương dẫ...
#          ✅ Tối ưu hoá trải nghiệm người dùng đối vớ...
#          ✅ UBND TP. Hà Nội ủy quyền 617 thủ tục hàn...
#          ✅ Hà Nội: Sở Tài chính, quận Cầu Giấy đứng...
#          ✅ Hà Nội mở kênh ZALO tiếp nhận phán ánh v...
#          ✅ Hà Nội thuộc nhóm có điểm tổng hợp chỉ s...
#          ✅ Hà Nội tạo lập thương hiệu Bộ phận Một c...
#          ✅ 100% doanh nghiệp nhỏ và vừa tại Hà Nội ...
#          ✅ Hà Nội thí điểm cung cấp 2 nhóm dịch vụ ...
#          ✅ Nhiều sáng kiến cải cách hành chính của ...
#          ✅ Phân cấp, uỷ quyền: Tăng chủ động cho đị...
#          ✅ Không để nhiều tầng nấc trung gian trong...
#          ✅ Gần 100% hồ sơ TTHC được giải quyết đúng...
#          ✅ Hà Nội xem xét phê duyệt phương án phân ...
#          ✅ Mô hình chính quyền đô thị: Mang lại hiệ...
#       -> Đã lưu 19 bài mới.
#       -> Trang 12: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-12.htm
#          ✅ Xây dựng mô hình mẫu ‘Bộ phận tiếp nhận ...
#          ✅ Tiếp tục nâng cao năng lực quản trị hành...
#          ✅ Xây dựng Chính quyền điện tử: Mô hình hi...
#          ✅ HĐND TP. Hà Nội giám sát về thực hành ti...
#          ✅ Hướng tới một Chính quyền điện tử thông ...
#          ✅ Sở KH&ĐT thí điểm ứng dụng mô hình cơ qu...
#          ✅ Sở Quy hoạch-Kiến trúc: Toàn bộ TTHC đượ...
#          ✅ Hà Nội triển khai nhiều trọng tâm cải cá...
#          ✅ Tiếp tục phương châm 'rõ người, rõ việc,...
#          ✅ Hà Nội phấn đấu chỉ số cải cách hành chí...
#          ✅ Kiên định mục tiêu lấy người dân và doan...
#          ✅ Cải cách hành chính: Thước đo hiệu quả h...
#          ✅ 100% số hồ sơ liên quan đến TTHC phải đư...
#          ✅ Nhiều chuyển biến trong công tác CCHC tạ...
#          ✅ Tiếp tục rà soát, đơn giản hóa TTHC tron...
#          ✅ Đơn giản hóa thủ tục hành chính trong lĩ...
#          ✅ Hà Nội xây dựng thành phố thông minh...
#          ✅ Tạo chuyển biến về cải cách hành chính đ...
#          ✅ Hà Nội có 689 dịch vụ công trực tuyến mứ...
#          ✅ Quận Long Biên: Sáng tạo trong các mô hì...
#          ✅ Hà Nội: 30% dịch vụ công trực tuyến sẽ đ...
#          ✅ Thông qua phương án đơn giản hóa 71 TTHC...
#          ✅ Hà Nội xây dựng chính quyền điện tử...
#       -> Đã lưu 23 bài mới.
#       -> Trang 13: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-13.htm
#          ✅ Đẩy mạnh tuyên truyền dịch vụ công lĩnh ...
#          ✅ Điều tra xã hội học để xác định chỉ số C...
#          ✅ Rút ngắn thời gian giải quyết nhiều TTHC...
#          ✅ Hà Nội đã vận hành 502 dịch vụ công trực...
#          ✅ Hà Nội dẫn đầu cả nước về tỷ lệ hồ sơ đă...
#          ✅ Không để nhiều đơn vị cùng đến kiểm tra ...
#          ✅ Công bố nhiều TTHC liên thông với cấp Tr...
#          ✅ Đã đưa vào hoạt động hơn 600 dịch vụ côn...
#          ✅ Một số quận, huyện bắt đầu triển khai ph...
#          ✅ Hà Nội: 100% đơn vị cấp xã áp dụng phần ...
#          ✅ Ngành Y tế Thủ đô áp dụng quản lý chất l...
#          ✅ Đơn giản hóa nhiều thủ tục hành chính ở ...
#          ✅ Tích cực cải cách hành chính để đón ‘làn...
#          ✅ Đẩy mạnh cải cách hành chính trong quản ...
#          ✅ Quận Ba Đình: Triển khai đồng bộ, hiệu q...
#          ✅ CCHC được xác định khâu đột phá của Hà N...
#          ✅ ‘Alo, Cục Thuế Hà Nội xin nghe’...
#          ✅ Hà Nội đã ban hành danh mục hơn 200 dịch...
#          ✅ Quận Hai Bà Trưng tăng cường triển khai ...
#          ✅ Nghiêm cấm nhũng nhiễu khi giải quyết TT...
#          ✅ Từ 2/1/2018, Hà Nội cấp GPLX trực tuyến ...
#          ✅ Khảo sát sự hài lòng của người dân về sự...
#          ✅ Nâng cao tỷ lệ thực hiện tại chỗ việc ti...
#          ✅ "Năm kỷ cương hành chính" với nhiều kết ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 14: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-14.htm
#          ✅ Người nộp thuế hài lòng với công tác hỗ ...
#          ✅ CCHC: Phải thay đổi từ tư duy, lề lối là...
#          ✅ Giữa tháng 8, có thêm 6 dịch vụ công trự...
#          ✅ Sự đồng tình của người dân là thước đo t...
#          ✅ Hà Nội sẽ quản lý dân cư qua mạng...
#          ✅ Tổ chức tốt ‘Một cửa liên thông’ để thực...
#          ✅ Hà Nội sẽ hành động vì doanh nghiệp...
#          ✅ Thêm 16 dịch vụ công trực tuyến mức độ 3...
#          ✅ Quận Hoàn Kiếm: Triển khai dịch vụ công ...
#          ✅ Ghi nhận về ngày làm việc thứ bảy theo q...
#          ✅ Quận Long Biên thí điểm mô hình khu chun...
#          ✅ Long Biên: Sáng tạo hơn nữa để tiếp tục ...
#          ✅ Chỉ số CCHC của Hà Nội xếp thứ 3 cả nước...
#          ✅ Tích cực hỗ trợ hộ kinh doanh chuyển đổi...
#          ✅ Sở TTTT: Đẩy mạnh ứng dụng CNTT, xây dựn...
#          ✅ Nhiều mô hình sáng tạo trong dịch vụ côn...
#          ✅ Hết tháng 8, Hà Nội số hóa xong dữ liệu ...
#          ✅ Thực hiện tốt việc kết nối dữ liệu dùng ...
#          ✅ Hà Nội có nhiều sáng kiến trong sắp xếp ...
#          ✅ Công bố TTHC thuộc thẩm quyền của Sở TN&...
#          ✅ Phát động cuộc thi "Thủ đô Hà Nội với cô...
#          ✅ Sơ kết triển khai cơ chế một cửa, một cử...
#          ✅ Giải quyết hơn 1,8 nghìn TTHC thuộc thẩm...
#          ✅ Hà Nội chuẩn bị triển khai khám, lập hồ ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 15: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-15.htm
#          ✅ Chương trình công tác của thành phố năm ...
#          ✅ Xác định CNTT là đòn bẩy cải cách hành c...
#          ✅ Hà Nội: Đăng ký khai sinh trực tuyến đạt...
#          ✅ Quốc Oai phấn đấu đi đầu ứng dụng CNTT t...
#          ✅ Hà Nội tập trung nâng cao chỉ số cải các...
#          ✅ Để hành chính gần gũi với dân...
#          ✅ Ngành Y tế thực hiện 2 dịch vụ công trực...
#          ✅ Quận Nam Từ Liêm cần phát huy hiệu quả v...
#          ✅ Hà Nội triển khai giải quyết TTHC qua dị...
#          ✅ Hà Nội phấn đấu thành xuất sắc nhiệm vụ ...
#          ✅ Thí điểm đăng ký xe ô tô qua mạng tại Hà...
#          ✅ Huyện Mê Linh: Tiếp tục đẩy mạnh cải các...
#          ✅ Khai trương hệ thống dịch vụ công trực t...
#          ✅ Giảm đến mức thấp nhất việc thực hiện cá...
#          ✅ Nêu cao tinh thần phục vụ, thực hiện văn...
#          ✅ Năm 2017-Năm bản lề xây dựng Chính phủ đ...
#          ✅ Ưu tiên những dịch vụ công trực tuyến dễ...
#          ✅ Sở Tư pháp: 100% hồ sơ được tiếp nhận và...
#          ✅ Triển khai dịch vụ công mức độ 3,4 lĩnh ...
#          ✅ Tạo đột phá trong năm kỷ cương hành chín...
#          ✅ Nhiều giải pháp ngăn chặn gian lận hóa đ...
#          ✅ Ngành Thuế Thủ đô phấn đấu hoàn thành vư...
#          ✅ Hà Nội tập trung quyết liệt triển khai c...
#          ✅ Thông qua phương án đơn giản hóa 183 thủ...
#       -> Đã lưu 24 bài mới.
#       -> Trang 16: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-16.htm
#          ✅ Rà soát việc thực hiện cơ chế một cửa, m...
#          ✅ Tinh giảm TTHC trong giao đất, cho thuê ...
#          ✅ Tạo mọi điều kiện tối đa cho doanh nghiệ...
#          ✅ Cải cách triệt để TTHC về cấp Giấy chứng...
#          ✅ Bảo đảm kết nối liên thông về chỉ đạo, đ...
#          ✅ Chủ tịch Hà Nội đối thoại nhân dân khu v...
#          ✅ Hải quan Hà Nội công bố đường dây nóng...
#          ✅ Mở rộng sử dụng hóa đơn điện tử có xác t...
#          ✅ Hà Nội liên thông hệ thống QLVB điện tử ...
#          ✅ Tăng cường các giải pháp thu hồi nợ đọng...
#          ✅ Hà Nội phấn đấu hết tháng 6/2017 hoàn th...
#          ✅ Tăng cường các biện pháp đôn đốc, thu hồ...
#          ✅ Xây dựng nền hành chính phục vụ, hiện đạ...
#          ✅ Xử lý “Thuế đọng”: Đồng hành và thúc đẩy...
#          ✅ Hà Nội là trung tâm khởi nghiệp, sáng tạ...
#          ✅ Đồng loạt mở lớp tập huấn miễn phí quyết...
#          ✅ Từ ngày 1/8, Hà Nội cấp sổ đỏ qua mạng...
#          ✅ Xác định CCHC là khâu đột phá trong quản...
#          ✅ Nhiều giải pháp nhằm cải thiện, thu hút ...
#          ✅ Gỡ vướng cho doanh nghiệp, tạo nguồn thu...
#          ✅ Đẩy mạnh đăng ký doanh nghiệp qua mạng đ...
#          ✅ Hà Nội: Bắt đầu nhận hồ sơ quyết toán th...
#       -> Đã lưu 22 bài mới.
#       -> Trang 17: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-17.htm
#          ✅ Làm hộ chiếu tận nơi cho đối tượng chính...
#       -> Đã lưu 0 bài mới.
#       -> Trang 34: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-34.htm
#       -> Đã lưu 0 bài mới.
#       -> Trang 35: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-35.htm
#       -> Đã lưu 0 bài mới.
#       -> Trang 36: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-36.htm
#       -> Đã lưu 0 bài mới.
#       -> Trang 37: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-37.htm
#       -> Đã lưu 0 bài mới.
#       -> Trang 38: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-38.htm
#       -> Đã lưu 0 bài mới.
#       -> Trang 39: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-39.htm
#       -> Đã lưu 0 bài mới.
#       -> Trang 40: https://thanglong.chinhphu.vn/nha-dau-tu/cai-cach-thu-tuc-hanh-chinh/trang-40.htm
#       -> Đã lưu 0 bài mới.

# %% [markdown]
# ### Thu thập dữ liệu từ giaoducthoidai.vn

# %%
import requests
import re
import csv
import time
import html
from bs4 import BeautifulSoup
from typing import Optional, List, Tuple, Dict
from urllib.parse import urljoin

# --- CẤU HÌNH ---
session = requests.Session()
session.headers.update({
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/124.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Referer': 'https://giaoducthoidai.vn/',
})

DOMAIN = 'https://giaoducthoidai.vn'
# Regex: Bắt các link bài viết có dạng ...post12345.html
ARTICLE_URL_RE = re.compile(r'post(\d+)\.html', re.IGNORECASE)

# --- TUỲ CHỈNH ĐỂ CRAWL NHIỀU HƠN ---
MAX_PAGES_PER_LINK = 50      # Tăng lên 50 trang mỗi mục (tương đương ấn xem thêm 50 lần)
STOP_AFTER_EMPTY = 5         # Tăng lên 5: Nếu 5 trang liên tiếp không có bài mới thì mới dừng
SLEEP_BETWEEN_REQUESTS = 0.5 
OUTPUT_FILE = 'giaoducthoidai_full_data.csv'

# --- HÀM TIỆN ÍCH XỬ LÝ TEXT ---
def clean_text(s: str) -> str:
    if not s: return ''
    s = html.unescape(s)
    return re.sub(r'\s+', ' ', s).strip()

def remove_prefix_gdtd(text: str) -> str:
    if not text: return ''
    text = re.sub(r'^GD&TĐ\s*-\s*', '', text, flags=re.IGNORECASE)
    return text.strip()

def normalize_href(href: str, base: str = DOMAIN) -> Optional[str]:
    if not href: return None
    href = href.strip()
    if href.startswith(('javascript:', '#', 'mailto:')): return None
    if href.startswith('//'): return 'https:' + href
    if href.startswith('/'): return urljoin(DOMAIN, href)
    if href.startswith('http'): return href
    return urljoin(base, href)

# --- [QUAN TRỌNG] LOGIC TẠO URL PHÂN TRANG ---
def make_page_url(base: str, page: int) -> str:
    """
    Tạo URL phân trang cho giaoducthoidai.vn
    VD: .../giao-duc/ -> .../giao-duc/?p=2
    """
    if page <= 1: return base
    
    # Xóa tham số p cũ nếu có để tránh trùng (vd: ?p=2&p=3)
    base_clean = re.sub(r'[?&]p=\d+', '', base)
    
    # Kiểm tra xem link gốc đã có tham số nào chưa (?) hay chưa có (&)
    separator = '&' if '?' in base_clean else '?'
    
    return f"{base_clean}{separator}p={page}"

# --- PARSE CHI TIẾT BÀI VIẾT ---
def parse_article(url: str) -> Dict[str, str]:
    result = {
        'title': '', 'summary': '', 'content': '', 'keywords': '',
        'publish_time': '', 'url': url, 'tags': '', 'description': ''
    }
    
    try:
        resp = session.get(url, timeout=15)
        if resp.status_code != 200: return result
        
        resp.encoding = 'utf-8' 
        soup = BeautifulSoup(resp.text, 'html.parser')

        # 1. URL
        meta_url = soup.find('meta', attrs={'name': 'twitter:url'})
        if meta_url: result['url'] = meta_url.get('content', url)

        # 2. Title
        meta_title = soup.find('meta', property='og:title')
        if meta_title: result['title'] = clean_text(meta_title.get('content'))
        
        # 3. Summary
        meta_og_desc = soup.find('meta', property='og:description')
        if meta_og_desc:
            raw_summary = clean_text(meta_og_desc.get('content'))
            result['summary'] = remove_prefix_gdtd(raw_summary)

        # 4. Description
        meta_desc = soup.find('meta', attrs={'name': 'description'})
        if meta_desc: result['description'] = clean_text(meta_desc.get('content'))

        # 5. Keywords
        meta_kw = soup.find('meta', attrs={'name': 'news_keywords'})
        if not meta_kw: meta_kw = soup.find('meta', attrs={'name': 'keywords'})
        if meta_kw: result['keywords'] = clean_text(meta_kw.get('content'))

        # 6. Publish Time
        meta_time = soup.find('meta', property='article:published_time')
        if meta_time: result['publish_time'] = clean_text(meta_time.get('content'))

        # 7. Tags
        meta_tags = soup.find_all('meta', property='article:tag')
        tag_list = [clean_text(t.get('content')) for t in meta_tags if t.get('content')]
        result['tags'] = ', '.join(tag_list)

        # 8. Content
        body = soup.select_one('.article__body.zce-content-body.cms-body')
        
        if body:
            # Xóa tiêu đề con, script, quảng cáo
            for junk in body.find_all(['h1', 'script', 'style', '.relate-news', '.box-ads', '.noted-info', 'figure']):
                junk.decompose()

            paras = body.select('p')
            cleaned_paras = []
            for p in paras:
                txt = clean_text(p.get_text())
                if len(txt) > 2: 
                    cleaned_paras.append(txt)
            
            result['content'] = ' '.join(cleaned_paras)

        return result

    except Exception as e:
        print(f"Lỗi parse: {e}")
        return result

# --- CRAWL UTILS ---
def get_links_extended(url: str) -> List[str]:
    try:
        resp = session.get(url, timeout=15)
        if resp.status_code != 200: return []
        
        soup = BeautifulSoup(resp.text, 'html.parser')
        article_links = set()

        for a in soup.find_all('a', href=True):
            full = normalize_href(a['href'], base=url)
            if not full: continue
            
            # Chỉ lấy link thuộc domain và đúng regex post(\d+).html
            if DOMAIN in full and ARTICLE_URL_RE.search(full):
                # Tránh lấy link trùng với chính trang danh mục (dù regex đã chặn, nhưng cẩn thận)
                if full != url: 
                    article_links.add(full)

        return sorted(list(article_links))
    except Exception:
        return []

# --- MAIN LOGIC ---
def main(topics_dict):
    seen_global = set() # Set chứa tất cả các link đã crawl để tránh trùng lặp
    fieldnames = ['topic', 'title', 'summary', 'description', 'content', 'keywords', 'tags', 'publish_time', 'url']

    with open(OUTPUT_FILE, 'w', newline='', encoding='utf-8-sig') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()

        for topic_name, url_data in topics_dict.items():
            print(f"\n ========== CHỦ ĐỀ: {topic_name} ==========")
            list_urls = [url_data] if isinstance(url_data, str) else list(url_data)

            for sub_url in list_urls:
                print(f"   >>> Quét nhánh: {sub_url}")
                page = 1
                consecutive_empty = 0
                
                while page <= MAX_PAGES_PER_LINK and consecutive_empty < STOP_AFTER_EMPTY:
                    # Tạo URL trang 2, 3...
                    p_url = make_page_url(sub_url, page)
                    print(f"      -> Trang {page}: {p_url}")
                    
                    # Lấy danh sách link trên trang
                    article_links = get_links_extended(p_url)
                    
                    # Lọc ra những link chưa từng gặp
                    new_links = [l for l in article_links if l not in seen_global]
                    
                    if not new_links:
                        print("         (Không tìm thấy link mới hoặc trang trùng lặp).")
                        consecutive_empty += 1
                    else:
                        consecutive_empty = 0 # Reset bộ đếm nếu tìm thấy link mới
                        count_ok = 0
                        
                        for link in new_links:
                            seen_global.add(link)
                            data = parse_article(link)
                            
                            if data['title'] and data['content']:
                                writer.writerow({
                                    'topic': topic_name,
                                    'title': data['title'],
                                    'summary': data['summary'],
                                    'description': data['description'],
                                    'content': data['content'],
                                    'keywords': data['keywords'],
                                    'tags': data['tags'],
                                    'publish_time': data['publish_time'],
                                    'url': data['url']
                                })
                                count_ok += 1
                                print(f"         ✅ {data['title'][:50]}...")
                            
                            time.sleep(0.1) # Delay nhỏ để tránh spam server
                        
                        print(f"      -> Đã lưu {count_ok} bài mới.")
                    
                    page += 1
                    time.sleep(SLEEP_BETWEEN_REQUESTS)
                
                if consecutive_empty >= STOP_AFTER_EMPTY:
                    print(f"      [STOP] Dừng vì {STOP_AFTER_EMPTY} trang liên tiếp không có bài mới.")

    print("\n[FINISH] Hoàn tất crawl. File:", OUTPUT_FILE)

# --- DANH MỤC CỦA GIAODUCTHOIDAI.VN ---
# --- DANH MỤC CỦA GIAODUCTHOIDAI.VN ---
if __name__ == "__main__":
    topics = {
        'Giáo dục': ['https://giaoducthoidai.vn/chinh-sach/',
                     'https://giaoducthoidai.vn/dia-phuong/',
                     'https://giaoducthoidai.vn/tuyen-sinh-du-hoc/',
                     'https://giaoducthoidai.vn/giao-duc-bon-phuong/',
                     'https://giaoducthoidai.vn/chuyen-dong/'],
        'Thời sự': ['https://giaoducthoidai.vn/giao-duc-do-thi/',
                    'https://giaoducthoidai.vn/thoi-su-xa-hoi/',
                    'https://giaoducthoidai.vn/chinh-tri/',
                    'https://giaoducthoidai.vn/kinh-te/'],
        "Giáo dục phát luật": ['https://giaoducthoidai.vn/an-ninh/',
                               'https://giaoducthoidai.vn/phap-dinh/',
                               'https://giaoducthoidai.vn/goc-nhin/'],
        "Kết nối": ['https://giaoducthoidai.vn/cong-doan/',
                    'https://giaoducthoidai.vn/dong-hanh/',
                    'https://giaoducthoidai.vn/khoa-hoc/'],
        "Trao đổi": ['https://giaoducthoidai.vn/phuong-phap/',
                     'https://giaoducthoidai.vn/goc-chuyen-gia/'],
        "Học đường": ['https://giaoducthoidai.vn/ky-nang-song/',
                      'https://giaoducthoidai.vn/du-hoc/',
                      'https://giaoducthoidai.vn/guong-mat/',
                      'https://giaoducthoidai.vn/the-chat/'],
        "Nhân ái": 'https://giaoducthoidai.vn/nhan-ai/',
        "Thế giới": ['https://giaoducthoidai.vn/giao-duc-quoc-phong/',
                     'https://giaoducthoidai.vn/the-gioi-do-day/',
                     'https://giaoducthoidai.vn/chuyen-la/'],
        "Sức khỏe": ['https://giaoducthoidai.vn/khoe-dep/',
                     'https://giaoducthoidai.vn/gia-dinh/',
                     'https://giaoducthoidai.vn/day-lui-covid/'],
        "Văn hóa": ['https://giaoducthoidai.vn/sang-tac/',
                    'https://giaoducthoidai.vn/doi-song-van-hoa/',
                    'https://giaoducthoidai.vn/the-gioi-sao/'],
        "Thể thao": 'https://giaoducthoidai.vn/the-thao-hoc-duong/'
    }
    
    main(topics)
# Out:
#  ========== CHỦ ĐỀ: Giáo dục ==========
#    >>> Quét nhánh: https://giaoducthoidai.vn/chinh-sach/
#       -> Trang 1: https://giaoducthoidai.vn/chinh-sach/
#          ✅ 8 nhóm nội dung được tiếp thu hoàn thiện Luật Giáo...
#          ✅ Bước tiến rõ rệt từ chính sách dành cho giáo viên,...
#          ✅ Chính sách đột phá, thí điểm học vượt cấp, vượt lớ...
#          ✅ Chính sách giáo dục có hiệu lực từ tháng 1 năm 202...
#          ✅ Công tác pháp chế giáo dục: Khơi thông nguồn lực, ...
#          ✅ Đắk Lắk: Khi chính sách giáo dục gắn với trách nhi...
#          ✅ Đào tạo nhân lực chất lượng cao người DTTS: Xung l...
#          ✅ Đặt tên cơ sở giáo dục đại học và phân hiệu: Chuẩn...
#          ✅ Đột phá chính sách đãi ngộ nhà giáo: Đòn bẩy để gi...
#          ✅ Đột phá giáo dục và đào tạo TPHCM từ Nghị quyết 71...
#          ✅ Dự kiến xét đặc cách thăng tiến nhà giáo: 'Cởi tró...
#          ✅ Kỳ vọng vào những đổi thay...
#          ✅ Linh hoạt cho trường học, tăng giám sát xã hội quả...
#          ✅ Minh bạch 'chương trình liên kết' để chấm dứt áp l...
#          ✅ Nâng phụ cấp nghề 70% với giáo viên, 30% với nhân ...
#          ✅ Những chính sách 'chạm' vào bục giảng...
#          ✅ Phổ cập giáo dục mầm non cho trẻ 3 - 5 tuổi: Đầu t...
#          ✅ Phụ cấp độc hại cho nhà giáo dạy nghề: Nhiều kỳ vọ...
#          ✅ Quốc hội thông qua Chương trình MTQG về nâng cao c...
#          ✅ Quốc hội thông qua dự thảo Luật Giáo dục đại học (...
#          ✅ Quy định chuyển sang hạng II mới với giáo viên THC...
#          ✅ Quy định xét chuyển sang chức danh nghề nghiệp giá...
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/dia-phuong/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/dia-phuong/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/dia-phuong/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/dia-phuong/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#    >>> Quét nhánh: https://giaoducthoidai.vn/tuyen-sinh-du-hoc/
#       -> Trang 1: https://giaoducthoidai.vn/tuyen-sinh-du-hoc/
#          ✅ Bộ GD&ĐT phản hồi về lọt thông tin đề thi trong gi...
#          ✅ Bộ trưởng Nguyễn Kim Sơn chúc thí sinh cả nước 'vư...
#          ✅ Chuẩn bị nguồn nhân lực chất lượng cao trong lĩnh ...
#          ✅ Chuẩn bị nhân lực cho các ngành đặc thù: Nền tảng ...
#          ✅ Cử nhân nông nghiệp 4.0: Khi 'tấm bằng đỏ' không n...
#          ✅ Đại học số cần hành lang pháp lý mạnh để bứt phá...
#          ✅ Đánh giá năng lực thí sinh năm 2026: Công bằng, kh...
#          ✅ Đào tạo tiến sĩ: 'Gạn đục khơi trong'...
#          ✅ Định hướng công tác tuyển sinh đại học chính quy 2...
#          ✅ Đổi mới để không bị đào thải...
#          ✅ Đột phá từ đầu tư để hình thành đại học xuất sắc...
#          ✅ Học sinh Trường Quốc tế Singapore đạt thủ khoa thế...
#          ✅ Học viện Kỹ thuật Quân sự trao bằng tốt nghiệp cho...
#          ✅ Hơn 501 nghìn thí sinh xác nhận nhập học trực tuyế...
#          ✅ Hướng tới công bằng, chất lượng và minh bạch trong...
#          ✅ Kỳ thi V-SAT năm 2026 Đại học Cần Thơ tổ chức 7 đợ...
#          ✅ Nền tảng cải tiến và nâng cao chất lượng đào tạo...
#          ✅ Ngôi trường đầu ngành đào tạo giáo viên nghệ thuật...
#          ✅ Sáp nhập cao đẳng sư phạm vào đại học: Tinh gọn hệ...
#          ✅ Sắp xếp lại hệ thống giáo dục đại học: Kiến tạo nề...
#          ✅ Siết mở ngành Y - Luật: Không thể quản lý bằng… tê...
#          ✅ Trả lại vai trò cho bộ môn...
#          ✅ Trung học nghề: Đẩy mạnh phân luồng nâng tầm giá t...
#          ✅ Trường Đại học Kinh tế - Tài chính TPHCM dự kiến m...
#          ✅ Trường Đại học Mở TPHCM công bố tuyển sinh 2026, q...
#          ✅ Trường Đại học Tây Nguyên có 14 cựu sinh viên trún...
#          ✅ Trường Đại học Văn Lang lần đầu bổ sung phương thứ...
#          ✅ Trường THCS & THPT Trí Đức tổ chức thi thử IELTS l...
#          ✅ Trường Tiểu học Lê Đình Chinh (P. Hòa Cường, TP Đà...
#          ✅ Tuyển sinh bằng V-SAT cho kết quả tích cực tại trư...
#       -> Đã lưu 30 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/tuyen-sinh-du-hoc/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/giao-duc-bon-phuong/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/giao-duc-bon-phuong/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#    >>> Quét nhánh: https://giaoducthoidai.vn/chuyen-dong/
#       -> Trang 1: https://giaoducthoidai.vn/chuyen-dong/
#          ✅ 5 năm kiến tạo thể chế, mở đường cho phát triển độ...
#          ✅ Bộ GD&ĐT: 4 nhóm nhiệm vụ, giải pháp triển khai hi...
#          ✅ Bộ GD&ĐT lên tiếng về thông tin xuyên tạc nội dung...
#          ✅ Bộ GD&ĐT lưu ý, làm rõ 3 vấn đề trong chuyển đổi s...
#          ✅ Bộ GD&ĐT tổng kết công tác pháp chế năm 2025...
#          ✅ Các cơ sở giáo dục tích cực góp sức cho công tác b...
#          ✅ Dự kiến một số sửa đổi trong Quy chế thi tốt nghiệ...
#          ✅ Đưa tiếng Anh trở thành ngôn ngữ thứ hai trong trư...
#          ✅ Giáo sư Toán duy nhất năm 2025 được bổ nhiệm tại T...
#          ✅ Hoàn thành chu kỳ triển khai CTGDPT 2018: Nền tảng...
#          ✅ Ký kết Hiệp định tài chính Dự án 'Chương trình giá...
#          ✅ Nắm bắt cơ hội, phát huy tối đa lợi thế từ thể chế...
#          ✅ Nâng cao chất lượng giảng dạy GDQPAN trong các cơ ...
#          ✅ Nâng cao hiệu quả phối hợp công tác pháp chế giữa ...
#          ✅ Nghị định 73 tạo động lực, nâng chất thi đua...
#          ✅ Nóng trong tuần: 10 kết quả GD-ĐT nổi bật; ngành G...
#          ✅ Phê duyệt bộ sách giáo khoa sử dụng thống nhất toà...
#          ✅ Rõ nét đột phá về phát triển nguồn nhân lực...
#          ✅ 'Startup Kite' thắp lửa khởi nghiệp sinh viên Tây ...
#          ✅ Tăng vai trò điểm học bạ: Yêu cầu cao hơn về tính ...
#          ✅ Thành tích vượt trội của học sinh Việt Nam tại các...
#          ✅ Tháo gỡ ‘nút thắt’ để thu hút các trường đại học v...
#          ✅ Thống nhất bộ sách giáo khoa trong toàn quốc: Khôn...
#          ✅ Thống nhất bộ SGK: Chủ động triển khai, giữ vững c...
#          ✅ Tiếng nói người trẻ trước Ngày hội non sông...
#          ✅ Tỉnh Hưng Yên cam kết hỗ trợ dự án xây dựng Cơ sở ...
#          ✅ Trang bị năng lực số cho giáo viên: Yêu cầu của th...
#          ✅ Trao quyết định bổ nhiệm nữ Giám đốc đầu tiên của ...
#          ✅ Triết lý giáo dục thời đại số phải đi sâu nghiên c...
#          ✅ Xây dựng cơ chế, chính sách đột phá nhằm đào tạo, ...
#          ✅ Xúc tiến ký kết hợp tác với Vương quốc Tây Ban Nha...
#       -> Đã lưu 31 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/chuyen-dong/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/chuyen-dong/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/chuyen-dong/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/chuyen-dong/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/chuyen-dong/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#
#  ========== CHỦ ĐỀ: Thời sự ==========
#    >>> Quét nhánh: https://giaoducthoidai.vn/giao-duc-do-thi/
#       -> Trang 1: https://giaoducthoidai.vn/giao-duc-do-thi/
#          ✅ Bất động sản cuối năm: Có khởi sắc?...
#          ✅ 'Bẫy suất ngoại giao' nhà ở xã hội: Khi giấc mơ an...
#          ✅ Cà Mau khởi công dự án nhà ở xã hội gần 1.000 căn...
#          ✅ Có thể miễn giấy phép xây dựng tại khu vực đã có q...
#          ✅ ‘Cởi trói' thủ tục đất đai, nhà đầu tư cần lưu ý g...
#          ✅ Đã truy tố 141 vụ với 655 bị cáo về tội liên quan ...
#          ✅ Dấu hỏi về 'đất vàng' nội đô Hà Nội sau khi bộ, ng...
#          ✅ Đẩy mạnh số hóa trong quản lý quy hoạch và kiến tr...
#          ✅ Đồng Nai tháo dỡ tổ hợp Eros Palace Luxury xây khô...
#          ✅ Dự kiến chuyển toàn bộ đường bay quốc tế từ Tân Sơ...
#          ✅ Giải ngân gần 20.000 tỷ đồng cho nhà ở xã hội...
#          ✅ Hà Nội: 7,5ha đất Long Biên dành xây nhà ở xã hội...
#          ✅ Hà Nội đề xuất tăng giá đất: Thị trường biến động ...
#          ✅ Hà Nội mở bán loạt dự án nhà ở xã hội: Giá từ 824 ...
#          ✅ Hà Nội 'mở đường' xây trường học...
#          ✅ Hà Nội sẽ 'mạnh tay' thu hồi các dự án 'treo'...
#          ✅ Hà Nội, TPHCM phát triển giao thông thông minh: Xu...
#          ✅ Huế hoàn thiện Đề án thành lập thành phố trực thuộ...
#          ✅ Loạt dự án giao thông khởi công, khánh thành dịp 2...
#          ✅ Minh bạch giá bất động sản: Cần biện pháp 'gỡ rối'...
#          ✅ Phát động Giải thưởng Quốc gia Bất động sản Việt N...
#          ✅ Quỹ nhà ở quốc gia: Mở cửa giấc mơ an cư...
#          ✅ Rà soát quy hoạch, kết nối sân bay Đà Nẵng – Chu L...
#          ✅ Siết cho vay mua nhà thứ 2 trở lên: 'Hạ nhiệt' the...
#          ✅ Sửa Luật Xây dựng: Tháo gỡ điểm nghẽn, kiểm soát đ...
#          ✅ Thị trường bất động sản cuối năm: Nguồn cung tăng,...
#          ✅ TPHCM dành đất 'vàng' làm công viên: Mở rộng không...
#          ✅ TPHCM được công nhận là thành viên Mạng lưới Thành...
#          ✅ TPHCM: 'Siết' cho thuê căn hộ chung cư ngắn ngày...
#       -> Đã lưu 29 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/giao-duc-do-thi/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/giao-duc-do-thi/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/giao-duc-do-thi/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/giao-duc-do-thi/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/giao-duc-do-thi/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#
#          ✅ Công tác đấu thầu tại Sở Xây dựng Bắc Ninh...
#          ✅ Đà Nẵng: Nhà đầu tư gặp khó sau hàng chục năm chậm...
#          ✅ Đà Nẵng: Phụ huynh phản ứng vì con phải ghép lớp b...
#          ✅ Dấu hiệu bất thường tại các cơ sở khám bệnh ở Bắc ...
#          ✅ Dấu hiệu thiếu minh bạch ở gói thầu Carnaval Hạ Lo...
#          ✅ Dấu hiệu vi phạm đấu thầu ở TP Hạ Long: Sẽ chuyển ...
#          ✅ Điện Biên: Chính quyền vào cuộc sau phản ánh bữa ă...
#          ✅ Hà Nội kiểm tra bãi trông giữ xe trước cổng Bệnh v...
#          ✅ Hà Nội: Thẩm mỹ Lani hoạt động không phép...
#          ✅ HDBank Cà Mau liên quan thế nào trong vụ án tín dụ...
#          ✅ Hiệu trưởng thẳng thắn nhận trách nhiệm...
#          ✅ Kon Tum: Dân khốn đốn vì bãi rác quá tải...
#          ✅ Lâm Đồng: Phụ huynh 'dậy sóng' vì lo thực phẩm bẩn...
#          ✅ Nhóm Lion Team của 'thầy' Hồ Ngọc Phương đang bị đ...
#          ✅ Phụ huynh ‘tố’ trường học ở Ba Vì không đóng bảo h...
#          ✅ Phú Thọ: Xử lý, buộc di dời xưởng sản xuất giấy kh...
#          ✅ Quảng Trị: Đường sử dụng chưa lâu đã... "nát như t...
#          ✅ Rừng phòng hộ hàng chục năm tuổi ở Quảng Trị bị đố...
#          ✅ Sở Y tế Bắc Ninh thông tin về dấu hiệu sai phạm tạ...
#          ✅ Sự thật không thể phủ nhận!...
#          ✅ Thanh Hóa: Kết thúc năm vẫn chưa có đồ dùng học tậ...
#          ✅ Thanh Hóa: Vì sao giáo viên biệt phái chưa được nh...
#          ✅ TPHCM: Trường Tiểu học Quốc tế Fosco đã được cấp p...
#          ✅ Trường THCS Võ Thị Sáu (Lê Chân, Hải Phòng): Dấu h...
#          ✅ Vĩnh Phúc: Dân kêu cứu vì bị đe dọa sau khi "tố" s...
#          ✅ Xác định hành vi đổ trộm đất thải từ Dự án Đường T...
#          ✅ Xe chở khách tuyến Hà Nội – Sơn La bán vé giường đ...
#       -> Đã lưu 30 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/goc-nhin/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/goc-nhin/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/goc-nhin/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/goc-nhin/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/goc-nhin/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#
#  ========== CHỦ ĐỀ: Kết nối ==========
#    >>> Quét nhánh: https://giaoducthoidai.vn/cong-doan/
#       -> Trang 1: https://giaoducthoidai.vn/cong-doan/
#          ✅ 1.000 ly sữa được trao cho trẻ em khó khăn, bị ảnh...
#          ✅ Báo Giáo dục và Thời đại tổ chức Hội nghị viên chứ...
#          ✅ CĐGDVN thăm, hỗ trợ các thầy cô giáo bị ảnh hưởng ...
#          ✅ Công đoàn ĐH Đà Nẵng đồng hành cùng đổi mới và phá...
#          ✅ Công đoàn Giáo dục Việt Nam gặp mặt nữ giảng viên ...
#          ✅ Công đoàn Giáo dục Việt Nam triển khai nhiệm vụ tr...
#          ✅ Công đoàn khẳng định vai trò trong quá trình tái c...
#          ✅ Công đoàn phải tiếp tục khẳng định vai trò đại diệ...
#          ✅ Công đoàn tỉnh An Giang tập trung thực hiện tốt 3 ...
#          ✅ Công đoàn Trường ĐH Cửu Long thực hiện nhiều phần ...
#          ✅ Công đoàn Trường ĐH Kiên Giang xác định 5 nhóm nhi...
#          ✅ Công đoàn Trường ĐH Sư phạm: Điểm tựa vững chắc ch...
#          ✅ Công đoàn VDB đồng hành cùng hệ thống trong giai đ...
#          ✅ Công đoàn VDB - VCN Đà Nẵng thăm và tặng quà học s...
#          ✅ Đại hội Công đoàn Báo Giáo dục và Thời đại lần thứ...
#          ✅ Đại hội Công đoàn Giáo dục Việt Nam nhiệm kỳ 2025-...
#          ✅ Đại hội Công đoàn Học viện Quản lý giáo dục...
#          ✅ Đại hội Công đoàn Trường ĐH Kinh doanh và Công ngh...
#          ✅ Đổi mới hoạt động CĐGDVN: Từ chăm lo trực tiếp đến...
#          ✅ Đổi mới hoạt động vì lợi ích viên chức, người lao ...
#          ✅ Đổi mới tư duy, nâng tầm vị thế, hướng tới Đại học...
#          ✅ EVNGENCO1 hưởng ứng Tuần lễ hồng EVN lần thứ XI...
#          ✅ Hội thảo khoa học '80 năm nền giáo dục cách mạng V...
#          ✅ Hơn 500 nhà giáo tranh tài tại Giải Pickleball lớn...
#          ✅ Quảng Trị: Tôn tạo khu tưởng niệm Anh hùng, Liệt s...
#          ✅ Trường ĐH Công đoàn tổ chức Đại hội lần thứ XXVIII...
#          ✅ Tuyên dương điển hình tiên tiến trong các phong tr...
#          ✅ VDB Gia Lai thăm hỏi, hỗ trợ NLĐ và cán bộ hưu trí...
#          ✅ Xúc động những hình ảnh về thầy cô giáo trong mắt ...
#       -> Đã lưu 29 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/cong-doan/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/cong-doan/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/cong-doan/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/cong-doan/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/cong-doan/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#    >>> Quét nhánh: https://giaoducthoidai.vn/dong-hanh/
#       -> Trang 1: https://giaoducthoidai.vn/dong-hanh/
#          ✅ 300 chuyên gia quốc tế quy tụ tại Đà Nẵng thảo luậ...
#          ✅ 338 tân tiến sĩ, thạc sĩ và cử nhân Trường ĐH Ngoạ...
#          ✅ Bàn giải pháp gắn di sản văn hóa với phát triển du...
#          ✅ Báo GD&TĐ cùng Trường ĐH Kiên Giang tăng cường hợp...
#          ✅ Báo Giáo dục và Thời đại nhận Bằng khen của Bộ trư...
#          ✅ Báo Giáo dục và Thời đại nhận Cờ thi đua của Bộ GD...
#          ✅ Báo Thanh Niên kỷ niệm 40 năm ngày phát hành số đầ...
#          ✅ Hành trình biến củ hành tím thành nước mắm chay củ...
#          ✅ Học viện Kỹ thuật quân sự phát động Cuộc thi Sáng ...
#          ✅ ICTU Nâng cao chất lượng giáo dục theo tinh thần N...
#          ✅ ICTU tiên phong đào tạo bán dẫn vi mạch và trí tuệ...
#          ✅ 'Mật ong điên' say ngất cả gấu...
#          ✅ Ngành giáo dục 'hứng chịu' nhiều vụ tấn công mạng ...
#          ✅ Nhà giáo nhân dân và học sinh được vinh danh tại N...
#          ✅ Nhiều giáo sư Toán học nổi tiếng tụ hội tại sự kiệ...
#          ✅ Nhịp cầu tri thức từ những tiết học trực tuyến...
#          ✅ Phao cứu sinh điều khiển từ xa, sẵn sàng cứu người...
#          ✅ Phim trường số kết nối đào tạo, công nghệ và sáng ...
#          ✅ Phó Giáo sư miền Tây nghiên cứu phao xi măng lưới ...
#          ✅ Sinh viên tạo bột dinh dưỡng từ bèo tấm...
#          ✅ Thu giữ CO2 từ cảm hứng quang hợp...
#          ✅ Trung tâm dữ liệu trong không gian: Tương lai của ...
#          ✅ Trường ĐH Kỹ thuật - Công nghệ Cần Thơ kết nối đổi...
#          ✅ Trường vùng cao thích ứng cùng AI...
#          ✅ Ứng dụng AI trong dạy học: Cần khung năng lực chuẩ...
#          ✅ Việt Nam chủ động phát triển ngành Công nghiệp bán...
#          ✅ Vinh danh và trao giải Cuộc thi Trí tuệ nhân tạo V...
#       -> Đã lưu 30 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/khoa-hoc/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/khoa-hoc/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/khoa-hoc/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/khoa-hoc/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/khoa-hoc/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#
#  ========== CHỦ ĐỀ: Trao đổi ==========
#    >>> Quét nhánh: https://giaoducthoidai.vn/phuong-phap/
#       -> Trang 1: https://giaoducthoidai.vn/phuong-phap/
#          ✅ 5 bài học từ kết quả học sinh Việt Nam dự thi Olym...
#          ✅ AI và quản trị số 'cú hích' trường học chuyển mình...
#          ✅ 'Chìa khóa' giữ học sinh ở lại trường...
#          ✅ Chuẩn bị hành trang từ trường sư phạm giúp giáo vi...
#          ✅ Chuyên gia 'gợi mở' kiến tạo hệ sinh thái an toàn ...
#          ✅ Để thí điểm hiệu quả nội dung giáo dục trí tuệ nhâ...
#          ✅ Đề Tiếng Anh thi vào lớp 10 Hà Nội khơi mở năng lự...
#          ✅ Đề xuất cấu trúc kế hoạch bài dạy cô đọng, linh ho...
#          ✅ Dùng AI ‘thổi hồn’ vào trang sách, làm mới giờ học...
#          ✅ Giải pháp bảo đảm tính khách quan, công bằng trong...
#          ✅ Giải pháp giúp giáo viên triển khai tốt chương trì...
#          ✅ Giảng viên thời 4.0: Công nghệ trở thành đồng nghi...
#          ✅ Giáo viên dự kiến phổ điểm Tiếng Anh trong kỳ thi ...
#          ✅ Giúp trẻ phát triển tình cảm và kỹ năng xã hội...
#          ✅ Hải Phòng dạy học lồng ghép biến đổi khí hậu trong...
#          ✅ Học sinh Hải Phòng hào hứng với giờ học Lịch sử và...
#          ✅ Khơi gợi cảm xúc, tư duy sáng tạo trong đề thi Ngữ...
#          ✅ Khung chương trình thí điểm dạy trí tuệ nhân tạo (...
#          ✅ Kinh nghiệm thực tiễn bồi dưỡng đội tuyển học sinh...
#          ✅ Lan tỏa Truyện Kiều trong học đường: Mạch nguồn kh...
#          ✅ Lồng ghép sửa lỗi phát âm L-N trong phát triển ngô...
#          ✅ Mang 'hơi thở' cuộc sống vào bài giảng...
#          ✅ Ngành Giáo dục Lào khảo sát, chia sẻ kinh nghiệm t...
#          ✅ Những mô hình hướng nghiệp hiệu quả trong trường T...
#          ✅ Những nhà giáo đam mê AI...
#          ✅ 'Sáng tạo với AI trong giáo dục' - đòn bẩy chất lư...
#          ✅ Sinh hoạt tổ chuyên môn theo cụm trường thích ứng ...
#          ✅ Sức hấp dẫn của ngôn từ văn học...
#          ✅ Ứng dụng AI sáng tạo giúp trò vùng cao hứng thú họ...
#          ✅ Vận dụng kỹ thuật mảnh ghép trong dạy học môn Toán...
#       -> Đã lưu 30 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/phuong-phap/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/phuong-phap/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/phuong-phap/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/phuong-phap/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/phuong-phap/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#    >>> Quét nhánh: https://giaoducthoidai.vn/goc-chuyen-gia/
#       -> Trang 1: https://giaoducthoidai.vn/goc-chuyen-gia/
#          ✅ AI đang tái định nghĩa nghề dạy học...
#          ✅ Cách tiếp cận lịch sử trong sách giáo khoa mới...
#          ✅ Cần tư duy đột phá cho giáo dục phổ thông trong ch...
#          ✅ Cấp thiết đổi mới đào tạo luật...
#          ✅ Chiếc mũ 'học sinh' đặt ở vị trí nào?...
#          ✅ Chuyển đổi số và phát triển bền vững định hình kin...
#          ✅ Cứ 5 thanh thiếu niên Việt Nam có 1 em gặp khó khă...
#          ✅ Đào tạo sư phạm trong kỷ nguyên AI...
#          ✅ Đào tạo truyền thông trong bối cảnh AI và chuyển đ...
#          ✅ Để chuẩn nghề nghiệp giảng viên trở thành công cụ ...
#          ✅ Gắn đào tạo với thực tiễn nhằm nâng cao chất lượng...
#          ✅ Giáo dục không phải là 'làm thay'...
#          ✅ Hạnh phúc học đường cần cả hệ sinh thái giáo dục v...
#          ✅ Hỗ trợ chuyên môn giúp giáo viên triển khai hiệu q...
#          ✅ Làm rõ một số vấn đề có tính triết lý trong chính ...
#          ✅ Ngành xã hội học đang mở rộng không gian việc làm ...
#          ✅ Những điều chỉnh cần thiết trong quy định về dạy t...
#          ✅ Tác động đa chiều khi công khai danh mục và mức th...
#          ✅ Tạo cơ chế đột phá thu hút chuyên gia, nhà khoa họ...
#          ✅ Hơn 1 triệu người ở TPHCM có nguy cơ với Covid-19...
#          ✅ Khoảng 20% bệnh nhân nặng, người cao tuổi điều trị...
#          ✅ Không còn điều trị miễn phí khi Covid-19 chuyển sa...
#          ✅ Nâng cao tỷ lệ tiêm vắc xin Covid-19 cho học sinh ...
#          ✅ Nguyên nhân nhiều học sinh ở TPHCM sốt, tiêu chảy,...
#          ✅ Những điều cần biết về hậu Covid-19 ở trẻ...
#          ✅ Phát hiện biến thể phụ JN.1 ở người mắc Covid-19 t...
#          ✅ Sốt xuất huyết vào mùa ở ĐBSCL, nhiều ca bệnh nặng...
#          ✅ Tăng cường triển khai tiêm vắc xin Covid-19 cho tr...
#          ✅ Tháng cao điểm tiêm vắc xin Covid-19 cho trẻ em tạ...
#          ✅ Thành phố Hồ Chí Minh kéo dài đợt cao điểm tiêm vắ...
#          ✅ Trong bối cảnh biến thể BA.4 và B.A5, tiêm vắc xin...
#          ✅ Vòng tay cảm biến phát hiện Covid-19 trước khi có ...
#       -> Đã lưu 27 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/day-lui-covid/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/day-lui-covid/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/day-lui-covid/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/day-lui-covid/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/day-lui-covid/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#
#  ========== CHỦ ĐỀ: Văn hóa ==========
#    >>> Quét nhánh: https://giaoducthoidai.vn/sang-tac/
#       -> Trang 1: https://giaoducthoidai.vn/sang-tac/
#          ✅ ‘100 chuyện nghề’: Lát cắt chân thực, xúc động về ...
#          ✅ Cách mạng Tháng Tám 1945: Khi toàn dân tộc quyết ‘...
#          ✅ Café ngày mới: Hạnh phúc là nhà!...
#          ✅ Cafe ngày mới: Vẻ đẹp vĩnh cửu...
#          ✅ Chiếc hộp gỗ của mẹ...
#          ✅ Học trò ơi, sắp khai giảng rồi!...
#          ✅ Khoán thủ trong “Nghĩa Mẹ, công Cha”...
#          ✅ Khơi nguồn động lực cho tiểu thuyết Việt Nam hiện ...
#          ✅ Người lính trong tim con...
#          ✅ Nụ cười của nắng...
#          ✅ Sống lại một trời ấu thơ...
#          ✅ 'Tấm lòng với Đất nước' của nguyên Phó Chủ tịch nư...
#          ✅ Tản mạn chuyện… thẩm thơ...
#          ✅ Thảo... 'Lai'...
#          ✅ Thiêng liêng tiếng trống khai trường!...
#          ✅ Truyện ngắn: Xứng đôi...
#          ✅ Từ trang sách: Bằng chứng của tình phụ tử...
#          ✅ Từ trang sách đến ký ức bất tử về 81 ngày đêm Thàn...
#          ✅ Từ trang sách: Hành trang tinh thần quý giá...
#          ✅ Từ trang sách: Học hỏi tinh thần sáng tạo từ cha ô...
#          ✅ Từ trang sách: Mở những điều ấm áp cho trẻ thơ...
#          ✅ 'Về diễn họa, Việt Nam không thua quốc gia nào'...
#          ✅ ‘Vu Lan báo hiếu’ - Khúc hoan ca đạo hiếu và khoán...
#          ✅ Vùng trời quê hương...
#       -> Đã lưu 24 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/sang-tac/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang
#          ✅ Bế mạc Giải Bóng rổ học sinh Tiểu học Hà Nội lần t...
#          ✅ Cô gái S’tiêng viết nên mùa vàng Vovinam Việt Nam...
#          ✅ Công bố Giải Cờ vua Cúp Báo Giáo dục và Thời đại 2...
#          ✅ Gần 200 giảng viên, sinh viên lập kỷ lục Việt Nam ...
#          ✅ Giải bóng chuyền nam ngành Giáo dục Quảng Trị - La...
#          ✅ Giải chạy học sinh 'S-Race 2025' thu hút hàng nghì...
#          ✅ Giải Pickleball ngành Giáo dục, thúc đẩy phong trà...
#          ✅ GMB League 2025: Sân chơi bóng rổ chuyên nghiệp ch...
#          ✅ Hành trình vượt núi ra thế giới của vận động viên ...
#          ✅ Khai mạc Đại hội Thể dục Thể thao ngành Giáo dục Đ...
#          ✅ Khai mạc giải bóng đá nam sinh viên toàn quốc năm ...
#          ✅ Khai mạc Giải bóng đá truyền thống sinh viên Trườn...
#          ✅ Khai mạc Vòng Chung kết Giải Bóng rổ học sinh Tiểu...
#          ✅ Khối phòng GD&ĐT huyện Lục Nam dẫn đầu giải thể th...
#          ✅ Lần đầu tiên giải Muay vô địch châu Á diễn ra tại ...
#          ✅ Lan tỏa tinh thần thể thao tại giải bóng chuyền si...
#          ✅ Nestlé MILO cùng dàn sao Việt đưa màn đồng diễn Vo...
#          ✅ Ngành GD Quảng Trị tổ chức Giải bóng chuyền chào m...
#          ✅ Ra mắt Vietnam Pickleball Open Cup Future Stars 20...
#          ✅ Sở GD&ĐT Hưng Yên gặp mặt, động viên học sinh dự W...
#          ✅ Sôi động Giải bóng đá Futsal dành cho học sinh tiể...
#          ✅ Sôi nổi vòng Chung kết Giải bóng đá nam sinh viên ...
#          ✅ Tôn vinh đội vô địch Giải bóng đá Thanh niên Sinh ...
#          ✅ Trường Đại học Luật, Đại học Huế vô địch Giải bóng...
#       -> Đã lưu 30 bài mới.
#       -> Trang 2: https://giaoducthoidai.vn/the-thao-hoc-duong/?p=2
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 3: https://giaoducthoidai.vn/the-thao-hoc-duong/?p=3
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 4: https://giaoducthoidai.vn/the-thao-hoc-duong/?p=4
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 5: https://giaoducthoidai.vn/the-thao-hoc-duong/?p=5
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       -> Trang 6: https://giaoducthoidai.vn/the-thao-hoc-duong/?p=6
#          (Không tìm thấy link mới hoặc trang trùng lặp).
#       [STOP] Dừng vì 5 trang liên tiếp không có bài mới.
#
# [FINISH] Hoàn tất crawl. File: giaoducthoidai_full_data.csv

# %% [markdown]
# ### Thu thập dữ liệu từ mst.gov.vn

# %%
import requests
import re
import csv
import time
import html
from bs4 import BeautifulSoup
from typing import Optional, List, Tuple, Dict
from urllib.parse import urljoin

# --- CẤU HÌNH ---
session = requests.Session()
session.headers.update({
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/124.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Referer': 'https://mst.gov.vn/',
})

DOMAIN = 'https://mst.gov.vn'
# Regex bắt các link bài viết (đuôi .htm)
ARTICLE_URL_RE = re.compile(r'.*\.htm$', re.IGNORECASE)

# --- TUỲ CHỈNH ---
MAX_PAGES_PER_LINK = 40       # Số trang muốn quét mỗi mục
STOP_AFTER_EMPTY = 3        
SLEEP_BETWEEN_REQUESTS = 1.0 
OUTPUT_FILE = 'mst_gov_data.csv'

# --- HÀM TIỆN ÍCH XỬ LÝ TEXT ---
def clean_text(s: str) -> str:
    """Xóa ký tự lạ, decode HTML và đưa về 1 dòng"""
    if not s: return ''
    s = html.unescape(s)
    return re.sub(r'\s+', ' ', s).strip()

def normalize_href(href: str, base: str = DOMAIN) -> Optional[str]:
    if not href: return None
    href = href.strip()
    if href.startswith(('javascript:', '#', 'mailto:')): return None
    if href.startswith('//'): return 'https:' + href
    if href.startswith('/'): return urljoin(DOMAIN, href)
    if href.startswith('http'): return href
    return urljoin(base, href)

# --- THAY ĐỔI CHÍNH Ở ĐÂY ---
def make_page_url(base: str, page: int) -> str:
    """
    Chuyển đổi URL sang dạng phân trang:
    Page 1: .../doi-moi-sang-tao.htm
    Page 2: .../doi-moi-sang-tao/trang-2.htm
    """
    if page <= 1: 
        return base
    
    # 1. Bỏ đuôi .htm hoặc .html ở cuối base url
    base_no_ext = re.sub(r'\.html?$', '', base, flags=re.IGNORECASE)
    
    # 2. Ghép thêm /trang-{page}.htm
    return f"{base_no_ext}/trang-{page}.htm"

# --- PARSE CHI TIẾT BÀI VIẾT ---
def parse_article(url: str) -> Dict[str, str]:
    result = {
        'title': '', 'summary': '', 'content': '', 'keywords': '',
        'publish_time': '', 'url': url, 'tags': '', 'description': ''
    }
    
    try:
        resp = session.get(url, timeout=20)
        if resp.status_code != 200: return result
        
        resp.encoding = 'utf-8' 
        soup = BeautifulSoup(resp.text, 'html.parser')

        # 1. URL (rel="canonical")
        link_canonical = soup.find('link', attrs={'rel': 'canonical'})
        if link_canonical:
            result['url'] = link_canonical.get('href', url)

        # 2. Title (ưu tiên lấy thẻ h1 nếu có)
        div_title = soup.find(class_='btn-group')
        if div_title:
            header_tag = div_title.find(['h1', 'h2', 'h3'])
            if header_tag:
                result['title'] = clean_text(header_tag.get_text())
            else:
                result['title'] = clean_text(div_title.get_text())
        
        if not result['title']:
            meta_title = soup.find('meta', property='og:title')
            if meta_title: result['title'] = clean_text(meta_title.get('content'))

        # 3. Summary
        meta_og_desc = soup.find('meta', property='og:description')
        if meta_og_desc:
            result['summary'] = clean_text(meta_og_desc.get('content'))

        # 4. Description
        meta_desc = soup.find('meta', attrs={'name': 'description'})
        if meta_desc:
            result['description'] = clean_text(meta_desc.get('content'))

        # 5. Keywords
        meta_kw = soup.find('meta', attrs={'name': 'news_keywords'})
        if not meta_kw:
            meta_kw = soup.find('meta', attrs={'name': 'keywords'})
        if meta_kw:
            result['keywords'] = clean_text(meta_kw.get('content'))

        # 6. Public Time
        time_tag = soup.find(attrs={'data-role': 'publishdate'})
        if time_tag:
            result['publish_time'] = clean_text(time_tag.get_text())

        # 7. Content
        body = soup.select_one('.detail-content.afcbc-body')
        
        if body:
            for junk in body.select('script, style, .relate-news, .box-ads'):
                junk.decompose()

            cleaned_paras = []
            paras = body.select('p')
            
            for p in paras:
                if p.find('strong'): continue # Bỏ qua thẻ in đậm
                
                txt = clean_text(p.get_text())
                if len(txt) > 2: 
                    cleaned_paras.append(txt)
            
            result['content'] = ' '.join(cleaned_paras)

        return result

    except Exception as e:
        print(f"Lỗi parse ({url}): {e}")
        return result

# --- CRAWL UTILS ---
def get_links_extended(url: str) -> Tuple[List[str], List[str]]:
    try:
        resp = session.get(url, timeout=20)
        if resp.status_code != 200: return [], []
        
        soup = BeautifulSoup(resp.text, 'html.parser')
        article_links = set()

        for a in soup.find_all('a', href=True):
            full = normalize_href(a['href'], base=url)
            if not full: continue
            
            if DOMAIN in full and ARTICLE_URL_RE.search(full):
                # --- LỌC QUAN TRỌNG ---
                # Loại bỏ link chính nó
                if full == url: continue
                
                # Loại bỏ link phân trang (trang-2.htm, trang-3.htm...) để tránh nhầm là bài viết
                if '/trang-' in full: continue
                
                article_links.add(full)

        return sorted(article_links), [] 
    except Exception:
        return [], []

# --- MAIN LOGIC ---
def main(topics_dict):
    seen_global = set()
    fieldnames = ['topic', 'title', 'summary', 'keywords', 'description', 'content', 'publish_time', 'url']

    with open(OUTPUT_FILE, 'w', newline='', encoding='utf-8-sig') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()

        for topic_name, url_data in topics_dict.items():
            print(f"\n ========== CHỦ ĐỀ: {topic_name} ==========")
            list_urls = [url_data] if isinstance(url_data, str) else list(url_data)

            for sub_url in list_urls:
                print(f"   >>> Quét nhánh: {sub_url}")
                page = 1
                consecutive_empty = 0
                
                while page <= MAX_PAGES_PER_LINK and consecutive_empty < STOP_AFTER_EMPTY:
                    # Tạo URL phân trang theo format mới
                    p_url = make_page_url(sub_url, page)
                    print(f"      -> Trang {page}: {p_url}")
                    
                    try:
                        article_links, _ = get_links_extended(p_url)
                    except:
                        article_links = []

                    new_links = [l for l in article_links if l not in seen_global]
                    
                    if not new_links:
                        print("         (Không tìm thấy link mới hoặc hết trang).")
                        consecutive_empty += 1
                    else:
                        consecutive_empty = 0
                        count_ok = 0
                        for link in new_links:
                            seen_global.add(link)
                            data = parse_article(link)
                            
                            if data['title'] and data['content']:
                                writer.writerow({
                                    'topic': topic_name,
                                    'title': data['title'],
                                    'summary': data['summary'],
                                    'keywords': data['keywords'],
                                    'description': data['description'],
                                    'content': data['content'],
                                    'publish_time': data['publish_time'],
                                    'url': data['url']
                                })
                                count_ok += 1
                                print(f"         ✅ {data['title'][:50]}...")
                            time.sleep(0.2) 
                        
                        print(f"      -> Đã lưu {count_ok} bài.")
                    
                    page += 1
                    time.sleep(SLEEP_BETWEEN_REQUESTS)

    print("\n[FINISH] Hoàn tất crawl. File:", OUTPUT_FILE)

# --- DANH MỤC CẦN CRAWL ---
if __name__ == "__main__":
    topics = {
        'Khoa học công nghệ': [
            'https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe.htm',
#       -> Đã lưu 28 bài.
#       -> Trang 2: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-2.htm
#          ✅ Tiêu chuẩn phải đi trước, dữ liệu phải dẫn đường...
#          ✅ Bộ trưởng Nguyễn Mạnh Hùng: Muốn ra thế giới, trướ...
#          ✅ Phát huy vai trò của công đoàn trong chuyển đổi số...
#          ✅ Đại hội Thi đua yêu nước toàn quốc lần thứ XI là Đ...
#          ✅ Đảng bộ Bộ KH&CN: Đổi mới nghiệp vụ công tác Đảng,...
#          ✅ Nâng cao tiềm lực khoa học và công nghệ trong lĩnh...
#          ✅ Đổi mới tư duy, hành động dựa trên kết quả, kiến t...
#          ✅ Quảng Trị: Bộ KH&CN nâng cao nhận thức quốc phòng,...
#          ✅ Giải thưởng Hồ Chí Minh, Giải thưởng Nhà nước về K...
#          ✅ Khai trương bộ phận một cửa Bộ Khoa học và Công ng...
#          ✅ Nâng cao tiềm lực khoa học cơ bản: Đặt nền móng dà...
#          ✅ Khoa học, công nghệ, đổi mới sáng tạo và chuyển đổ...
#          ✅ Khối Tham mưu; Công nghiệp công nghệ số; Thông tin...
#          ✅ Mở không gian mới để cán bộ phát huy tối đa năng l...
#          ✅ Phiên thứ nhất Đại hội Công đoàn KH&CN Việt Nam: Đ...
#          ✅ Ứng dụng hiệu quả Cổng Sáng kiến KH,CN&ĐMST: Mở “đ...
#       -> Đã lưu 16 bài.
#       -> Trang 3: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-3.htm
#          ✅ 05 đạo luật mở không gian phát triển mới cho khoa ...
#          ✅ Bộ KH&CN và GGGI công bố Bản ghi nhớ hợp tác chiến...
#          ✅ Định hình vai trò, vị thế của nghiên cứu cơ bản tr...
#          ✅ Hoàn thiện cơ sở dữ liệu và mô hình sản xuất cho b...
#          ✅ Hoàn thiện cơ sở khoa học và công cụ cảnh báo sớm ...
#          ✅ Hoàn thiện hệ thiết bị nghiên cứu tác động của môi...
#          ✅ Hoàn thiện module cửa sổ điều tiết ánh sáng và tíc...
#          ✅ Hoàn thiện robot ngầm phòng sinh học mô phỏng chuy...
#          ✅ Kết nối các khu ứng dụng công nghệ cao nông nghiệp...
#          ✅ Khai thác và phát triển nguồn gen ngô địa phương c...
#          ✅ Khai thác và phát triển nguồn gen trâu Thanh Chươn...
#          ✅ Làm chủ công nghệ chế tạo hệ thống đo địa chấn đáy...
#          ✅ Luật Trí tuệ nhân tạo: Khung pháp lý đầu tiên cho ...
#          ✅ Nghiên cứu động thái carbon do thay đổi sử dụng đấ...
#          ✅ Phát triển thiết bị LoC hỗ trợ phát hiện sớm tế bà...
#          ✅ Thủ tướng Phạm Minh Chính tham dự Lễ khai mạc Tech...
#          ✅ Ủy ban KH,CN&MT Quốc hội: Ba dự án Luật tạo nền tả...
#          ✅ Việt Nam - Lào thúc đẩy hợp tác KH&CN gắn với chuy...
#          ✅ Xây dựng bộ chỉ số hóa sinh cơ bản về độc chất học...
#          ✅ Xây dựng mô hình lồng ghép hành lang bảo vệ bờ biể...
#       -> Đã lưu 20 bài.
#       -> Trang 4: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-4.htm
#          ✅ Bộ KH&CN ban hành Thông tư quy định mã số và tiêu ...
#          ✅ Bộ KH&CN tập huấn sử dụng Hệ thống thông tin giải ...
#          ✅ Bộ Khoa học và Công nghệ thúc đẩy đơn giản hóa thủ...
#          ✅ Chế tạo chất lỏng nano tương phản ảnh MRI và CT tr...
#          ✅ Công nghệ trị liệu không xâm lấn: Hướng tiếp cận m...
#          ✅ Đồng bộ thể chế, hạ tầng và thị trường để khoa học...
#          ✅ Giải mã cơ chế tan rã đất đắp đập để bảo đảm an to...
#          ✅ Hoàn thành nghiên cứu chỉnh sửa gen nâng cao khả n...
#          ✅ Hoàn thiện công nghệ vật liệu hấp phụ mới xử lý nư...
#          ✅ Hoàn thiện thể chế, mở đường cho bứt phá công nghệ...
#          ✅ Hội nghị toàn quốc triển khai Nghị định 265/2025/N...
#          ✅ Làm chủ công nghệ sản xuất nấm Agaricus subrufesce...
#          ✅ Quốc hội dự kiến thông qua 5 luật lớn, hoàn thiện ...
#          ✅ Quy định mới về tiêu chí xét hỗ trợ nâng cao năng ...
#          ✅ NAFOSTED - RSF ký kết MOU: Tăng cường hợp tác tron...
#          ✅ TECHFEST Việt Nam 2025 lan tỏa tinh thần khởi nghi...
#          ✅ Ứng dụng công nghệ sinh điện hóa kiểm soát vi khuẩ...
#          ✅ Ứng dụng công nghệ sinh học nâng cao hàm lượng vi ...
#          ✅ Ứng dụng hiệu quả Cổng Sáng kiến KH&CN: Hạt nhân s...
#          ✅ Xây dựng kịch bản mưa lũ cực hạn cho lưu vực sông ...
#       -> Đã lưu 20 bài.
#       -> Trang 5: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-5.htm
#          ✅ Ba nữ nhà khoa học Việt nhận học bổng L’Oréal - UN...
#          ✅ Bộ KH&CN công bố các quyết định về công tác cán bộ...
#          ✅ Bộ KH&CN tập huấn công tác bảo đảm an toàn thông t...
#          ✅ Bộ Khoa học và Công nghệ hoàn thiện 5 dự án luật, ...
#          ✅ Dấu ấn đậm nét của GS.TS Chu Tuấn Nhạ với sự phát ...
#          ✅ GS.TS. Chu Tuấn Nhạ trọn đời cống hiến cho khoa họ...
#          ✅ Khoa học và công nghệ: Động lực trung tâm của chuy...
#          ✅ Khóa họp lần thứ 6 Ủy ban hợp tác về giáo dục, kho...
#          ✅ "Nâng cao chất lượng cán bộ cơ sở chính là tăng sứ...
#          ✅ Nghiên cứu xây dựng bộ mô hình và quy trình công n...
#          ✅ Phát huy hiệu quả của AI: Đại biểu Quốc hội đề ngh...
#          ✅ Quy định khung và trình tự, thủ tục xây dựng, thẩm...
#          ✅ Samsung khẳng định cam kết lâu dài tại Việt Nam: M...
#          ✅ Thành phố Huế - Hành trình chuyển đổi xanh vì một ...
#          ✅ Tháo gỡ điểm nghẽn để phát triển công nghệ và sản ...
#          ✅ Thay đổi vị trí việc làm là hết sức bình thường tr...
#          ✅ Thứ trưởng Thường trực Vũ Hải Quân làm Tổ trưởng T...
#          ✅ Ứng dụng khoa học công nghệ, trí tuệ nhân tạo và c...
#          ✅ Việt Nam – Nhật Bản chia sẻ kinh nghiệm xây dựng c...
#          ✅ Vĩnh biệt GS.TS Chu Tuấn Nhạ, nguyên Bộ trưởng Bộ ...
#       -> Đã lưu 20 bài.
#       -> Trang 6: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-6.htm
#          ✅ Bảo tồn loài nguy cấp bằng công nghệ hệ gen...
#          ✅ Bảo tồn và phát triển nguồn gen hai loài Lan quý h...
#          ✅ Chuyển đổi xanh: Cơ hội và giải pháp để phát triển...
#          ✅ Đại hội Đại biểu Đoàn TNCS Hồ Chí Minh Bộ KH&CN lầ...
#          ✅ Hệ sinh thái khởi nghiệp đổi mới sáng tạo Việt Nam...
#          ✅ Hoàn thiện công nghệ sản xuất xi măng alumin từ ch...
#          ✅ Hoàn thiện thể chế và chính sách hành chính phục v...
#          ✅ Khai thác và phát triển nguồn gen cây thuốc Tế tân...
#          ✅ Làm chủ nguồn gen virus để phát triển kit chẩn đoá...
#          ✅ Nghiên cứu tiến hóa magma Trường Sơn: Nền tảng kho...
#          ✅ Quy định mới về sản phẩm, dịch vụ công nghệ số đượ...
#          ✅ Tăng cường an toàn hệ thống điện với thiết bị thôn...
#          ✅ Tạo ống ghép mạch máu đường kính nhỏ bằng hệ thống...
#          ✅ Techfest 2025: Lần đầu tiên tổ chức theo mô hình k...
#          ✅ Thanh niên Bộ KH&CN phải góp phần tạo ra kỷ nguyên...
#          ✅ Tiêu chí để tạp chí khoa học được hỗ trợ kinh phí ...
#          ✅ Triển khai đợt 7 Giải thưởng Hồ Chí Minh, Giải thư...
#          ✅ Ứng dụng khoa học, công nghệ và đổi mới sáng tạo n...
#          ✅ Ưu đãi lựa chọn nhà thầu cho sản phẩm, dịch vụ côn...
#          ✅ Xây dựng bộ cơ sở dữ liệu ngành Ngọc lan (Magnolio...
#       -> Đã lưu 20 bài.
#       -> Trang 7: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-7.htm
#          ✅ 11 nhiệm vụ mới mở đường cho phát triển công nghệ ...
#          ✅ Bộ KH&CN hướng dẫn triển khai Giải thưởng cao nhất...
#          ✅ Bộ trưởng Nguyễn Mạnh Hùng: Sửa luật để tạo thị tr...
#          ✅ Bộ trưởng Nguyễn Mạnh Hùng tiếp Hội đồng Kinh doan...
#          ✅ Bước tiến mới của khoa học vật liệu y sinh Việt Na...
#          ✅ Chuyển đổi xanh: Cơ hội và thách thức cho Việt Nam...
#          ✅ Đẩy nhanh kết nối, liên thông dữ liệu các sàn giao...
#          ✅ Dự thảo Luật Trí tuệ nhân tạo: Hành lang pháp lý c...
#          ✅ Giải pháp phục hồi độ phì và phát triển lâm nghiệp...
#          ✅ Hà Nội định vị vai trò tiên phong của KHCN, ĐMST t...
#          ✅ Hướng đi mới cho mục tiêu loại bỏ chất thải nguy h...
#          ✅ Khai trương Hệ thống quản lý trực tuyến các nhiệm ...
#          ✅ Loạt nhiệm vụ đột phá về UAV, vệ tinh siêu nhỏ đượ...
#          ✅ Nghiên cứu, đánh giá vai trò, thực trạng của hệ si...
#          ✅ Nghiên cứu tiến hóa magma Trường Sơn: Nền tảng kho...
#          ✅ Phát triển công nghệ chiến lược bắt đầu từ thay đổ...
#          ✅ Quản lý rủi ro trong KH&CN: Kiến tạo hành lang đổi...
#          ✅ Tạo thị trường công nghệ và nâng cao tự chủ...
#          ✅ Tiêu chí để doanh nghiệp điện tử được hưởng ưu đãi...
#          ✅ Ứng dụng khoa học, công nghệ và chuyển đổi số tron...
#       -> Đã lưu 20 bài.
#       -> Trang 8: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-8.htm
#          ✅ Biểu tượng quan hệ hợp tác Việt - Hàn về khoa học ...
#          ✅ Đột phá về KH,CN,ĐMST&CĐS trong Dự thảo Chương trì...
#          ✅ Hoàn thiện khung pháp lý để quản lý toàn diện chuỗ...
#          ✅ Hoàn thiện khung pháp lý ưu đãi doanh nghiệp công ...
#          ✅ Hoàn thiện thể chế để phát triển an toàn, nhân văn...
#          ✅ "Hồi sinh" giống lúa huyết rồng quý hiếm...
#          ✅ Khai thác và phát triển nguồn gen Bách bộ và Rau đ...
#          ✅ Kiến tạo tinh thần quốc gia khởi nghiệp sáng tạo...
#          ✅ Làm rõ cơ chế góp vốn bằng công nghệ...
#          ✅ Làm rõ mô hình và vai trò của Ủy ban Quốc gia về T...
#          ✅ Luật Trí tuệ nhân tạo: Làm rõ trách nhiệm và quyền...
#          ✅ Từ trái tim đến hành động: Bộ KH&CN phát động ủng ...
#          ✅ Phát huy giá trị cây nông nghiệp bản địa...
#          ✅ Phát triển thị trường công nghệ - Động lực nâng ca...
#          ✅ Phó Chủ tịch Quốc hội Lê Minh Hoan: Hoàn thiện hệ ...
#          ✅ Quy định tiêu chí nhập khẩu dây chuyền, thiết bị đ...
#          ✅ Sửa đổi Luật Chuyển giao công nghệ: Chuyển từ kiểm...
#          ✅ Tự chủ công nghệ chiến lược để phát triển khoa học...
#          ✅ Việt Nam đặt mục tiêu trở thành Trung tâm công ngh...
#          ✅ Bật công tắc chiến lược: Việt Nam tăng tốc làm chủ...
#       -> Đã lưu 20 bài.
#       -> Trang 9: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-9.htm
#          ✅ Bảo tồn và phát triển nguồn gen Trâu Langbiang...
#          ✅ Biến rác thành năng lượng sạch: Giải pháp công ngh...
#          ✅ Đề xuất cơ chế thử nghiệm cho doanh nghiệp nhà nướ...
#          ✅ Hành trình đánh thức nguồn chè búp tím quý...
#          ✅ Hy vọng mới cho trẻ mắc bệnh lý gan mật nhờ liệu p...
#          ✅ Khai thác và phát triển nguồn gen cây Mù u: Hướng ...
#          ✅ Khai thác và phát triển nguồn gen chè Trung du búp...
#          ✅ Mở hướng mới cho rừng măng bói ở Tây Bắc...
#          ✅ Người chế tạo hơn 50.000 thiết bị cơ giới sản xuất...
#          ✅ Nguồn gen bản địa mở hướng phát triển sinh kế bền ...
#          ✅ Phát huy giá trị khoai lang bản địa thích ứng với ...
#          ✅ Phát huy giá trị nguồn gen cây Trắc...
#          ✅ Phát huy giá trị và nguồn lực nhân văn vùng đồng b...
#          ✅ Sắn ruột vàng Phú Thọ cho giá trị gia tăng và phát...
#          ✅ Tháo gỡ nhiều vấn đề “nút thắt” trong chuyển giao ...
#          ✅ Thủy tùng Tây Nguyên: Khôi phục nguồn gen quý hiếm...
#          ✅ Triển khai quyết liệt các nhiệm vụ trọng tâm về KH...
#          ✅ Tuyển chọn thành công 5 giống khoai lang bản địa ư...
#          ✅ Ứng dụng công nghệ để dự báo và giảm xói lở bờ biể...
#          ✅ Xây dựng bộ công cụ đánh giá, dự báo biến động hìn...
#       -> Đã lưu 20 bài.
#       -> Trang 10: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-10.htm
#          ✅ Bài toán xâm nhập mặn trên lưu vực sông Cauto: Góc...
#          ✅ Cần trao quyền cho địa phương và đẩy mạnh khoa học...
#          ✅ Cơ giới hóa canh tác chuối quy mô tập trung: Giảm ...
#          ✅ Đột phá phát triển khoa học, công nghệ, đổi mới sá...
#          ✅ Dự thảo Văn kiện Đại hội XIV của Đảng: Hoàn thiện ...
#          ✅ Giải mã ô nhiễm vùng ven biển Nam Bộ...
#          ✅ Hà Nội: Mở rộng cơ chế hỗ trợ đặc thù, tạo động lự...
#          ✅ Khai thác và Phát triển Nguồn Gen Bí Nếp và Bí Thơ...
#          ✅ Khai trương Trung tâm Nghiên cứu Phát triển - Đào ...
#          ✅ Khi công nghệ giúp nhà vườn làm nông chính xác và ...
#          ✅ Khoa học và công nghệ: Đòn bẩy nâng giá trị ngành ...
#          ✅ Khoa học và công nghệ tạo sức bật mới cho xuất khẩ...
#          ✅ Nền tảng mới cho nông nghiệp bền vững và giảm phát...
#          ✅ Phát triển nguồn nhân lực khoa học trẻ trong doanh...
#          ✅ Sắn ruột vàng trở lại thắp sinh kế mới trên những ...
#          ✅ Tăng tốc nghiên cứu và làm chủ công nghệ 4.0...
#          ✅ Thêm cú hích vốn cho startup công nghệ...
#          ✅ Tuần lễ Khoa học Công nghệ VinFuture 2025: Kết nối...
#          ✅ Ứng dụng kỹ thuật năng lượng mặt trời tưới nhỏ giọ...
#          ✅ Xác lập mô hình tăng trưởng mới lấy KHCN,ĐMST&CĐS ...
#       -> Đã lưu 20 bài.
#       -> Trang 11: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-11.htm
#          ✅ 12 cơ sở dữ liệu quốc gia "chạy nước rút"...
#          ✅ Ban hành Danh mục sản phẩm, dịch vụ công nghệ số t...
#          ✅ Bảo đảm nguồn lực cho KH,CN, ĐMST&CĐS – Nỗ lực từ ...
#          ✅ Bổ sung quy định về phát triển đô thị công nghệ ca...
#          ✅ Danh mục thủ tục hành chính mới trong lĩnh vực kho...
#          ✅ Đẩy mạnh ứng dụng trí tuệ nhân tạo trong thu thập ...
#          ✅ Đột phá nguồn nhân lực – Nền tảng cho KH, CN, ĐMST...
#          ✅ Giữ vững nông nghiệp công nghệ cao trong hành lang...
#          ✅ Hoàn thiện hệ sinh thái dữ liệu – Đột phá trong ch...
#          ✅ Hoàn thiện Luật Công nghệ cao: Tạo nền tảng mới th...
#          ✅ Khoa học và công nghệ giữ vai trò then chốt trong ...
#          ✅ Lộ trình làm chủ công nghệ chiến lược của Việt Nam...
#          ✅ Nâng cao năng lực nghiên cứu, chủ động hội nhập qu...
#          ✅ Nghiên cứu kháng sinh nano trong chăn nuôi gia cầm...
#          ✅ Nghiên cứu xây dựng bộ công cụ phục vụ đánh giá, d...
#          ✅ Nông nghiệp ven đô Hà Nội bứt phá với mô hình hoa ...
#          ✅ Tạo hành lang pháp lý đủ mạnh để bứt phá công nghệ...
#          ✅ Thái Bình phát triển mô hình trồng dưa thơm và hoa...
#          ✅ Xác lập mô hình tăng trưởng mới dựa trên khoa học,...
#          ✅ Xây dựng và hoàn thiện thể chế: Động lực phát triể...
#       -> Đã lưu 20 bài.
#       -> Trang 12: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-12.htm
#          ✅ Bộ KH&CN công bố các quyết định về công tác cán bộ...
#          ✅ Bộ KH&CN đẩy mạnh triển khai Nghị quyết 57-NQ/TW, ...
#          ✅ Bộ KH&CN phát huy vai trò nòng cốt trong triển kha...
#          ✅ Chính phủ yêu cầu tăng tốc hoàn thành các nhiệm vụ...
#          ✅ Cơ chế bảo vệ nghiên cứu có trách nhiệm...
#          ✅ Cơ chế đặc biệt thu hút chuyên gia trong lĩnh vực ...
#          ✅ Cổng Sáng kiến: Bảo đảm sở hữu trí tuệ, an toàn dữ...
#          ✅ Cổng Sáng kiến: Hỗ trợ pháp lý, kết nối công nghệ ...
#          ✅ Hoàn thiện chế độ báo cáo định kỳ trong ngành KH&C...
#          ✅ Lần đầu tiên: Việt Nam bàn chiến lược đưa 'Kinh tế...
#          ✅ Năm 2026, dành khoảng 95 nghìn tỷ đồng ngân sách c...
#          ✅ NEAC đại diện Việt Nam tham dự Hội nghị thường niê...
#          ✅ Nền tảng khoa học cho đổi mới mô hình tăng trưởng ...
#          ✅ Nghiên cứu cảnh quan biển, đảo nhiệt đới gió mùa V...
#          ✅ Phân cấp, phân quyền KH&CN: Địa phương vướng đến đ...
#          ✅ Phát huy giá trị quốc gia và nguồn lực nhân văn ph...
#          ✅ Ra mắt Liên minh Kinh tế tầm thấp, tham gia thị tr...
#          ✅ Tạo đột phá trong cơ chế tài trợ, đặt hàng và hỗ t...
#          ✅ Tiêu chuẩn xét tặng bằng khen của Bộ Khoa học và C...
#          ✅ VinFuture mùa 5: Mở rộng quy mô, lan tỏa tri thức ...
#       -> Đã lưu 20 bài.
#          ✅ Trình Quốc hội ba dự án luật về chuyển đổi số, côn...
#          ✅ Vai trò phân tích dữ liệu không gian địa lý...
#       -> Đã lưu 20 bài.
#       -> Trang 15: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-15.htm
#          ✅ ADM 2030: Hướng tới một Cộng đồng số bao trùm và b...
#          ✅ Bộ KH&CN công bố và trao quyết định bổ nhiệm, điều...
#          ✅ Đẩy mạnh nghiên cứu và ứng dụng Toán học phục vụ p...
#          ✅ Đề xuất quy định về quản lý nhiệm vụ khoa học và c...
#          ✅ Diễn đàn ITU 2025: Thúc đẩy đổi mới sáng tạo và ch...
#          ✅ Hoàn thiện quy trình xét duyệt và ký hợp đồng nhiệ...
#          ✅ Hoàn thiện thể chế KHCN&ĐMST, nâng cao năng lực cạ...
#          ✅ Hội nghị lần thứ nhất Ban chấp hành đảng bộ Bộ Kho...
#          ✅ Hội nghị tập huấn công tác Văn thư, Lưu trữ và Bảo...
#          ✅ Lấy ý kiến quy định về lập dự toán, quản lý, sử dụ...
#          ✅ Nhiều quy định mới trong Dự thảo Luật sửa đổi, bổ ...
#          ✅ Quốc tế hóa hoạt động nghiên cứu, góp phần xây dựn...
#          ✅ Sửa đổi Luật Chuyển giao công nghệ đáp ứng yêu cầu...
#          ✅ Thúc đẩy hợp tác giữa Bộ Khoa học và Công nghệ và ...
#          ✅ Thúc đẩy phát triển hạ tầng viễn thông bền vững ph...
#          ✅ Ứng dụng KH&CN để thích ứng biến đổi khí hậu, phát...
#          ✅ Việt Nam công bố Báo cáo RAM: Hướng tới AI nhân vă...
#          ✅ Việt Nam tăng cường hợp tác quốc tế phát triển nhâ...
#          ✅ Bộ Khoa học và Công nghệ và UNICEF thúc đẩy hợp tá...
#          ✅ Việt Nam hiện thực hóa cam kết khí hậu tại Công ướ...
#       -> Đã lưu 20 bài.
#       -> Trang 16: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-16.htm
#          ✅ Bước đột phá về cơ chế tài chính cho các Quỹ phát ...
#          ✅ Các thách thức của chuyển đổi xanh và vai trò của ...
#          ✅ Chính sách ưu đãi mới dành cho nhà khoa học và kỹ ...
#          ✅ Chương trình KC.03/21-30: Thúc đẩy công nghệ cơ kh...
#          ✅ Đảm bảo thống nhất và hiện đại hóa hoạt động thống...
#          ✅ Đổi mới cơ chế khoán chi trong thực hiện nhiệm vụ ...
#          ✅ Khai mạc Tuần lễ Số Quốc tế Việt Nam 2025: Thúc đẩ...
#          ✅ Khoa học và công nghệ - Động lực then chốt hướng t...
#          ✅ Khoa học và công nghệ thúc đẩy chuyển đổi xanh tro...
#          ✅ Lấy ý kiến dự thảo Chương trình phát triển sản phẩ...
#          ✅ Phát triển kinh tế xanh và kinh tế tuần hoàn trong...
#          ✅ Quản trị trí tuệ nhân tạo: Cân bằng giữa đổi mới v...
#          ✅ Quy định mới về chi ngân sách cho khoa học, công n...
#          ✅ Quy định mới về thành lập tổ chức khoa học và công...
#          ✅ Khoa học, công nghệ, đổi mới sáng tạo và chuyển đổ...
#          ✅ Khoa học và công nghệ - Động lực cho thích ứng biế...
#          ✅ Nguồn lực xã hội cho khoa học, công nghệ và đổi mớ...
#          ✅ Nhiều chỉ tiêu phát triển KH, CN và ĐMST đến năm 2...
#          ✅ Quy định về Quỹ đầu tư mạo hiểm quốc gia và địa ph...
#          ✅ Quy định về xây dựng kế hoạch tổng thể về khoa học...
#          ✅ Tăng tốc chuyển đổi số: Đẩy mạnh nghiên cứu, phát ...
#          ✅ Thông tư 22/2025/TT-BKHCN: Tăng cường quản lý, sử ...
#          ✅ Thúc đẩy khoa học và công nghệ phục vụ phát triển ...
#       -> Đã lưu 19 bài.
#       -> Trang 19: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-19.htm
#          ✅ 65 năm thắp lửa tri thức - Ngành Kỹ thuật Nhiệt ti...
#          ✅ Ban hành Bộ tiêu chí đánh giá hiệu quả của KH,CN, ...
#          ✅ Chính sách công nghệ cao: Bài học từ các quốc gia ...
#          ✅ Cơ chế ưu đãi trong Dự thảo Luật Công nghệ cao: Là...
#          ✅ Công nghệ cao - Động lực mới cho kỷ nguyên tăng tr...
#          ✅ Doanh nghiệp kỳ vọng Luật Công nghệ cao (sửa đổi) ...
#          ✅ Hành trình hơn 16 năm Luật Công nghệ cao: Từ nền m...
#          ✅ Hoàn thiện chính sách công nghệ cao: Bài học từ ki...
#          ✅ Hoàn thiện Luật Công nghệ cao để tạo hành lang phá...
#          ✅ Hoàn thiện thể chế, tạo động lực phát triển công n...
#          ✅ Kiến tạo “mùa vàng” khoa học và công nghệ: Khi nhâ...
#          ✅ Luật Chuyển giao công nghệ (sửa đổi): Bảo đảm đồng...
#          ✅ NAFOSTED tạo đột phá: Rút ngắn thời gian xét duyệt...
#          ✅ Những điểm mới nổi bật trong Dự thảo Luật Công ngh...
#          ✅ Phát triển công nghiệp công nghệ cao: Cần chính sá...
#          ✅ Phát triển công nghiệp hóa dược: Nâng cao năng lực...
#          ✅ Quảng Trị kiện toàn Ban Chỉ đạo phát triển khoa họ...
#          ✅ Sửa đổi Luật Công nghệ cao: Cơ hội cho doanh nghiệ...
#          ✅ Thủ tướng Chính phủ thăm Triển lãm thành tựu KH,CN...
#          ✅ Trường Đại học Bách khoa TP. HCM và VNPT hợp tác c...
#       -> Đã lưu 20 bài.
#       -> Trang 20: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-20.htm
#          ✅ 80 năm Bộ KH&CN: Hành trình kiến tạo và phụng sự đ...
#          ✅ Ban hành một số chính sách đột phá phát triển khoa...
#          ✅ Bứt phá từ đổi mới sáng tạo - động lực trung tâm k...
#          ✅ Chương trình hành động phát triển và ứng dụng công...
#          ✅ Công nghệ chiến lược là “chìa khoá vàng” phát triể...
#          ✅ Đẩy mạnh phát triển công nghệ sinh học: Hướng tới ...
#          ✅ Đưa công nghệ vũ trụ trở thành trụ cột trong đổi m...
#          ✅ Công nghệ số - Trụ cột hỗ trợ chính quyền địa phươ...
#          ✅ Đổi mới phương thức quản lý chất lượng sản phẩm, h...
#          ✅ Hoàn thiện thể chế cho phát triển - Bộ Khoa học và...
#          ✅ Quỹ đầu tư mạo hiểm, Sàn giao dịch chứng khoán...
#          ✅ Luật KH,CN&ĐMST: Đưa doanh nghiệp vào vị trí trung...
#          ✅ Luật KH,CN&ĐMST: Kiến tạo hệ sinh thái tri thức, d...
#          ✅ Luật Khoa học, Công nghệ và Đổi mới sáng tạo - Mở ...
#          ✅ Luật sửa đổi, bổ sung một số điều của Luật Chất lư...
#          ✅ Luật Tiêu chuẩn & Quy chuẩn kỹ thuật (sửa đổi) tra...
#          ✅ Một luật – Nhiều đột phá: Luật mới mở đường cho hộ...
#          ✅ Sàn giao dịch khoa học và công nghệ: Thúc đẩy giao...
#          ✅ Bộ trưởng Nguyễn Mạnh Hùng “đốt lửa” tinh thần kho...
#          ✅ VietNamNet chính thức trở thành cơ quan ngôn luận ...
#          ✅ VKIST phát triển hệ thống lọc nước nhiễm mặn thích...
#       -> Đã lưu 20 bài.
#       -> Trang 30: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-30.htm
#          ✅ 15 ý kiến góp ý giúp hoàn thiện Dự thảo Luật KH,CN...
#          ✅ 3 tháng đổi mới quyết liệt ngành KH&CN: Tư duy mới...
#          ✅ Danh mục công nghệ chiến lược và sản phẩm công ngh...
#          ✅ Bộ KH&CN tiên phong hành động vì môi trường: Chung...
#          ✅ 21 bài toán lớn về khoa học, công nghệ, đổi mới sá...
#          ✅ Bước ngoặt thể chế từ Trung ương tới địa phương...
#          ✅ Hoàn thiện Dự thảo Luật KH,CN&ĐMST: Nhấn mạnh vai ...
#          ✅ Hướng tới mô hình Quỹ khoa học và công nghệ năng đ...
#          ✅ Khởi công Tổ hợp không gian sáng tạo CMC: Dấu mốc ...
#          ✅ Luật Khoa học, Công nghệ và Đổi mới sáng tạo: Hành...
#          ✅ Mở rộng quyền chủ động cho địa phương, đảm bảo kiể...
#          ✅ Nghiên cứu xác định bể chứa cacbon hữu cơ trong đấ...
#          ✅ Phân định thẩm quyền lĩnh vực KH&CN: Bước tiến tro...
#          ✅ Ra mắt Trung tâm Công nghệ chiến lược Úc - Việt...
#          ✅ Ra mắt Trung tâm Nghiên cứu và Phát triển trí tuệ ...
#          ✅ Đổi mới cách tiếp cận trong tài trợ nghiên cứu kho...
#          ✅ Trao quyền cho cấp xã trong kiểm tra đo lường, chấ...
#          ✅ Việt Nam tích cực tham gia xây dựng Cộng đồng khoa...
#          ✅ Việt Nam và Estonia tăng cường hợp tác về KHCN, ĐM...
#       -> Đã lưu 19 bài.
#       -> Trang 31: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-31.htm
#          ✅ 42 công trình đoạt Giải thưởng Sáng tạo khoa học c...
#          ✅ Dự án Luật Năng lượng nguyên tử (sửa đổi)...
#       -> Trang 33: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-33.htm
#          ✅ Bộ KH&CN tổ chức hội thảo lấy ý kiến hoàn thiện dự...
#          ✅ Bộ Khoa học và Công nghệ hưởng ứng Tuần lễ quốc gi...
#          ✅ Bộ trưởng Nguyễn Mạnh Hùng: Không còn đếm đầu việc...
#          ✅ Bộ trưởng Nguyễn Mạnh Hùng tiếp Tổng Giám đốc Viện...
#          ✅ Đẩy mạnh ứng dụng công nghệ trong xử lý, điều hành...
#          ✅ Đóng góp của khoa học, công nghệ và đổi mới sáng t...
#          ✅ Hội nghị Thượng đỉnh P4G 2025: Tăng trưởng xanh bề...
#          ✅ Triển lãm về Tăng trưởng xanh với chủ đề “Sáng tạo...
#          ✅ Khoa học, công nghệ, đổi mới sáng tạo và chuyển đổ...
#          ✅ Khơi thông nguồn lực cho phát triển KHCN&ĐMST...
#          ✅ Phát động phong trào “Cả nước thi đua đổi mới sáng...
#          ✅ Sao Khuê 2025: Dấu ấn sáng tạo và Khát vọng vươn m...
#          ✅ Sở hữu trí tuệ là chìa khóa cho sự phát triển bứt ...
#          ✅ Sửa đổi Luật Năng lượng nguyên tử: Bảo đảm phù hợp...
#          ✅ Sửa đổi Luật Năng lượng nguyên tử: Tạo hành lang p...
#          ✅ Thẩm tra Luật Năng lượng nguyên tử (sửa đổi)...
#          ✅ Thúc đẩy khởi nghiệp sáng tạo trong lĩnh vực chuyể...
#          ✅ Tự lực, tự cường về khoa học công nghệ: Khát vọng ...
#          ✅ Tương lai số công bằng và dành cho tất cả mọi ngườ...
#          ✅ Đổi mới sáng tạo toàn dân...
#       -> Đã lưu 20 bài.
#       -> Trang 34: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-34.htm
#          ✅ 150 đơn vị tham gia Triển lãm Analytica Vietnam 20...
#          ✅ Analytica Vietnam 2025: Cầu nối chiến lược đưa côn...
#          ✅ Bộ KH&CN cam kết đồng hành với Doanh nghiệp trong ...
#          ✅ Bộ KH&CN tổ chức lớp bồi dưỡng về GenAI cho lãnh đ...
#          ✅ Bộ KH&CN và MISA thúc đẩy phát triển trí tuệ nhân ...
#          ✅ Bộ Khoa học và Công nghệ dẫn dắt 3 hoạt động trọng...
#          ✅ Bộ Khoa học và Công nghệ đồng hành cùng doanh nghi...
#          ✅ Bộ Khoa học và Công nghệ thành lập Ban Chỉ đạo về ...
#          ✅ Bộ trưởng Nguyễn Mạnh Hùng: Thành công phải bắt đầ...
#          ✅ Hiện thực hóa mục tiêu đưa KH,CN,ĐMST và CĐS là độ...
#          ✅ Hưởng ứng Ngày Sáng tạo và Đổi mới sáng tạo thế gi...
#          ✅ Ký kết hợp tác nghiên cứu và ứng dụng công nghệ vi...
#          ✅ Mô hình S.T.I.D: Con đường để Việt Nam phát triển ...
#          ✅ Phó Thủ tướng Chính phủ Nguyễn Chí Dũng làm việc v...
#          ✅ Tăng cường cung cấp kiến thức về SHTT cho học sinh...
#          ✅ Thúc đẩy hợp tác Việt Nam – IAEA trong phát triển ...
#          ✅ Tiếp tục thể chế hóa các chủ trương, đường lối của...
#          ✅ Ưu tiên chính sách về phát triển nguồn nhân lực KH...
#          ✅ Việt Nam và Cộng hòa Séc thảo luận chính sách hợp ...
#          ✅ VKIST ký kết hợp tác nâng cao giá trị kinh tế cây ...
#       -> Đã lưu 20 bài.
#       -> Trang 35: https://mst.gov.vn/tin-tuc-su-kien/khoa-hoc-va-cong-nghe/trang-35.htm
#          ✅ AI trở thành yếu tố quyết định hiệu suất doanh ngh...
#          ✅ Bộ KH&CN nghe ý kiến đóng góp về dự thảo Nghị định...
# ...
#          ✅ Định Hoá - Thái Nguyên: Ra quân hưởng ứng Ngày Chu...
#          ✅ Hỗ trợ doanh nghiệp nhỏ và vừa chuyển đổi số trên ...
#          ✅ Hơn 400 vận động viên tham gia Hội thao ngành TT&T...
#          ✅ Khai mạc Ngày hội Công nghệ số tỉnh Khánh Hòa năm ...
#          ✅ Phổ cập hạ tầng số, tăng cường ứng dụng số để thúc...
#          ✅ Phú Thọ: Nhiều hoạt động thiết thực hưởng ứng Ngày...
#          ✅ Quảng Bình: Chuyển đổi số, rút ngắn thời gian chờ ...
#          ✅ Quảng Bình: Phổ cập hạ tầng số, thúc đẩy kinh tế s...
#          ✅ Sở TT&TT Quảng Bình nỗ lực chuyển đổi số, xây dựng...
#          ✅ Sôi nổi Hội thi tuyên truyền cải cách hành chính, ...
#          ✅ Sôi nổi Ngày hội Chuyển đổi số tỉnh Cà Mau...
#          ✅ Sức lan tỏa từ Cuộc thi trực tuyến “Tìm hiểu về Cả...
#          ✅ Tập huấn kỹ năng làm báo đa phương tiện cho cán bộ...
#          ✅ Trung tâm Cách mạng công nghiệp lần thứ 4 tại TPHC...
#          ✅ Trung tâm điều hành thông minh tỉnh Quảng Bình: Bộ...
#          ✅ Tuần lễ Chuyển đổi số tỉnh Quảng Ngãi năm 2024: Đề...
#       -> Đã lưu 20 bài.
#       -> Trang 30: https://mst.gov.vn/tin-tuc-su-kien/tin-dia-phuong/trang-30.htm
#          ✅ Đắk Lắk: Bồi dưỡng công tác QLNN về báo chí và tru...
#          ✅ Hiệu quả từ mô hình “Móc khoá an ninh trật tự” tại...
#          ✅ Sở TT&TT Hòa Bình phát động ủng hộ đồng bào khắc p...
#          ✅ Linh hoạt trong thông tin về phòng chống bão lụt ở...
#          ✅ Phát động tháng cao điểm thực hiện chuyển đổi số t...
#          ✅ Phó Thủ tướng Hồ Đức Phớc: Cửa khẩu thông minh phả...
#          ✅ Quảng Nam khai mạc cuộc thi tìm hiểu cải cách hành...
#          ✅ Quảng Ngãi: Tập huấn công tác thông tin đối ngoại ...
#          ✅ Quảng Ninh: Thống nhất chủ trương dành 1.000 tỷ đồ...
#          ✅ Sở TT&TT Bình Phước phát động ủng hộ đồng bào khắc...
#          ✅ Sở TT&TT Phú Thọ phát động ủng hộ đồng bào khắc ph...
#          ✅ Sở TT&TT Quảng Bình phát động ủng hộ đồng bào khắc...
#          ✅ HĐND TP.HCM ứng dụng 'trợ lý ảo' thẩm tra các dự t...
#          ✅ Huyện đầu tiên ở tỉnh Hải Dương thí điểm đăng ký t...
#          ✅ Lãnh đạo tỉnh Khánh Hòa làm việc với đoàn công tác...
#          ✅ Lập Thạch dẫn đầu về chuyển đổi số...
#          ✅ “Mắt xích” kiến tạo xã hội số...
#          ✅ Ngân hàng số di sản văn hóa ở Quảng Trị: Đưa di sả...
#          ✅ Quảng Nam lần đầu tiên có Ki-ốt Dịch vụ công...
#          ✅ Sở Thông tin và Truyền thông Hà Tĩnh - 20 năm một ...
#          ✅ Tập huấn tuyên truyền phòng, chống tội phạm về đa ...
#          ✅ Tây Ninh: Cải cách thủ tục hành chính gắn với chuy...
#          ✅ TPHCM: Thúc đẩy chuyển đổi số trong giải quyết thủ...
#       -> Đã lưu 20 bài.
#       -> Trang 33: https://mst.gov.vn/tin-tuc-su-kien/tin-dia-phuong/trang-33.htm
#          ✅ Bắc Yên - Sơn La nỗ lực chuyển đổi số...
#          ✅ Bình Phước: Chuyển đổi số để phục vụ người dân đượ...
#          ✅ Bình Thủy - Cần Thơ đẩy mạnh chuyển đổi số trên nh...
#          ✅ Cục Thuế thành phố Hà Nội đẩy mạnh cải cách hành c...
#          ✅ Đắk Lắk: Sở Nông nghiệp và Phát triển nông thôn và...
#          ✅ Hà Nội: Thúc đẩy chuyển đổi số ngành du lịch...
#          ✅ Núi Thành xây dựng đô thị thông minh...
#          ✅ Quảng Bình: Thúc đẩy chuyển đổi số nông nghiệp...
#          ✅ Quảng Nam ban hành kế hoạch triển khai đề án chuyể...
#          ✅ Quảng Nam: Chuyển đổi số hạ tầng công nghệ đi trướ...
#          ✅ Sở TT&TT Đắk Lắk triển khai nhiệm vụ 6 tháng cuối ...
#          ✅ TP.HCM dự kiến năm 2025 đạt chỉ tiêu kinh tế số ch...
#          ✅ TPHCM: Tăng tốc số hóa dữ liệu từ cơ sở...
#          ✅ Ứng dụng công dân số YenBai-S tích hợp thêm ứng dụ...
#          ✅ Ứng dụng công nghệ số - "Chìa khóa" phát triển du ...
#          ✅ Vân Hồ - Sơn La đẩy mạnh chuyển đổi số toàn diện t...
#          ✅ Vĩnh Phúc: Tăng tốc xây dựng chính quyền số...
#          ✅ Yên Bái góp phần xây dựng chính quyền điện tử...
#          ✅ Yên Bái nỗ lực xây dựng doanh nghiệp số...
#       -> Đã lưu 19 bài.
#       -> Trang 34: https://mst.gov.vn/tin-tuc-su-kien/tin-dia-phuong/trang-34.htm
#          ✅ Bà Phạm Thị Mỹ Hạnh giữ chức Phó Giám đốc Sở Thông...
#          ✅ Bảo hiểm xã hội tỉnh Yên Bái đẩy mạnh chuyển đổi s...
#          ✅ Cần Thơ triển khai thực hiện có hiệu quả Kế hoạch ...
#          ✅ Đắk Lắk: Gặp mặt kỷ niệm 99 năm Ngày Báo chí cách ...
#          ✅ Đắk Lắk triển khai sử dụng, vận hành Hệ thống thôn...
#          ✅ Đẩy mạnh chuyển đổi số và dịch vụ công trực tuyến ...
#          ✅ Khai trương Trạm phát sóng ở xã xa nhất tỉnh Yên B...
#          ✅ Kiến tạo một Cà Mau Online bằng công nghệ 3D...
#          ✅ Lâm Đồng chuyển đổi số nông nghiệp...
#          ✅ Nghệ An: Chuyển đổi số gắn với cải cách hành chính...
#          ✅ Phú Thọ tổ chức gặp mặt kỷ niệm 99 năm Ngày Báo ch...
#          ✅ Tam Kỳ ứng dụng chuyển đổi số xây dựng đô thị thôn...
#          ✅ Thành phố Cà Mau: Ứng dụng số - Nâng chất hoạt độn...
#          ✅ Thành phố Sơn La phát triển kinh tế số...
#          ✅ Thúc đẩy số hóa ngành nông nghiệp: Cần sớm tháo gỡ...
#          ✅ Thực trạng và định hướng, giải pháp phát triển kin...
#          ✅ TP.HCM công bố danh mục dữ liệu mở...
#          ✅ Vĩnh Phúc thúc đẩy chuyển đổi số đến tận thôn xóm...
#          ✅ Xử phạt Tạp chí điện tử Môi trường Xây dựng...
#          ✅ Yên Bái đẩy mạnh chuyển đổi số trong doanh nghiệp...
#       -> Đã lưu 20 bài.
#       -> Trang 35: https://mst.gov.vn/tin-tuc-su-kien/tin-dia-phuong/trang-35.htm
#          ✅ Cà Mau: Tổ công nghệ số cộng đồng xuất sắc...
#          ✅ Chuyển đổi số: Nhiều ứng dụng thiết thực trong thự...
#          ✅ tăng tốc xây dựng đề án phát triển chíp bán dẫn và...
#          ✅ Đẩy mạnh đưa chuyển đổi số vào cuộc sống...
#          ✅ Đồng Nai thành lập Hội đồng tư vấn chuyển đổi số...
#          ✅ Đồng Nai ưu tiên các hoạt động chuyển đổi số...
#          ✅ Hà Nội dành hơn 10 tỷ đồng hỗ trợ chuyển đổi số nô...
#          ✅ Khai mạc Hội Sách Đất Tổ năm 2024...
#          ✅ Lào Cai: Thanh niên tiên phong trong chuyển đổi số...
#          ✅ Lưu ý trong sử dụng từ ngữ đặt tiêu đề cho bài viế...
#          ✅ PC Quảng Ninh góp phần đưa Quảng Ninh trở thành tỉ...
#          ✅ Quảng Ninh phấn đấu đứng trong top 5 tỉnh, thành p...
#          ✅ Quảng Ninh...
#          ✅ Chủ tịch Hội đồng Quản trị Công ty cổ phần IGB, Vũ...
#          ✅ Ứng dụng Điện Biên Smart...
#          ✅ Thanh Hoá nỗ lực hoàn thành mục tiêu chuyển đổi số...
#          ✅ Tiền Giang: Tuổi trẻ chung tay chuyển đổi số vì cộ...
#          ✅ Thành phố Hồ Chí Minh rực rỡ cờ đỏ sao vàng trong ...
#          ✅ Trà Vinh: Xã Hưng Mỹ tiên phong thực hiện chuyển đ...
#          ✅ Trung tâm CMCN 4.0 tại TPHCM tạo động lực mới cho ...
#       -> Đã lưu 20 bài.
#       -> Trang 36: https://mst.gov.vn/tin-tuc-su-kien/tin-dia-phuong/trang-36.htm
#          ✅ An Giang tiếp tục đẩy mạnh chuyển đổi số...
#          ✅ Bắc Ninh quyết liệt sử dụng biên lai điện tử trong...
#          ✅ Bình Thuận: Xây dựng cấu trúc chuyển đổi số “Tổng ...
#          ✅ Bộ TT&TT biệt phái cán bộ nhận nhiệm vụ Giám đốc S...
#          ✅ Cảnh giác đối tượng giả danh cán bộ Sở TT&TT Cà Ma...
#          ✅ Cao Bằng triển khai đồng bộ các giải pháp thực hiệ...
#          ✅ Đồng Nai: Tăng cường cảnh báo về tội phạm lừa đảo ...
#          ✅ Hải Dương chuyển đổi số để nâng cao chất lượng môi...
#          ✅ Phát động hưởng ứng Ngày Sách và Văn hóa đọc Việt ...
#          ✅ Phú Yên có tân Giám đốc Sở TT&TT...
#          ✅ Quảng Nam khai mạc Ngày Sách và Văn hóa đọc Việt N...
#          ✅ Quảng Ninh: Hoàn thành việc phát hành hóa đơn điện...
#          ✅ Số hoá hơn 8.000 cây sầu riêng tại huyện Krông Búk...
#          ✅ Sở TT&TT tỉnh Lâm Đồng tổ chức Hội nghị Giao ban d...
#          ✅ Thanh Hoá phát động Ngày sách và văn hoá đọc...
#          ✅ Thanh niên Móng Cái khẳng định vai trò xung kích t...
#          ✅ Tích cực thực hiện lộ trình tắt sóng 2G: Đáp ứng y...
#          ✅ Trà Vinh: Xử phạt hành chính bà Đỗ Trúc Phượng do ...
#          ✅ Triển khai hiệu quả công tác chuyển đổi số theo ph...
#          ✅ Vĩnh Phúc: Nỗ lực chuyển đổi số tại cấp xã...
#       -> Đã lưu 20 bài.
#       -> Trang 37: https://mst.gov.vn/tin-tuc-su-kien/tin-dia-phuong/trang-37.htm
#          ✅ Bắc Ninh: Chuyển biến tích cực trong cung cấp và s...
#          ✅ Bắc Ninh: Đẩy mạnh chuyển đổi số tạo đà phát triển...
#          ✅ Bước tiến chuyển đổi số trong lĩnh vực y tế...
#          ✅ Cao Bằng cần đẩy mạnh chuyển đổi số, chính quyền s...
#          ✅ Chọn 174 tác phẩm tham dự Giải báo chí “Hải Dương ...
#          ✅ Chủ tịch UBND tỉnh Kiên Giang kêu gọi phòng, chống...
#          ✅ Công bố kết quả đánh giá Chỉ số Chuyển đổi số tỉnh...
#          ✅ Cụm thi đua số 7 – Bộ TT&TT tổ chức Hội nghị tổng ...
#          ✅ Hải Dương hưởng ứng Cuộc thi viết thư quốc tế UPU ...
#          ✅ Lễ hội Hoa Ban năm 2024 tại tỉnh Điện Biên sẽ có n...
#          ✅ Năm du lịch quốc gia Điện Biên: “Vinh quang Điện B...
#          ✅ Ngành Thông tin và Truyền thông Bắc Ninh: Dâng hươ...
#          ✅ Ngành Thông tin và Truyền thông Phú Thọ triển khai...
#          ✅ Ngành Thông tin và Truyền thông Quảng Ngãi triển k...
#          ✅ Phát động ra quân cao điểm cài đặt Ứng dụng Điện B...
#          ✅ Quảng Nam có hơn 88% nhà văn hóa thôn, khối phố lắ...
#          ✅ Sở Thông tin và Truyền thông tỉnh Hòa Bình Tổng kế...
#          ✅ Sở TT&TT Bắc Ninh phát động cuộc thi ảnh " Duyên d...
#          ✅ Sở TT&TT Quảng Trị triển khai nhiệm vụ năm 2024...
#          ✅ Tổng kết công tác thi đua, khen thưởng Cụm thi đua...
#       -> Đã lưu 20 bài.
#          ✅ Tỉnh Sơn La tổ chức kiểm tra, giám sát các hoạt độ...
#          ✅ Tổng điều tra kinh tế, điều tra cơ sở hành chính n...
#          ✅ Vĩnh Phúc: Tổng điều tra kinh tế 2021 đảm bảo tiến...
#          ✅ Yên Bái: Ra quân tổng điều tra kinh tế 2021, giai ...
#       -> Đã lưu 20 bài.
#       -> Trang 40: https://mst.gov.vn/tin-tuc-su-kien/tin-dia-phuong/trang-40.htm
#          ✅ An Giang: Ban hành Chỉ thị số 01/CT-UBND về việc t...
#          ✅ Bạc Liêu: Triển khai công tác Tổng điều tra kinh t...
#          ✅ Bắt đầu Tổng điều tra kinh tế toàn quốc năm 2021...
#          ✅ BCĐTổng điều tra tỉnh An Giang ban hành kế hoạch k...
#          ✅ Bình Dương: Bảo đảm công tác tổng điều tra kinh tế...
#          ✅ Cà Mau: Tổ chức thực hiện tổng điều tra kinh tế và...
#          ✅ Hà Tĩnh "chạy nước rút” cuộc Tổng điều tra kinh tế...
#          ✅ Hòa Bình: Áp dụng triệt để công nghệ trong Tổng đi...
#          ✅ Hưng Yên: Tổng điều tra kinh tế và Điều tra cơ sở ...
#          ✅ Khánh Hòa: Tổng điều tra kinh tế và điều tra cơ sở...
#          ✅ Kiểm tra công tác tổng điều tra kinh tế, cơ sở hàn...
#          ✅ Phú Thọ: Tập trung thực hiện tốt cuộc Tổng điều tr...
#          ✅ Phú Thọ: Ứng dụng CNTT trong tổng điều tra kinh tế...
#          ✅ Tạo mọi điều kiện thuận lợi nhất để ngành Thống kê...
#          ✅ Thừa Thiên Huế: Triển khai Phương án Tổng điều tra...
#          ✅ Tổng điều tra kinh tế, cơ sở hành chính năm 2021 t...
#          ✅ Tổng điều tra kinh tế năm 2021, sẽ tính toán lại q...
#          ✅ Tổng điều tra kinh tế và cơ sở hành chính năm 2021...
#          ✅ Triển khai tổng điều tra kinh tế năm 2021...
#          ✅ Xây dựng “bức tranh” toàn diện về doanh nghiệp...
#       -> Đã lưu 20 bài.
#
# [FINISH] Hoàn tất crawl. File: mst_gov_data.csv

# %% [markdown]
# ### Trang baochinhphu.vn

# %%
import requests
import re
import csv
import time
import html
from bs4 import BeautifulSoup
from typing import Optional, List, Dict, Tuple
from urllib.parse import urljoin

# --- CẤU HÌNH ---
session = requests.Session()
session.headers.update({
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/124.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Referer': 'https://baochinhphu.vn/',
})

DOMAIN = 'https://baochinhphu.vn'

# Regex: Bắt các link bài viết (thường kết thúc bằng id số và .htm)
ARTICLE_URL_RE = re.compile(r'.*\d+\.htm$', re.IGNORECASE)

# --- TUỲ CHỈNH ---
MAX_PAGES_PER_LINK = 50      # Tăng lên 50 để lấy nhiều tin hơn (tương đương 50 lần ấn xem thêm)
SLEEP_BETWEEN_REQUESTS = 0.5 
OUTPUT_FILE = 'baochinhphu_data.csv' 

# --- HÀM TIỆN ÍCH ---
def clean_text(s: str) -> str:
    if not s: return ''
    s = html.unescape(s)
    return re.sub(r'\s+', ' ', s).strip()

def normalize_href(href: str, base: str = DOMAIN) -> Optional[str]:
    if not href: return None
    href = href.strip()
    if href.startswith(('javascript:', '#', 'mailto:', 'tel:')): return None
    if href.startswith('/'): return urljoin(DOMAIN, href)
    if href.startswith('http'): return href
    return urljoin(base, href)

def make_page_url(base: str, page: int) -> str:
    """Tạo URL phân trang: ?page=2, ?page=3..."""
    if page <= 1: return base
    if '?' in base:
        if re.search(r'[?&]page=\d+', base):
            return re.sub(r'([?&])page=\d+', lambda m: m.group(1) + f'page={page}', base)
        else:
            return f"{base}&page={page}"
    else:
        return f"{base}?page={page}"

# --- PARSE CHI TIẾT BÀI VIẾT ---
def parse_article(url: str) -> Dict[str, str]:
    result = {
        'title': '', 'summary': '', 
        'content': '', 'keywords': '', 'publish_time': '', 'url': url
    }
    
    try:
        resp = session.get(url, timeout=20)
        if resp.status_code != 200: return result
        
        resp.encoding = 'utf-8'
        soup = BeautifulSoup(resp.text, 'html.parser')

        # --- META ---
        if soup.title: result['title'] = clean_text(soup.title.string)

        meta_desc = soup.find('meta', property='og:description')
        if meta_desc: result['summary'] = clean_text(meta_desc.get('content'))

        link_canonical = soup.find('link', attrs={'rel': 'canonical'})
        if link_canonical: result['url'] = link_canonical.get('href', url)

        meta_kw = soup.find('meta', attrs={'name': 'news_keywords'})
        if not meta_kw: meta_kw = soup.find('meta', attrs={'name': 'keywords'})
        if meta_kw: result['keywords'] = clean_text(meta_kw.get('content'))

        # --- BODY ---
        time_tag = soup.find(class_='detail-time')
        if time_tag: result['publish_time'] = clean_text(time_tag.get_text())

        body = soup.select_one('.detail-content.afcbc-body.clearfix')
        if body:
            # Xóa rác
            for junk in body.find_all(['img', 'figure', 'figcaption', 'script', 'style', 'table', 'div.box-relate']):
                junk.decompose()
            # Xóa H2 theo yêu cầu
            for h2 in body.find_all('h2'):
                h2.decompose()

            cleaned_paras = []
            paras = body.find_all('p')
            if paras:
                for p in paras:
                    txt = clean_text(p.get_text())
                    if len(txt) > 2: cleaned_paras.append(txt)
                result['content'] = ' '.join(cleaned_paras)
            else:
                result['content'] = clean_text(body.get_text())

        return result
    except Exception as e:
        print(f"Lỗi parse ({url}): {e}")
        return result

# --- CRAWL DANH SÁCH LINK VÀ CHECK NÚT LOADMORE ---
def get_links_and_check_loadmore(url: str) -> Tuple[List[str], bool]:
    """
    Trả về: (Danh sách link bài viết, Có nút 'Xem thêm' hay không?)
    """
    try:
        resp = session.get(url, timeout=20)
        if resp.status_code != 200: return [], False
        
        soup = BeautifulSoup(resp.text, 'html.parser')
        article_links = set()

        # 1. Lấy link bài viết
        for a in soup.find_all('a', href=True):
            full = normalize_href(a['href'], base=url)
            if not full: continue
            
            if DOMAIN in full and ARTICLE_URL_RE.search(full):
                if full.split('?')[0] != url.split('?')[0]: 
                    article_links.add(full)

        # 2. [QUAN TRỌNG] Kiểm tra sự tồn tại của class="loadmore"
        # Nếu tìm thấy class này nghĩa là trang web báo hiệu còn dữ liệu để xem thêm
        has_loadmore = False
        loadmore_btn = soup.select_one('.loadmore')
        
        # Đôi khi nút tồn tại nhưng bị ẩn (display: none), ta kiểm tra kỹ hơn
        if loadmore_btn:
            style = loadmore_btn.get('style', '').lower()
            if 'display: none' not in style:
                has_loadmore = True
        
        return sorted(list(article_links)), has_loadmore

    except Exception:
        return [], False

# --- MAIN LOGIC ---
def main(topics_dict):
    seen_global = set()
    fieldnames = ['topic', 'title', 'summary', 'keywords', 'content', 'publish_time', 'url']

    with open(OUTPUT_FILE, 'w', newline='', encoding='utf-8-sig') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()

        for topic_name, url_data in topics_dict.items():
            print(f"\n ========== CHỦ ĐỀ: {topic_name} ==========")
            list_urls = [url_data] if isinstance(url_data, str) else list(url_data)

            for sub_url in list_urls:
                print(f"   >>> Quét nhánh: {sub_url}")
                page = 1
                keep_crawling = True # Biến cờ để kiểm soát vòng lặp dựa trên nút Loadmore
                
                while page <= MAX_PAGES_PER_LINK and keep_crawling:
                    p_url = make_page_url(sub_url, page)
                    print(f"      -> Trang {page}: {p_url}")
                    
                    # Lấy link và trạng thái nút Loadmore
                    new_links_raw, has_loadmore_btn = get_links_and_check_loadmore(p_url)
                    
                    # Cập nhật trạng thái vòng lặp
                    # Nếu không tìm thấy nút loadmore -> Đây là trang cuối -> Dừng sau lần này
                    if not has_loadmore_btn:
                        print("         (Không tìm thấy nút 'Xem thêm', chuẩn bị dừng nhánh này).")
                        keep_crawling = False
                    
                    # Lọc trùng lặp
                    new_links = [l for l in new_links_raw if l not in seen_global]
                    
                    if not new_links:
                        print("         (Không có bài mới).")
                    else:
                        count_ok = 0
                        for link in new_links:
                            seen_global.add(link)
                            data = parse_article(link)
                            
                            if data['title'] and data['content']:
                                writer.writerow({
                                    'topic': topic_name,
                                    'title': data['title'],
                                    'summary': data['summary'],
                                    'keywords': data['keywords'],
                                    'content': data['content'],
                                    'publish_time': data['publish_time'],
                                    'url': data['url']
                                })
                                count_ok += 1
                                print(f"         ✅ {data['title'][:60]}...")
                            time.sleep(0.1) 
                        
                        print(f"      -> Đã lưu {count_ok} bài.")
                    
                    page += 1
                    time.sleep(SLEEP_BETWEEN_REQUESTS)

    print("\n[FINISH] Hoàn tất crawl. File:", OUTPUT_FILE)

# --- DANH MỤC CẦN CRAWL ---
if __name__ == "__main__":
    topics = {
        'Chính trị': ['https://baochinhphu.vn/chinh-tri.htm',
                      'https://baochinhphu.vn/chinh-tri/to-chuc-nhan-su.htm',
                      'https://baochinhphu.vn/chinh-tri/doi-ngoai.htm',
                      'https://baochinhphu.vn/chinh-tri/hoi-nhap.htm',
                      'https://baochinhphu.vn/chi-dao-quyet-dinh-cua-chinh-phu-thu-tuong-chinh-phu.htm'],
        'Kinh tế': ['https://baochinhphu.vn/kinh-te/ngan-hang.htm',
                    'https://baochinhphu.vn/kinh-te.htm',
                    'https://baochinhphu.vn/kinh-te/chung-khoan.htm',
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 242
#     211 if __name__ == "__main__":
#     212     topics = {
#     213         'Chính trị': ['https://baochinhphu.vn/chinh-tri.htm',
#     214                       'https://baochinhphu.vn/chinh-tri/to-chuc-nhan-su.htm',
#    (...)
#     239                     'https://baochinhphu.vn/quoc-te/viet-nam-asean.htm']
#     240     }
# --> 242     main(topics)
#
# Cell In[5], line 170, in main(topics_dict)
#     167 print(f"      -> Trang {page}: {p_url}")
#     169 # Lấy link và trạng thái nút Loadmore
# --> 170 new_links_raw, has_loadmore_btn = get_links_and_check_loadmore(p_url)
#     172 # Cập nhật trạng thái vòng lặp
#     173 # Nếu không tìm thấy nút loadmore -> Đây là trang cuối -> Dừng sau lần này
#     174 if not has_loadmore_btn:
#
# Cell In[5], line 119, in get_links_and_check_loadmore(url)
#     116 resp = session.get(url, timeout=20)
#     117 if resp.status_code != 200: return [], False
# --> 119 soup = BeautifulSoup(resp.text, 'html.parser')
#     120 article_links = set()
#     122 # 1. Lấy link bài viết
#
# File c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py:473, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     471 self.builder.initialize_soup(self)
#     472 try:
# --> 473     self._feed()
#     474     success = True
#     475     break
#
# File c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\__init__.py:658, in BeautifulSoup._feed(self)
#     655 self.builder.reset()
#     657 if self.markup is not None:
# --> 658     self.builder.feed(self.markup)
#     659 # Close out any unfinished strings and close all the open tags.
#     660 self.endData()
#
# File c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\builder\_htmlparser.py:467, in HTMLParserTreeBuilder.feed(self, markup)
#     464 parser = BeautifulSoupHTMLParser(self.soup, *args, **kwargs)
#     466 try:
# --> 467     parser.feed(markup)
#     468     parser.close()
#     469 except AssertionError as e:
#     470     # html.parser raises AssertionError in rare cases to
#     471     # indicate a fatal problem with the markup, especially
#     472     # when there's an error in the doctype declaration.
#
# File c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\html\parser.py:203, in HTMLParser.goahead(self, end)
#     201 if match:
#     202     name = match.group()[2:-1]
# --> 203     self.handle_charref(name)
#     204     k = match.end()
#     205     if not startswith(';', k-1):
#
# File c:\Users\ductr\AppData\Local\Programs\Python\Python39\lib\site-packages\bs4\builder\_htmlparser.py:252, in BeautifulSoupHTMLParser.handle_charref(self, name)
#     245 if real_name < 256:
#     246     # HTML numeric entities are supposed to reference Unicode
#     247     # code points, but sometimes they reference code points in
#     248     # some other encoding (ahem, Windows-1252). E.g. &#147;
#     249     # instead of &#201; for LEFT DOUBLE QUOTATION MARK. This
#     250     # code tries to detect this situation and compensate.
#     251     for encoding in (self.soup.original_encoding, "windows-1252"):
# --> 252         if not encoding:
#     253             continue
#     254         try:
#
# KeyboardInterrupt:
